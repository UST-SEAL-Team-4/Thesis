# %%
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform
from project.utils import collatev2
import winsound
from project.utils import compute_statistics
from project.evaluation import isa_rpn_metric, isa_vit_metric, Tracker
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.21 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations

# %%
vit_tk = Tracker()
rpn_tk = Tracker()

# %% [markdown]
# ### Monitoring and CUDA Setup

# %%
import logging
from datetime import datetime as dtt
import os

path = 'logs'
os.makedirs(path, exist_ok=True)
os.makedirs('history', exist_ok=True)
rn = dtt.now()
dte = rn.strftime('%b_%d_%Y_%H%M%S')

logger = logging.getLogger('kess')
fh = logging.FileHandler(f'logs/rpn_vit_{dte}.log')
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)

logger.setLevel(logging.DEBUG)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)

logger.addHandler(fh)

dte
# Out:
# 'Nov_19_2024_174153'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
vit_tk.date = rn
vit_tk.logfile = f'rpn_vit_{dte}.log'
vit_tk.device = device

rpn_tk.date = rn
rpn_tk.logfile = f'rpn_vit_{dte}.log'
rpn_tk.device = device

# %% [markdown]
# ### Config for RPN and ViT Fitter

# %%
from project.model import RPN, ISAVIT

rpn_config = {
    'model': RPN(
        input_dim=512,
        output_dim=4,
        image_size=300,
        global_context=True,
        nh=4,
        pretrained=True
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 2,
    'loss': nn.SmoothL1Loss(),
    'lr': 0.0001
}
# Out:
# 324
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
vit_config = {
    'model': ISAVIT(
        d_model=512,
        patch_size=32,
        dim_ff=1600,
        global_context=True,
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 2,
    'loss': nn.BCEWithLogitsLoss(),
    'lr': 0.0001
}

# %%
vit_tk.model = 'ViT'
vit_tk.model_hyperparams = vit_config['model'].config
vit_tk.optimizer = f"{vit_config['optimizer']}"
vit_tk.epochs = vit_config['epochs']
vit_tk.loss = f"{vit_config['loss']}"
vit_tk.lr = vit_config['lr']

rpn_tk.model = 'RPN'
rpn_tk.model_hyperparams = rpn_config['model'].config
rpn_tk.uses_resnet = rpn_config['model'].config['pretrained']
rpn_tk.optimizer = f"{rpn_config['optimizer']}"
rpn_tk.epochs = rpn_config['epochs']
rpn_tk.loss = f"{rpn_config['loss']}"
rpn_tk.lr = rpn_config['lr']

# %% [markdown]
# ### Dataset Loading

# %%
data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 8)

# %%
data = data.query('has_microbleed_slice == 1').reset_index(drop=True)
vit_tk.only_cmb_slices = True
rpn_tk.only_cmb_slices = True
data
# Out:
#                                                    mri  \
# 0    C:\Users\araza\Documents\1\gits\thesis_project...
# 1    C:\Users\araza\Documents\1\gits\thesis_project...
# 2    C:\Users\araza\Documents\1\gits\thesis_project...
# 3    C:\Users\araza\Documents\1\gits\thesis_project...
# 4    C:\Users\araza\Documents\1\gits\thesis_project...
# ..                                                 ...
# 359  C:\Users\araza\Documents\1\gits\thesis_project...
# 360  C:\Users\araza\Documents\1\gits\thesis_project...
# 361  C:\Users\araza\Documents\1\gits\thesis_project...
# 362  C:\Users\araza\Documents\1\gits\thesis_project...
# 363  C:\Users\araza\Documents\1\gits\thesis_project...
#
#                                                  masks  target  \
# 0    C:\Users\araza\Documents\1\gits\thesis_project...       8
# 1    C:\Users\araza\Documents\1\gits\thesis_project...       9
# 2    C:\Users\araza\Documents\1\gits\thesis_project...      11
# 3    C:\Users\araza\Documents\1\gits\thesis_project...      12
# 4    C:\Users\araza\Documents\1\gits\thesis_project...      15
# ..                                                 ...     ...
# 359  C:\Users\araza\Documents\1\gits\thesis_project...      25
# 360  C:\Users\araza\Documents\1\gits\thesis_project...      26
# 361  C:\Users\araza\Documents\1\gits\thesis_project...      24
# 362  C:\Users\araza\Documents\1\gits\thesis_project...      25
# 363  C:\Users\araza\Documents\1\gits\thesis_project...      20
#
#      has_microbleed_case  has_microbleed_slice  cohort   max_value  slices
# 0                      1                     1       1  928.405273      35
# 1                      1                     1       1  928.405273      35
# 2                      1                     1       1  928.405273      35
# 3                      1                     1       1  928.405273      35
# 4                      1                     1       1  928.405273      35
# ..                   ...                   ...     ...         ...     ...
# 359                    1                     1       3  241.000000      36
# 360                    1                     1       3  241.000000      36
# 361                    1                     1       3  448.000000      39
# 362                    1                     1       3  448.000000      39
# 363                    1                     1       3  253.000000      39
#
# [364 rows x 8 columns]

# %% [markdown]
# ### Preprocessing and Train-Test Split Function

# %%
from sklearn.model_selection import train_test_split

def make_loaders(data,
                 cohort,
                 test_size=0.2,
                 random_state=12,
                 target_shape=(300, 300),
                 rpn_mode=True,
                 logger=None,
                 rpn_tracker=rpn_tk,
                 vit_tracker=vit_tk
                ):
    if cohort == 1:
        rpn_tracker.cohort1 = True
        vit_tracker.cohort1 = True
    if cohort == 2:
        rpn_tracker.cohort2 = True
        vit_tracker.cohort2 = True
    if cohort == 3:
        rpn_tracker.cohort3 = True
        vit_tracker.cohort3 = True
    
    rpn_tracker.test_size = test_size
    vit_tracker.target_shape = target_shape
    data = data[data.cohort == cohort]
    
    s = f'Creating loaders for Cohort {cohort}\n'

    data_train, data_test = train_test_split(
        data,
        test_size=test_size,
        random_state=random_state
    )

    s += f'TRAIN & TEST: {data_train.shape, data_test.shape}\n'

    paths = data_train.stripped.unique().tolist()
    s += f'Total Unique MRI Samples in data_train: {len(paths)}\n'
    
    global_min, global_max = compute_statistics(paths)
    s += f'GLOBAL MIN & MAX {global_min, global_max}\n'

    transform = NiftiToTensorTransform(
        target_shape=target_shape,
        rpn_mode=rpn_mode,
        normalization=(global_min, global_max)
    )

    train_set = VALDODataset(
        cases=data_train.stripped.tolist(),
        masks=data_train.masks.tolist(),
        target=data_train.target.tolist(),
        transform=transform
    )
    val_set = VALDODataset(
        cases=data_test.stripped.tolist(),
        masks=data_test.masks.tolist(),
        target=data_test.target.tolist(),
        transform=transform
    )

    if logger != None:
        logger.info(s)
    else:
        print(s)
    
    return train_set, val_set

# %% [markdown]
# ### RPN Fitter

# %%
from project import Fitter

# %%
class RPNFitter(Fitter):
    def train_one_epoch(self, train_loader):
        self.model.train()
        loss_history = []
        evaluation_metric = {
            'iou_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': []
        }
        counter = 0
        for batch in train_loader:
            # self.log('----------------- BATCH -----------------')
            Y = []
            T = []
            for slices, masks, target, case in batch:
                x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                # x = slices.squeeze(1).float().to(self.device)
                masks = masks.squeeze(1).float().to(self.device)/300
                y = self.model(x, target)

                iou_score, precision_score, recall_score, f1_score = isa_rpn_metric(image_size=300, target_bbox=masks[target], predicted_bbox=y)
                evaluation_metric['iou_score'].append(iou_score)
                evaluation_metric['precision_score'].append(precision_score)
                evaluation_metric['recall_score'].append(recall_score)
                evaluation_metric['f1_score'].append(f1_score)
                # self.log(f'EVAL METS: {iou_score, precision_score, recall_score, f1_score}')
                Y.append(y)
                T.append(masks[target])
            
            losses = self.loss(torch.stack(Y), torch.stack(T))
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += 1
            # if counter % len(batch) == 0:
            self.log(f'Batch:\t{counter}/{len(train_loader)}')
            self.log(f'Batch samples:\t{len(batch)}')
            self.log(f'Current error:\t{losses}\n')
            
            
            loss_history.append(losses.detach().cpu().numpy())
        
        self.log(f'\nTraining Evaluation Metric:')
        self.log(f"Avg IOU: {sum(evaluation_metric['iou_score']) / len(evaluation_metric['iou_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        
        return loss_history, evaluation_metric
    def validation(self, val_loader):
        self.model.eval()
        loss_history = []
        evaluation_metric = {
            'iou_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': []
        }
        with torch.inference_mode():
            for batch in val_loader:
                Y = []
                T = []
                for slices, masks, target, case in batch:
                    x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                    # x = slices.squeeze(1).float().to(self.device)
                    masks = masks.squeeze(1).float().to(self.device)/300
                    y = self.model(x, target)
                    iou_score, precision_score, recall_score, f1_score = isa_rpn_metric(image_size=300, target_bbox=masks[target], predicted_bbox=y)
                    evaluation_metric['iou_score'].append(iou_score)
                    evaluation_metric['precision_score'].append(precision_score)
                    evaluation_metric['recall_score'].append(recall_score)
                    evaluation_metric['f1_score'].append(f1_score)
                    Y.append(y)
                    T.append(masks[target])
                losses = self.loss(torch.stack(Y), torch.stack(T))
                loss_history.append(losses.cpu().numpy())
        self.log(f'\nValidation Evaluation Metric:')
        self.log(f"Avg IOU: {sum(evaluation_metric['iou_score']) / len(evaluation_metric['iou_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        return loss_history, evaluation_metric

# %% [markdown]
# ### ViT Fitter

# %%
from project import Fitter

class ViTFitter(Fitter):
    
    def fit(self, train_loader, val_loader, stage1):
        train_history = []
        val_history = []
        train_metric_history = []
        val_metric_history = []
        for epoch in range(self.epochs):
            self.log(f'EPOCH {epoch} ==============================')
            train_loss, train_metric = self.train_one_epoch(train_loader, stage1)
            val_loss, val_metric = self.validation(val_loader, stage1)
            train_history.append(train_loss)
            val_history.append(val_loss)
            train_metric_history.append(train_metric)
            val_metric_history.append(val_metric)
        return train_history, val_history, train_metric_history, val_metric_history

    def train_one_epoch(self, train_loader, stage1):
        self.model.train()
        loss_history = []
        evaluation_metric = {
            'dice_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': [],
            'fpr': []
        }
        counter = 0
        for batch in train_loader:
            Y = []
            T = []
            for slices, masks, target, case in batch:
                # slices = slices.squeeze(1).float().to(self.device)
                slices = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                masks = masks.float().to(self.device)

                with torch.inference_mode():
                    x, t = stage1(slices, masks, target)
                
                # self.log(f'{x.requires_grad}, {t.requires_grad}')
                # self.log(f'{x.shape}, {t.shape}')

                x = x.flatten(2).float().to(self.device)
                t = t.flatten(2).float().to(self.device)
                # self.log(f'XT SHAPES: {x.shape}, {t.shape}')
                
                y = self.model(x, target)
                
                # print('Prediction:', (y.sigmoid() >= 0.5).int().unique())
                # print('Truth:', (t[target] >= 0).int().unique())

                dice_score, precision_score, recall_score, f1_score, fpr = isa_vit_metric((y.sigmoid().squeeze().detach().cpu().numpy() >= 0.5), (t[target].squeeze().detach().cpu().numpy() > 0))

                evaluation_metric['dice_score'].append(dice_score)
                evaluation_metric['precision_score'].append(precision_score)
                evaluation_metric['recall_score'].append(recall_score)
                evaluation_metric['f1_score'].append(f1_score)
                evaluation_metric['fpr'].append(fpr)
                # self.log(f'EVAL METS: {dice_score, precision_score, recall_score, f1_score, fpr}')

                Y.append(y)
                T.append(t[target])
            
            losses = self.loss(torch.stack(Y), torch.stack(T))
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += 1
            self.log(f'Batch:\t{counter}/{len(train_loader)}')
            self.log(f'Batch samples:\t{len(batch)}')
            self.log(f'Current error:\t{losses}\n')
            
            loss_history.append(losses.detach().cpu().numpy())
        
        self.log(f'\nTraining Evaluation Metric:')
        self.log(f"Avg Dice: {sum(evaluation_metric['dice_score']) / len(evaluation_metric['dice_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        self.log(f"Avg FPR: {sum(evaluation_metric['fpr']) / len(evaluation_metric['fpr'])}\n")
        return loss_history, evaluation_metric
    
    def validation(self, val_loader, stage1):
        self.model.eval()
        loss_history = []
        evaluation_metric = {
            'dice_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': [],
            'fpr': []
        }
        with torch.inference_mode():
            for batch in val_loader:
                Y = []
                T = []
                for slices, masks, target, case in batch:
                    # slices = slices.squeeze(1).float().to(self.device)
                    slices = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                    masks = masks.float().to(self.device)
                    x, t = stage1(slices, masks, target)
                    x = x.flatten(2).float().to(self.device)
                    t = t.flatten(2).float().to(self.device)
                    y = self.model(x, target)

                    dice_score, precision_score, recall_score, f1_score, fpr = isa_vit_metric((y.sigmoid().squeeze().detach().cpu().numpy() >= 0.5), (t[target].squeeze().detach().cpu().numpy() > 0))
                    evaluation_metric['dice_score'].append(dice_score)
                    evaluation_metric['precision_score'].append(precision_score)
                    evaluation_metric['recall_score'].append(recall_score)
                    evaluation_metric['f1_score'].append(f1_score)
                    evaluation_metric['fpr'].append(fpr)
                    Y.append(y)
                    T.append(t[target])
                
                losses = self.loss(torch.stack(Y), torch.stack(T))
                loss_history.append(losses.cpu().numpy())
        
        self.log(f'\nValidations Evaluation Metric:')
        self.log(f"Avg Dice: {sum(evaluation_metric['dice_score']) / len(evaluation_metric['dice_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        self.log(f"Avg FPR: {sum(evaluation_metric['fpr']) / len(evaluation_metric['fpr'])}\n")
        return loss_history, evaluation_metric

# %% [markdown]
# ### Train-Test Split

# %%
rpn_t1, rpn_v1 = make_loaders(
    data=data,
    cohort=1,
    rpn_mode=True
)

rpn_t3, rpn_v3 = make_loaders(
    data=data,
    cohort=3,
    rpn_mode=True
)
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# Creating loaders for Cohort 1
# TRAIN & TEST: ((36, 8), (9, 8))
# Total Unique MRI Samples in data_train: 8
# GLOBAL MIN & MAX (0.0, 1417.92822265625)
#
# Creating loaders for Cohort 3
# TRAIN & TEST: ((37, 8), (10, 8))
# Total Unique MRI Samples in data_train: 26
# GLOBAL MIN & MAX (0.0, 664.0)

# %%
vit_t1, vit_v1 = make_loaders(
    data=data,
    cohort=1,
    rpn_mode=False
)

vit_t3, vit_v3 = make_loaders(
    data=data,
    cohort=3,
    rpn_mode=False
)
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# Creating loaders for Cohort 1
# TRAIN & TEST: ((36, 8), (9, 8))
# Total Unique MRI Samples in data_train: 8
# GLOBAL MIN & MAX (0.0, 1417.92822265625)
#
# Creating loaders for Cohort 3
# TRAIN & TEST: ((37, 8), (10, 8))
# Total Unique MRI Samples in data_train: 26
# GLOBAL MIN & MAX (0.0, 664.0)

# %%
from torch.utils.data import ConcatDataset

rpn_train_set = ConcatDataset([rpn_t1, rpn_t3])
rpn_test_set = ConcatDataset([rpn_v1, rpn_v3])

print(f'RPN Train Set Size: {rpn_train_set}')
print(f'RPN Test Set Size: {rpn_test_set}')

vit_train_set = ConcatDataset([vit_t1, vit_t3])
vit_test_set = ConcatDataset([vit_v1, vit_v3])

print(f'ViT Train Set Size: {vit_train_set}')
print(f'ViT Test Set Size: {vit_test_set}')
# Out:
# RPN Train Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x00000198B6D3DFC0>
# RPN Test Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x00000198B6D3EFB0>
# ViT Train Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x00000198B6D3EE60>
# ViT Test Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x00000198B6D3EE00>

# %%
batchs = 20
rpn_tk.batch_size = batchs
vit_tk.batch_size = batchs
rpn_test_dataloader = DataLoader(
    rpn_test_set,
    shuffle=True,
    batch_size=batchs,
    collate_fn=collatev2
)

vit_test_dataloader = DataLoader(
    vit_test_set,
    shuffle=True,
    batch_size=batchs,
    collate_fn=collatev2
)

# %% [markdown]
# ### K-Fold Cross Validation

# %%
from torch.utils.data import Subset
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=45)
kf
# Out:
# KFold(n_splits=5, random_state=45, shuffle=True)

# %%
from project.model import Feeder, GCRPN
from project.preprocessing import NiftiToTensorTransform, get_transform

image_size = 300
patch_size = 32

# %%
rpn_test_iou = []
rpn_test_precision = []
rpn_test_recall = []
rpn_test_f1 = []

vit_test_dice = []
vit_test_precision = []
vit_test_recall = []
vit_test_f1 = []
vit_test_fpr = []

# %%
rpn_fold_metrics = []
vit_fold_metrics = []


fold_dir = f'./fold/{dte}'
os.makedirs(fold_dir, exist_ok=True)

for i, (train_index, val_index) in enumerate(kf.split(rpn_train_set)):
    print(f'Fold {i + 1}/{5}')
    
    # RPN
    rpn_config['model'] = RPN(**rpn_tk.model_hyperparams).to(device)
    
    rpn_fitter = RPNFitter(rpn_config, logger=logger)
    
    rpn_train_subset = Subset(rpn_train_set, train_index)
    rpn_val_subset = Subset(rpn_train_set, val_index)

    rpn_tk.batch_size = 5
    
    rpn_train_subset_dl = DataLoader(
        rpn_train_subset,
        shuffle=True,
        batch_size=rpn_tk.batch_size,
        collate_fn=collatev2
    )
    
    rpn_val_subset_dl = DataLoader(
        rpn_val_subset,
        shuffle=True,
        batch_size=rpn_tk.batch_size,
        collate_fn=collatev2
    )
    
    rpn_thist, rpn_vhist, rpn_tmhist, rpn_vmhist = rpn_fitter.fit(rpn_train_subset_dl, rpn_val_subset_dl)
    
    rpn_fold_metrics.append({
        'fold': i + 1,
        'training_history': rpn_thist,
        'validation_history': rpn_vhist,
        'training_metrics': rpn_tmhist,
        'validation_metrics': rpn_vmhist
    })
    
    rpn_h, rpn_mh = rpn_fitter.validation(rpn_test_dataloader)
    rpn_valmets = pd.DataFrame(rpn_mh)
    rpn_mets = rpn_valmets.mean()
    
    rpn_test_iou.append(rpn_mets.iou_score)
    rpn_test_precision.append(rpn_mets.precision_score)
    rpn_test_recall.append(rpn_mets.recall_score)
    rpn_test_f1.append(rpn_mets.f1_score)
    
    os.makedirs(f'{fold_dir}/fold_{i+1}', exist_ok=True)
    torch.save(rpn_fitter.model.state_dict(), f'{fold_dir}/fold_{i+1}/rpn_fold{i+1}.pt')
    
    # FEEDER
    
    resize = get_transform(
        height=patch_size,
        width=patch_size,
        p=1.0,
        rpn_mode=False
    )

    feeder = Feeder(resize)
    stone = GCRPN(
        rpn=rpn_fitter.model,
        feeder=feeder,
        image_size=image_size,
        patch_size=patch_size
    ).to(device)
    
    # ViT
    
    vit_config['model'] = ISAVIT(**vit_tk.model_hyperparams).to(device)
    
    vit_fitter = ViTFitter(vit_config, logger=logger)
    
    train_subset = Subset(vit_train_set, train_index)
    val_subset = Subset(vit_train_set, val_index)

    vit_tk.batch_size = 5
    
    train_subset_dl = DataLoader(
        train_subset,
        shuffle=True,
        batch_size=vit_tk.batch_size,
        collate_fn=collatev2
    )
    
    val_subset_dl = DataLoader(
        val_subset,
        shuffle=True,
        batch_size=vit_tk.batch_size,
        collate_fn=collatev2
    )
    
    vit_thist, vit_vhist, vit_tmhist, vit_vmhist = vit_fitter.fit(train_subset_dl, val_subset_dl, stone)
    
    vit_fold_metrics.append({
        'fold': i + 1,
        'training_history': vit_thist,
        'validation_history': vit_vhist,
        'training_metrics': vit_tmhist,
        'validation_metrics': vit_vmhist
    })
    
    vit_h, vit_mh = vit_fitter.validation(vit_test_dataloader, stone)
    vit_valmets = pd.DataFrame(vit_mh)
    vit_mets = vit_valmets.mean()
    
    vit_test_dice.append(vit_mets.dice_score)
    vit_test_precision.append(vit_mets.precision_score)
    vit_test_recall.append(vit_mets.recall_score)
    vit_test_f1.append(vit_mets.f1_score)
    vit_test_fpr.append(vit_mets.fpr)
    
    torch.save(vit_fitter.model.state_dict(), f'{fold_dir}/fold_{i+1}/vit_fold{i+1}.pt')
# Out:
# Fold 1/5
# 324
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# INFO:kess:EPOCH 0 ==============================
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# C:\Program Files\Python310\lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.04032210633158684
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	2/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.017310936003923416
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	3/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.013852894306182861
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	4/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.014424949884414673
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	5/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.009256663732230663
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	6/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.025217315182089806
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	7/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.015219122171401978
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	8/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.014127964153885841
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	9/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.015903249382972717
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	10/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.021180888637900352
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	11/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.014943301677703857
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	12/12
# INFO:kess:Batch samples:	3
# INFO:kess:Current error:	0.019401539117097855
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg IOU: 0.20564113542084292
# INFO:kess:Avg Precision: 0.31712958930413526
# INFO:kess:Avg Recall: 0.43639738620098295
# INFO:kess:Avg F1: 0.3115941887512675
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.2558592821160952
# INFO:kess:Avg Precision: 0.3183920785784721
# INFO:kess:Avg Recall: 0.6014997531970342
# INFO:kess:Avg F1: 0.3841288606325785
# INFO:kess:EPOCH 1 ==============================
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.01517429482191801
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	2/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.011447332799434662
#
# INFO:kess:Batch:	3/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.019202282652258873
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	4/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.009127634577453136
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	5/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.013327320106327534
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	6/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.010892504826188087
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	7/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.01189060416072607
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	8/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.020259583368897438
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	9/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.014804362319409847
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	10/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.013038364239037037
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	11/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.013897234573960304
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	12/12
# INFO:kess:Batch samples:	3
# INFO:kess:Current error:	0.011140558868646622
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg IOU: 0.26896513926250665
# INFO:kess:Avg Precision: 0.3819103235989038
# INFO:kess:Avg Recall: 0.5077791254533904
# INFO:kess:Avg F1: 0.39672246626738844
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.3201333910226822
# INFO:kess:Avg Precision: 0.4379632572333018
# INFO:kess:Avg Recall: 0.6188995569944382
# INFO:kess:Avg F1: 0.4676400532325109
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.23868558497021072
# INFO:kess:Avg Precision: 0.3572079598119384
# INFO:kess:Avg Recall: 0.4632879656396414
# INFO:kess:Avg F1: 0.35680449989281204
# INFO:kess:EPOCH 0 ==============================
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.7349820733070374
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	2/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.710996150970459
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	3/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6850454211235046
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	4/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6714543104171753
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	5/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6517319679260254
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	6/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6339972615242004
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	7/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.611534833908081
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	8/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.5980812907218933
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	9/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.5821186900138855
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	10/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.5638285875320435
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	11/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.5549960136413574
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	12/12
# INFO:kess:Batch samples:	3
# INFO:kess:Current error:	0.5355143547058105
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.001948402547894453
# INFO:kess:Avg Precision: 0.000982174191076524
# INFO:kess:Avg Recall: 0.18563218390804595
# INFO:kess:Avg F1: 0.001948402547894453
# INFO:kess:Avg FPR: 0.25742703313598997
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.002907832738718064
# INFO:kess:Avg Precision: 0.0015270465547935028
# INFO:kess:Avg Recall: 0.14331550802139034
# INFO:kess:Avg F1: 0.0029078327387180645
# INFO:kess:Avg FPR: 0.14699863713474587
#
# INFO:kess:EPOCH 1 ==============================
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.532869279384613
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	2/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4957544505596161
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	3/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.49405309557914734
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	4/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4721718728542328
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	5/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4778359532356262
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	6/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.46161046624183655
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	7/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4695449471473694
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	8/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.43622857332229614
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	9/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.41836443543434143
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	10/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4304800033569336
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	11/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4073105752468109
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	12/12
# INFO:kess:Batch samples:	3
# INFO:kess:Current error:	0.385626882314682
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0021030481475930933
# INFO:kess:Avg Precision: 0.0010718487070382862
# INFO:kess:Avg Recall: 0.0896551724137931
# INFO:kess:Avg F1: 0.0021030481475930933
# INFO:kess:Avg FPR: 0.10673372209914546
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0
# INFO:kess:Avg Precision: 0.0
# INFO:kess:Avg Recall: 0.0
# INFO:kess:Avg F1: 0.0
# INFO:kess:Avg FPR: 0.034979856358923984
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.005847953216374269
# INFO:kess:Avg Precision: 0.0030110542814717044
# INFO:kess:Avg Recall: 0.10526315789473684
# INFO:kess:Avg F1: 0.005847953216374269
# INFO:kess:Avg FPR: 0.035247395852004676
#
# INFO:kess:EPOCH 0 ==============================
# Fold 2/5
# 324
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.04488617554306984
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	2/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.02266218326985836
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	3/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.016469841822981834
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	4/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.012653556652367115
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	5/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.020838474854826927
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	6/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.00987109262496233
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	7/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.018458206206560135
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	8/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.014531070366501808
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	9/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.016852473840117455
#
# INFO:kess:Batch:	10/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.010575435124337673
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	11/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.017137009650468826
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	12/12
# INFO:kess:Batch samples:	3
# INFO:kess:Current error:	0.023795396089553833
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg IOU: 0.21857764902685223
# INFO:kess:Avg Precision: 0.28904416604802524
# INFO:kess:Avg Recall: 0.5126092227753895
# INFO:kess:Avg F1: 0.3254684669704273
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.27200585256020227
# INFO:kess:Avg Precision: 0.2936116298039754
# INFO:kess:Avg Recall: 0.8167956312497456
# INFO:kess:Avg F1: 0.41569224894046786
# INFO:kess:EPOCH 1 ==============================
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.023556727916002274
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	2/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.009779074229300022
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	3/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.017390498891472816
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	4/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.012986189685761929
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	5/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.006448649801313877
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	6/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.01379896979779005
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	7/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.01258667092770338
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	8/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.00953492522239685
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	9/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.01529945433139801
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	10/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.00886328425258398
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	11/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.015299536287784576
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	12/12
# INFO:kess:Batch samples:	3
# INFO:kess:Current error:	0.008881059475243092
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg IOU: 0.2782285129209852
# INFO:kess:Avg Precision: 0.4044101448601176
# INFO:kess:Avg Recall: 0.5193068027046734
# INFO:kess:Avg F1: 0.41003734400849146
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.28160676956176756
# INFO:kess:Avg Precision: 0.3718491723140081
# INFO:kess:Avg Recall: 0.5258723060290019
# INFO:kess:Avg F1: 0.414816681543986
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.25669179454837976
# INFO:kess:Avg Precision: 0.3921502130596261
# INFO:kess:Avg Recall: 0.45627054532891825
# INFO:kess:Avg F1: 0.3833311449148153
# INFO:kess:EPOCH 0 ==============================
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.7354671955108643
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# ...
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.24643271808561526
# INFO:kess:Avg Precision: 0.3771278322919419
# INFO:kess:Avg Recall: 0.39891039148757335
# INFO:kess:Avg F1: 0.3620210640916699
# INFO:kess:EPOCH 0 ==============================
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.7357537150382996
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	2/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.7126726508140564
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	3/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6955621838569641
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	4/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6756741404533386
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	5/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6507534980773926
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	6/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6299908757209778
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	7/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6132961511611938
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	8/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.6015510559082031
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	9/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.580272376537323
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	10/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.5565274357795715
#
# INFO:kess:Batch:	11/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.5640285611152649
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	12/12
# INFO:kess:Batch samples:	4
# INFO:kess:Current error:	0.536630392074585
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0025707804587399067
# INFO:kess:Avg Precision: 0.00130473073930289
# INFO:kess:Avg Recall: 0.20894416318145134
# INFO:kess:Avg F1: 0.0025707804587399067
# INFO:kess:Avg FPR: 0.25595990497673354
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0
# INFO:kess:Avg Precision: 0.0
# INFO:kess:Avg Recall: 0.0
# INFO:kess:Avg F1: 0.0
# INFO:kess:Avg FPR: 0.13935313523996534
#
# INFO:kess:EPOCH 1 ==============================
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	1/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.519587516784668
#
# INFO:kess:Batch:	2/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.5060569643974304
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	3/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4927465617656708
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	4/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.49910789728164673
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	5/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.45857593417167664
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	6/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4636317789554596
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	7/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.44364848732948303
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	8/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4381624162197113
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	9/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.42122969031333923
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	10/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.4149220585823059
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	11/12
# INFO:kess:Batch samples:	5
# INFO:kess:Current error:	0.41210219264030457
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:Batch:	12/12
# INFO:kess:Batch samples:	4
# INFO:kess:Current error:	0.3867521286010742
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0025899124209083587
# INFO:kess:Avg Precision: 0.0013347919898426901
# INFO:kess:Avg Recall: 0.08525937339496661
# INFO:kess:Avg F1: 0.0025899124209083587
# INFO:kess:Avg FPR: 0.09796487242081674
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0
# INFO:kess:Avg Precision: 0.0
# INFO:kess:Avg Recall: 0.0
# INFO:kess:Avg F1: 0.0
# INFO:kess:Avg FPR: 0.028533165803232945
#
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0
# INFO:kess:Avg Precision: 0.0
# INFO:kess:Avg Recall: 0.0
# INFO:kess:Avg F1: 0.0
# INFO:kess:Avg FPR: 0.02919444627168945

# %%
import winsound

winsound.Beep(500, 500)
winsound.Beep(500, 500)
winsound.Beep(500, 500)

# %% [markdown]
# ### Metrics Visualization

# %% [markdown]
# `rpn_fold_metrics[i]`
#
# - represents each fold
#
# `rpn_fold_metrics[1].keys()`
#
# - 'fold', 'training_history', 'validation_history', 'training_metrics', 'validation_metrics'
#
# `rpn_fold_metrics[1]['training_metrics'][i]`
#
# - represents each epoch
#
# `rpn_fold_metrics[1]['training_metrics'][1].keys()`
#
# - 'iou_score', 'precision_score', 'recall_score', 'f1_score'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_metric_history(fold_metrics, metric, title=None):
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))

    for fold in range(len(rpn_fold_metrics)):
        train = []
        test = []
        ax=axes[fold]
        
        for epoch in range(len(fold_metrics[fold]['training_metrics'])):
            th = np.array(fold_metrics[fold]['training_metrics'][epoch][metric]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_metrics'][epoch][metric]).mean()
            test.append(vh)
            
        sns.lineplot(x=range(1, len(train)+1), y=train, label=f'Training {metric}', ax=ax)
        sns.lineplot(x=range(1, len(test)+1), y=test, label=f'Validation {metric}', ax=ax)
    
    
        ax.set_title(f'{title}Training and Validation {metric}: Fold {fold+1}')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric)
        ax.legend()
        
    plt.tight_layout()  
    plt.show()

# %%
rpn_metrics = ['iou_score', 'precision_score', 'recall_score', 'f1_score']

for metric in rpn_metrics:
    plot_metric_history(rpn_fold_metrics, metric, 'RPN ')

# %%
vit_metrics = ['dice_score', 'precision_score', 'recall_score', 'f1_score', 'fpr']

for metric in vit_metrics:
    plot_metric_history(vit_fold_metrics, metric, 'ViT ')

# %% [markdown]
# ### Loss History Visualization

# %%
def plot_loss_history(fold_metrics, title=None):
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))

    for fold in range(5):
        train = []
        test = []
        ax=axes[fold]
        
        for epoch in range(len(fold_metrics[fold]['training_history'])):
            th = np.array(fold_metrics[fold]['training_history'][epoch]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_history'][epoch]).mean()
            test.append(vh)
        
        sns.lineplot(x=range(1, len(train)+1), y=train, label='Training history', ax=ax)
        sns.lineplot(x=range(1, len(test)+1), y=test, label='Validation history', ax=ax)
        
        ax.set_title(f'{title}Training and Validation History: Fold {fold+1}')
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Loss')
        ax.legend()
    
    plt.tight_layout()  
    plt.show()

# %%
plot_loss_history(rpn_fold_metrics, 'RPN ')
plot_loss_history(vit_fold_metrics, 'ViT ')

# %% [raw]
# rpn_hist = torch.tensor(np.array(rpn_fold_metrics))
# vit_hist = torch.tensor(np.array(vit_fold_metrics))
#
# s_rpn_hist = f'history/{dte}_rpn_hist.pt'
# s_vit_hist = f'history/{dte}_vit_hist.pt'
# rpn_tk.saved_thist = s_rpn_hist
# vit_tk.saved_vhist = s_vit_hist
# torch.save(rpn_hist, s_rpn_hist)
# torch.save(vit_hist, s_vit_hist)

# %% [markdown]
# ### Evaluate Test Set

# %% [markdown]
# #### RPN

# %%
df_rpn_metrics = pd.DataFrame(columns=['fold', 'iou', 'precision', 'recall', 'f1'])
df_rpn_metrics
# Out:
# Empty DataFrame
# Columns: [fold, iou, precision, recall, f1]
# Index: []

# %%
df_rpn_metrics['fold'] = [1, 2, 3, 4, 5]
df_rpn_metrics['iou'] = rpn_test_iou
df_rpn_metrics['precision'] = rpn_test_precision
df_rpn_metrics['recall'] = rpn_test_recall
df_rpn_metrics['f1'] = rpn_test_f1

# %%
rpn_tk.iou = df_rpn_metrics.iou.mean()
rpn_tk.precision = df_rpn_metrics.precision.mean()
rpn_tk.recall = df_rpn_metrics.recall.mean()
rpn_tk.f1 = df_rpn_metrics.f1.mean()

# %%
df_rpn_metrics
# Out:
#    fold       iou  precision    recall        f1
# 0     1  0.238686   0.357208  0.463288  0.356804
# 1     2  0.256692   0.392150  0.456271  0.383331
# 2     3  0.203862   0.355519  0.360957  0.308388
# 3     4  0.188696   0.366132  0.269588  0.291408
# 4     5  0.246433   0.377128  0.398910  0.362021

# %%
rpn_iou_score = np.array(rpn_test_iou).mean()
rpn_precision_score = np.array(rpn_test_precision).mean()
rpn_recall_score = np.array(rpn_test_recall).mean()
rpn_f1_score = np.array(rpn_test_f1).mean()

print('RPN Test Set Performance Metrics')
print(f'Average IOU: {rpn_iou_score} ')
print(f'Average Precision: {rpn_precision_score} ')
print(f'Average Recall: {rpn_recall_score} ')
print(f'Average F1 Score: {rpn_f1_score} ')
# Out:
# RPN Test Set Performance Metrics
# Average IOU: 0.22687376088854908
# Average Precision: 0.36962744600452047
# Average Recall: 0.3898027850927687
# Average F1 Score: 0.34039064049904577

# %%
df_rpn_metrics.to_csv(f'{fold_dir}/rpn_metrics.csv')

# %% [markdown]
# #### ViT

# %%
df_vit_metrics = pd.DataFrame(columns=['fold', 'dice', 'precision', 'recall', 'f1', 'fpr'])
df_vit_metrics
# Out:
# Empty DataFrame
# Columns: [fold, dice, precision, recall, f1, fpr]
# Index: []

# %%
df_vit_metrics['fold'] = [1, 2, 3, 4, 5]
df_vit_metrics['dice'] = vit_test_dice
df_vit_metrics['precision'] = vit_test_precision
df_vit_metrics['recall'] = vit_test_recall
df_vit_metrics['f1'] = vit_test_f1
df_vit_metrics['fpr'] = vit_test_fpr

# %%
vit_tk.dice = df_vit_metrics.dice
vit_tk.precision = df_vit_metrics.precision
vit_tk.recall = df_vit_metrics.recall
vit_tk.f1 = df_vit_metrics.f1
vit_tk.fpr = df_vit_metrics.fpr

# %%
df_vit_metrics
# Out:
#    fold      dice  precision    recall        f1       fpr
# 0     1  0.005848   0.003011  0.105263  0.005848  0.035247
# 1     2  0.000000   0.000000  0.000000  0.000000  0.028048
# 2     3  0.002845   0.001595  0.013158  0.002845  0.039170
# 3     4  0.003509   0.001815  0.052632  0.003509  0.033581
# 4     5  0.000000   0.000000  0.000000  0.000000  0.029194

# %%
# vit_iou_score = np.array(vit_test_iou).mean()
vit_dice_score = np.array(vit_test_dice).mean()
vit_precision_score = np.array(vit_test_precision).mean()
vit_recall_score = np.array(vit_test_recall).mean()
vit_f1_score = np.array(vit_test_f1).mean()
vit_fpr_score = np.array(vit_test_fpr).mean()

print('ViT Test Set Performance Metrics')
print(f'Average Dice Score: {vit_dice_score} ')
print(f'Average Precision: {vit_precision_score} ')
print(f'Average Recall: {vit_recall_score} ')
print(f'Average F1 Score: {vit_f1_score} ')
print(f'Average FPR: {vit_fpr_score} ')
# Out:
# ViT Test Set Performance Metrics
# Average Dice Score: 0.002440335071914019
# Average Precision: 0.0012841665291756037
# Average Recall: 0.03421052631578947
# Average F1 Score: 0.0024403350719140195
# Average FPR: 0.033048213845901404

# %%
df_vit_metrics.to_csv(f'{fold_dir}/vit_metrics.csv')

# %% [markdown]
# ### Sample

# %% [markdown]
# #### RPN

# %%
rpn_sample = next(enumerate(rpn_test_dataloader))
rpn_slices, rpn_masks, rpn_target, rpn_case = rpn_sample[1][1]
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1

# %%
# rpn_x = rpn_slices.squeeze(1).float().to(device)
rpn_x = rpn_slices.squeeze(1).repeat(1, 3, 1, 1).float().to(device)
rpn_T = rpn_masks.squeeze(1).float().to(device)

# %%
rpn_y = rpn_fitter.model(rpn_x, rpn_target)
rpn_y
# Out:
# tensor([[0.3558, 0.2728, 0.7086, 0.6924]], device='cuda:0',
#        grad_fn=<SigmoidBackward0>)

# %%
rpn_fitter.loss(rpn_y, rpn_T[rpn_target])
# Out:
# tensor(109.1489, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)

# %%
rpn_bbox = rpn_masks[rpn_target].squeeze().cpu().long()
rpn_y = (rpn_y*300).squeeze().detach().cpu().long()

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

ax = sns.heatmap(rpn_x[rpn_target][0].squeeze().cpu(), cmap='gray')

truth = patches.Rectangle(
    (rpn_bbox[0], rpn_bbox[1]),
    rpn_bbox[2] - rpn_bbox[0],
    rpn_bbox[3] - rpn_bbox[1],
    linewidth=1, edgecolor='g', facecolor='none'
)

pred = patches.Rectangle(
    (rpn_y[0], rpn_y[1]),
    rpn_y[2] - rpn_y[0],
    rpn_y[3] - rpn_y[1],
    linewidth=1, edgecolor='r', facecolor='none'
)

ax.add_patch(truth)
ax.add_patch(pred)
plt.show()

# %% [markdown]
# #### ViT

# %%
vit_sample = next(enumerate(vit_test_dataloader))
vit_slices, vit_masks, vit_target, vit_case = vit_sample[1][0]
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1

# %%
# vit_slices = vit_slices.squeeze(1).float().to(device)
vit_slices = vit_slices.squeeze(1).repeat(1, 3, 1, 1).float().to(device)
vit_masks = vit_masks.float().to(device)

# %%
vit_x, vit_t = stone(vit_slices, vit_masks, vit_target)

# %%
f, a = plt.subplots(1, 2, figsize=(10, 4))

f.tight_layout()
ax1 = a.flat[0]
ax2 = a.flat[1]
ax1.set_title('MRI Slice Crop')
ax2.set_title('Mask Slice Crop')
sns.heatmap(vit_x[vit_target].squeeze(), ax=ax1)
sns.heatmap(vit_t[vit_target].squeeze(), ax=ax2)
# Out:
# <Axes: title={'center': 'Mask Slice Crop'}>

# %%
vit_y = vit_fitter.model(vit_x.flatten(2).to(device), vit_target)
vit_y = vit_y.view(32, 32)

# %%
f, a = plt.subplots(1, 2, figsize=(10, 4))

f.tight_layout()
ax1 = a.flat[0]
ax2 = a.flat[1]
ax1.set_title('Mask Prediction')
ax2.set_title('Mask Truth')
sns.heatmap((vit_y > -0.3).detach().cpu(), ax=ax1, vmax=1)
sns.heatmap(vit_t[vit_target].squeeze(), ax=ax2, vmax=1)
# Out:
# <Axes: title={'center': 'Mask Truth'}>

# %% [markdown]
# # Log Progress

# %%
vit_tk.notes = '''
Global Context

'''
rpn_tk.notes = '''
Global Context
'''

# %%
vit_tk()
# Out:
#                            model loaded_weights stage1_weights uses_resnet  \
# date
# 2024-11-19 17:41:53.455285   ViT           None           None        None
#
#                             only_cmb_slices  cohort1  cohort2  cohort3  \
# date
# 2024-11-19 17:41:53.455285             True     True    False     True
#
#                                                   optimizer  epochs  ...  \
# date                                                                 ...
# 2024-11-19 17:41:53.455285  <class 'torch.optim.adam.Adam'>       2  ...
#
#                                                                        recall  \
# date
# 2024-11-19 17:41:53.455285  0    0.105263
# 1    0.000000
# 2    0.013158
# 3   ...
#
#                                                                            f1  \
# date
# 2024-11-19 17:41:53.455285  0    0.005848
# 1    0.000000
# 2    0.002845
# 3   ...
#
#                                                                           fpr  \
# date
# 2024-11-19 17:41:53.455285  0    0.035247
# 1    0.028048
# 2    0.039170
# 3   ...
#
#                             saved_weights saved_thist saved_vhist  \
# date
# 2024-11-19 17:41:53.455285           None        None        None
#
#                                                             model_hyperparams  \
# date
# 2024-11-19 17:41:53.455285  {'d_model': 512, 'patch_size': 32, 'dim_ff': 1...
#
#                                                   logfile device  \
# date
# 2024-11-19 17:41:53.455285  rpn_vitNov_19_2024_174153.log   cuda
#
#                                            notes
# date
# 2024-11-19 17:41:53.455285  \nGlobal Context\n\n
#
# [1 rows x 28 columns]

# %%
rpn_tk()
# Out:
#                            model loaded_weights stage1_weights  uses_resnet  \
# date
# 2024-11-19 17:41:53.455285   RPN           None           None        False
#
#                             only_cmb_slices  cohort1  cohort2  cohort3  \
# date
# 2024-11-19 17:41:53.455285             True     True    False     True
#
#                                                   optimizer  epochs  ...  \
# date                                                                 ...
# 2024-11-19 17:41:53.455285  <class 'torch.optim.adam.Adam'>       2  ...
#
#                               recall        f1   fpr  saved_weights  \
# date
# 2024-11-19 17:41:53.455285  0.389803  0.340391  None           None
#
#                            saved_thist  saved_vhist  \
# date
# 2024-11-19 17:41:53.455285        None         None
#
#                                                             model_hyperparams  \
# date
# 2024-11-19 17:41:53.455285  {'input_dim': 512, 'output_dim': 4, 'image_siz...
#
#                                                   logfile  device  \
# date
# 2024-11-19 17:41:53.455285  rpn_vitNov_19_2024_174153.log    cuda
#
#                                          notes
# date
# 2024-11-19 17:41:53.455285  \nGlobal Context\n
#
# [1 rows x 28 columns]

# %%
if os.path.exists('history/runs.csv'):
    print('Merging to old df')
    prev_df = pd.read_csv('history/runs.csv', index_col='date')
    merged = pd.concat([prev_df, rpn_tk()])
    merged.to_csv('history/runs.csv')

    prev_df = pd.read_csv('history/runs.csv', index_col='date')
    merged = pd.concat([prev_df, vit_tk()])
    merged.to_csv('history/runs.csv')
else:
    print('Making new csv file')
    rpn_tk().to_csv('history/runs.csv')

    prev_df = pd.read_csv('history/runs.csv', index_col='date')
    merged = pd.concat([prev_df, vit_tk()])
    merged.to_csv('history/runs.csv')
# Out:
# Merging to old df
# C:\Users\araza\AppData\Local\Temp\ipykernel_24148\1565825461.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat([prev_df, rpn_tk()])
# C:\Users\araza\AppData\Local\Temp\ipykernel_24148\1565825461.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat([prev_df, vit_tk()])
