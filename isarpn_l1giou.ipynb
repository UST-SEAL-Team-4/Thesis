# %%
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform
from project.utils import collatev2
import winsound
from project.utils import compute_statistics
from project.evaluation import isa_rpn_metric, isa_vit_metric, Tracker, l1_giou

# %%
### Only update this

ALPHA = 0.9
BETA = 0.1

# %%
rpn_tk = Tracker()

# %% [markdown]
# ### Monitoring and CUDA Setup

# %%
import logging
from datetime import datetime as dtt
import os

path = 'logs'
os.makedirs(path, exist_ok=True)
os.makedirs('history', exist_ok=True)
rn = dtt.now()
dte = rn.strftime('%b_%d_%Y_%H%M%S')

logger = logging.getLogger('kess')
fh = logging.FileHandler(f'logs/rpn_vit_{dte}.log')
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)

logger.setLevel(logging.DEBUG)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)

logger.addHandler(fh)

dte
# Out:
# 'Nov_22_2024_175756'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
rpn_tk.date = rn
rpn_tk.logfile = f'rpn_vit_{dte}.log'
rpn_tk.device = device

# %% [markdown]
# ### Config for RPN and ViT Fitter

# %%
from project.model import RPN, ISAVIT

rpn_config = {
    'model': RPN(
        input_dim=512,
        output_dim=4,
        image_size=300,
        global_context=True,
        nh=4,
        pretrained=False
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 10,
    'loss': l1_giou.loss,
    'lr': 0.0001
}
# Out:
# 324
# d:\Programming Files\Python\Lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
rpn_tk.model = 'RPN'
rpn_tk.model_hyperparams = rpn_config['model'].config
rpn_tk.uses_resnet = rpn_config['model'].config['pretrained']
rpn_tk.optimizer = f"{rpn_config['optimizer']}"
rpn_tk.epochs = rpn_config['epochs']
rpn_tk.loss = f"{rpn_config['loss']}"
rpn_tk.lr = rpn_config['lr']

# %% [markdown]
# ### Dataset Loading

# %%
data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 9)

# %%
data = data.query('has_microbleed_slice == 1').reset_index(drop=True)
rpn_tk.only_cmb_slices = True
data
# Out:
#                                                    mri  \
# 0    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 1    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 2    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 3    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 4    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# ..                                                 ...
# 359  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 360  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 361  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 362  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 363  d:\Github\Thesis and ML Project\Dataset\VALDO_...
#
#                                                  masks  \
# 0    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 1    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 2    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 3    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 4    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# ..                                                 ...
# 359  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 360  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 361  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 362  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 363  d:\Github\Thesis and ML Project\Dataset\VALDO_...
#
#                                               stripped  target  \
# 0    d:\Github\Thesis and ML Project\Dataset\VALDO_...       8
# 1    d:\Github\Thesis and ML Project\Dataset\VALDO_...       9
# 2    d:\Github\Thesis and ML Project\Dataset\VALDO_...      11
# 3    d:\Github\Thesis and ML Project\Dataset\VALDO_...      12
# 4    d:\Github\Thesis and ML Project\Dataset\VALDO_...      15
# ..                                                 ...     ...
# 359  d:\Github\Thesis and ML Project\Dataset\VALDO_...      25
# 360  d:\Github\Thesis and ML Project\Dataset\VALDO_...      26
# 361  d:\Github\Thesis and ML Project\Dataset\VALDO_...      24
# 362  d:\Github\Thesis and ML Project\Dataset\VALDO_...      25
# 363  d:\Github\Thesis and ML Project\Dataset\VALDO_...      20
#
#      has_microbleed_case  has_microbleed_slice  cohort   max_value  slices
# 0                      1                     1       1  928.405273      35
# 1                      1                     1       1  928.405273      35
# 2                      1                     1       1  928.405273      35
# 3                      1                     1       1  928.405273      35
# 4                      1                     1       1  928.405273      35
# ..                   ...                   ...     ...         ...     ...
# 359                    1                     1       3  241.000000      36
# 360                    1                     1       3  241.000000      36
# 361                    1                     1       3  448.000000      39
# 362                    1                     1       3  448.000000      39
# 363                    1                     1       3  253.000000      39
#
# [364 rows x 9 columns]

# %% [markdown]
# ### Preprocessing and Train-Test Split Function

# %%
from sklearn.model_selection import train_test_split

def make_loaders(data,
                 cohort,
                 test_size=0.2,
                 random_state=12,
                 target_shape=(300, 300),
                 rpn_mode=True,
                 logger=None,
                 rpn_tracker=rpn_tk,
                ):
    if cohort == 1:
        rpn_tracker.cohort1 = True
    if cohort == 2:
        rpn_tracker.cohort2 = True
    if cohort == 3:
        rpn_tracker.cohort3 = True
    
    rpn_tracker.test_size = test_size
    data = data[data.cohort == cohort]
    
    s = f'Creating loaders for Cohort {cohort}\n'

    data_train, data_test = train_test_split(
        data,
        test_size=test_size,
        random_state=random_state
    )

    s += f'TRAIN & TEST: {data_train.shape, data_test.shape}\n'

    paths = data_train.stripped.unique().tolist()
    s += f'Total Unique MRI Samples in data_train: {len(paths)}\n'
    
    global_min, global_max = compute_statistics(paths)
    s += f'GLOBAL MIN & MAX {global_min, global_max}\n'

    transform = NiftiToTensorTransform(
        target_shape=target_shape,
        rpn_mode=rpn_mode,
        normalization=(global_min, global_max)
    )

    train_set = VALDODataset(
        cases=data_train.stripped.tolist(),
        masks=data_train.masks.tolist(),
        target=data_train.target.tolist(),
        transform=transform
    )
    val_set = VALDODataset(
        cases=data_test.stripped.tolist(),
        masks=data_test.masks.tolist(),
        target=data_test.target.tolist(),
        transform=transform
    )

    if logger != None:
        logger.info(s)
    else:
        print(s)
    
    return train_set, val_set

# %% [markdown]
# ### RPN Fitter

# %%
from project import Fitter

# %%
class RPNFitter(Fitter):
    def train_one_epoch(self, train_loader):
        self.model.train()
        loss_history = []
        evaluation_metric = {
            'iou_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': []
        }
        counter = 0
        for batch in train_loader:
            # self.log('----------------- BATCH -----------------')
            Y = []
            T = []
            for slices, masks, target, case in batch:
                # x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                x = slices.squeeze(1).float().to(self.device)
                masks = masks.squeeze(1).float().to(self.device)/300
                y = self.model(x, target)

                iou_score, precision_score, recall_score, f1_score = isa_rpn_metric(image_size=300, target_bbox=masks[target], predicted_bbox=y)
                evaluation_metric['iou_score'].append(iou_score)
                evaluation_metric['precision_score'].append(precision_score)
                evaluation_metric['recall_score'].append(recall_score)
                evaluation_metric['f1_score'].append(f1_score)
                # self.log(f'EVAL METS: {iou_score, precision_score, recall_score, f1_score}')
                Y.append(y)
                T.append(masks[target])
            
            losses= self.loss(pred= torch.stack(Y), target = torch.stack(T), alpha=ALPHA, beta=BETA)
            print("L1 and GIOU Training loss: ", losses)
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += 1
            # if counter % len(batch) == 0:
            self.log(f'Batch:\t{counter}/{len(train_loader)}')
            self.log(f'Batch samples:\t{len(batch)}')
            self.log(f'Current error:\t{losses}\n')
            
            
            loss_history.append(losses.detach().cpu().numpy())
        
        self.log(f'\nTraining Evaluation Metric:')
        self.log(f"Avg IOU: {sum(evaluation_metric['iou_score']) / len(evaluation_metric['iou_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        
        return loss_history, evaluation_metric
    def validation(self, val_loader):
        self.model.eval()
        loss_history = []
        evaluation_metric = {
            'iou_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': []
        }
        with torch.inference_mode():
            for batch in val_loader:
                Y = []
                T = []
                for slices, masks, target, case in batch:
                    # x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                    x = slices.squeeze(1).float().to(self.device)
                    masks = masks.squeeze(1).float().to(self.device)/300
                    y = self.model(x, target)
                    iou_score, precision_score, recall_score, f1_score = isa_rpn_metric(image_size=300, target_bbox=masks[target], predicted_bbox=y)
                    evaluation_metric['iou_score'].append(iou_score)
                    evaluation_metric['precision_score'].append(precision_score)
                    evaluation_metric['recall_score'].append(recall_score)
                    evaluation_metric['f1_score'].append(f1_score)
                    Y.append(y)
                    T.append(masks[target])
                losses= self.loss(pred= torch.stack(Y), target = torch.stack(T), alpha=ALPHA, beta=BETA)
                print("L1 and GIOU Validation loss: ", losses)
                loss_history.append(losses.cpu().numpy())
        self.log(f'\nValidation Evaluation Metric:')
        self.log(f"Avg IOU: {sum(evaluation_metric['iou_score']) / len(evaluation_metric['iou_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        return loss_history, evaluation_metric

# %% [markdown]
# ### Train-Test Split

# %%
rpn_t1, rpn_v1 = make_loaders(
    data=data,
    cohort=1,
    rpn_mode=True
)

rpn_t3, rpn_v3 = make_loaders(
    data=data,
    cohort=3,
    rpn_mode=True
)
# Out:
# Creating loaders for Cohort 1
# TRAIN & TEST: ((36, 9), (9, 9))
# Total Unique MRI Samples in data_train: 8
# GLOBAL MIN & MAX (0.0, 1417.92822265625)
#
# Creating loaders for Cohort 3
# TRAIN & TEST: ((37, 9), (10, 9))
# Total Unique MRI Samples in data_train: 26
# GLOBAL MIN & MAX (0.0, 573.0)

# %%
from torch.utils.data import ConcatDataset

rpn_train_set = ConcatDataset([rpn_t1, rpn_t3])
rpn_test_set = ConcatDataset([rpn_v1, rpn_v3])

print(f'RPN Train Set Size: {rpn_train_set}')
print(f'RPN Test Set Size: {rpn_test_set}')
# Out:
# RPN Train Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x0000014B5D420990>
# RPN Test Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x0000014B6B334F10>

# %%
batchs = 20

rpn_test_dataloader = DataLoader(
    rpn_test_set,
    shuffle=True,
    batch_size=batchs,
    collate_fn=collatev2
)

# %% [markdown]
# ### K-Fold Cross Validation

# %%
from torch.utils.data import Subset
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=2, shuffle=True, random_state=45)
kf
# Out:
# KFold(n_splits=2, random_state=45, shuffle=True)

# %%
from project.model import Feeder, GCRPN
from project.preprocessing import NiftiToTensorTransform, get_transform

image_size = 300
patch_size = 32

# %%
rpn_test_iou = []
rpn_test_precision = []
rpn_test_recall = []
rpn_test_f1 = []

# %%
rpn_fold_metrics = []

fold_dir = f'./fold/{dte}'
os.makedirs(fold_dir, exist_ok=True)

for i, (train_index, val_index) in enumerate(kf.split(rpn_train_set)):
    print(f'Fold {i + 1}/{5}')
    logger.info(f'################################### Fold {i+1}/5 ###################################')
    
    # RPN
    rpn_config['model'] = RPN(**rpn_tk.model_hyperparams).to(device)
    
    rpn_fitter = RPNFitter(rpn_config, logger=logger)
    
    rpn_train_subset = Subset(rpn_train_set, train_index)
    rpn_val_subset = Subset(rpn_train_set, val_index)

    rpn_tk.batch_size = 20
    
    rpn_train_subset_dl = DataLoader(
        rpn_train_subset,
        shuffle=True,
        batch_size=rpn_tk.batch_size,
        collate_fn=collatev2
    )
    
    rpn_val_subset_dl = DataLoader(
        rpn_val_subset,
        shuffle=True,
        batch_size=rpn_tk.batch_size,
        collate_fn=collatev2
    )
    
    rpn_thist, rpn_vhist, rpn_tmhist, rpn_vmhist = rpn_fitter.fit(rpn_train_subset_dl, rpn_val_subset_dl)
    
    rpn_fold_metrics.append({
        'fold': i + 1,
        'training_history': rpn_thist,
        'validation_history': rpn_vhist,
        'training_metrics': rpn_tmhist,
        'validation_metrics': rpn_vmhist
    })
    
    rpn_h, rpn_mh = rpn_fitter.validation(rpn_test_dataloader)
    rpn_valmets = pd.DataFrame(rpn_mh)
    rpn_mets = rpn_valmets.mean()
    
    rpn_test_iou.append(rpn_mets.iou_score)
    rpn_test_precision.append(rpn_mets.precision_score)
    rpn_test_recall.append(rpn_mets.recall_score)
    rpn_test_f1.append(rpn_mets.f1_score)
    
    os.makedirs(f'{fold_dir}/fold_{i+1}', exist_ok=True)
    torch.save(rpn_fitter.model.state_dict(), f'{fold_dir}/fold_{i+1}/rpn_fold{i+1}.pt')
# Out:
# INFO:kess:################################### Fold 1/5 ###################################
# d:\Programming Files\Python\Lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# INFO:kess:EPOCH 0 ==============================
# Fold 1/5
# 324
# d:\Programming Files\Python\Lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# L1 and GIOU Training loss:  tensor(0.3027, device='cuda:0', grad_fn=<AddBackward0>)
# INFO:kess:Batch:	1/2
# INFO:kess:Batch samples:	20
# INFO:kess:Current error:	0.30267971754074097
# L1 and GIOU Training loss:  tensor(0.2434, device='cuda:0', grad_fn=<AddBackward0>)
# INFO:kess:Batch:	2/2
# INFO:kess:Batch samples:	16
# INFO:kess:Current error:	0.2433798760175705
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg IOU: 0.011511276052462764
# INFO:kess:Avg Precision: 0.10085552527258794
# INFO:kess:Avg Recall: 0.01197166199886447
# INFO:kess:Avg F1: 0.020377087021996785
# L1 and GIOU Validation loss:  tensor(0.1687, device='cuda:0')
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.2666798633447773
# INFO:kess:Avg Precision: 0.4677461008918849
# INFO:kess:Avg Recall: 0.4333934044100445
# INFO:kess:Avg F1: 0.38976835755228595
# INFO:kess:EPOCH 1 ==============================
# L1 and GIOU Validation loss:  tensor(0.1768, device='cuda:0')
# L1 and GIOU Training loss:  tensor(0.2046, device='cuda:0', grad_fn=<AddBackward0>)
# INFO:kess:Batch:	1/2
# INFO:kess:Batch samples:	20
# INFO:kess:Current error:	0.20464855432510376
# L1 and GIOU Training loss:  tensor(0.1844, device='cuda:0', grad_fn=<AddBackward0>)
# INFO:kess:Batch:	2/2
# INFO:kess:Batch samples:	16
# INFO:kess:Current error:	0.18437150120735168
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg IOU: 0.23293475113395187
# INFO:kess:Avg Precision: 0.35107786104910904
# INFO:kess:Avg Recall: 0.4406570738905834
# INFO:kess:Avg F1: 0.34130189743720823
# L1 and GIOU Validation loss:  tensor(0.1987, device='cuda:0')
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.29948778974043355
# INFO:kess:Avg Precision: 0.33955219428281525
# INFO:kess:Avg Recall: 0.7548822917648264
# INFO:kess:Avg F1: 0.4389209493591979
# L1 and GIOU Validation loss:  tensor(0.1810, device='cuda:0')
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.28793565027023615
# INFO:kess:Avg Precision: 0.32296863629629735
# INFO:kess:Avg Recall: 0.7587692110162032
# INFO:kess:Avg F1: 0.42905740596746145
# INFO:kess:################################### Fold 2/5 ###################################
# INFO:kess:EPOCH 0 ==============================
# L1 and GIOU Validation loss:  tensor(0.1909, device='cuda:0')
# Fold 2/5
# 324
# L1 and GIOU Training loss:  tensor(0.2525, device='cuda:0', grad_fn=<AddBackward0>)
# INFO:kess:Batch:	1/2
# INFO:kess:Batch samples:	20
# INFO:kess:Current error:	0.2525171637535095
# L1 and GIOU Training loss:  tensor(0.1932, device='cuda:0', grad_fn=<AddBackward0>)
# INFO:kess:Batch:	2/2
# INFO:kess:Batch samples:	17
# INFO:kess:Current error:	0.1931931972503662
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg IOU: 0.0839792574445931
# INFO:kess:Avg Precision: 0.32249931779664914
# INFO:kess:Avg Recall: 0.10548330947829133
# INFO:kess:Avg F1: 0.12979161237819573
# L1 and GIOU Validation loss:  tensor(0.1953, device='cuda:0')
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.26201897728606127
# INFO:kess:Avg Precision: 0.3397039202779221
# INFO:kess:Avg Recall: 0.4920164330655502
# INFO:kess:Avg F1: 0.3750147985863603
# INFO:kess:EPOCH 1 ==============================
# L1 and GIOU Validation loss:  tensor(0.2031, device='cuda:0')
# L1 and GIOU Training loss:  tensor(0.1801, device='cuda:0', grad_fn=<AddBackward0>)
# INFO:kess:Batch:	1/2
# INFO:kess:Batch samples:	20
# INFO:kess:Current error:	0.18009251356124878
# L1 and GIOU Training loss:  tensor(0.1887, device='cuda:0', grad_fn=<AddBackward0>)
# INFO:kess:Batch:	2/2
# INFO:kess:Batch samples:	17
# INFO:kess:Current error:	0.1886805295944214
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg IOU: 0.2882982549836507
# INFO:kess:Avg Precision: 0.36710470240261106
# INFO:kess:Avg Recall: 0.6243149189127458
# INFO:kess:Avg F1: 0.42151121593810414
# L1 and GIOU Validation loss:  tensor(0.2082, device='cuda:0')
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.2651711096987128
# INFO:kess:Avg Precision: 0.2869358045152492
# INFO:kess:Avg Recall: 0.7586701802081532
# INFO:kess:Avg F1: 0.3949321351117558
# L1 and GIOU Validation loss:  tensor(0.2104, device='cuda:0')
# INFO:kess:
# Validation Evaluation Metric:
# INFO:kess:Avg IOU: 0.24602038864242404
# INFO:kess:Avg Precision: 0.26142070834573944
# INFO:kess:Avg Recall: 0.7088280649561631
# INFO:kess:Avg F1: 0.3675771230145505
# L1 and GIOU Validation loss:  tensor(0.2218, device='cuda:0')

# %%
import winsound

winsound.Beep(500, 500)
winsound.Beep(500, 500)
winsound.Beep(500, 500)

# %% [markdown]
# ### Metrics Visualization

# %% [markdown]
# `rpn_fold_metrics[i]`
#
# - represents each fold
#
# `rpn_fold_metrics[1].keys()`
#
# - 'fold', 'training_history', 'validation_history', 'training_metrics', 'validation_metrics'
#
# `rpn_fold_metrics[1]['training_metrics'][i]`
#
# - represents each epoch
#
# `rpn_fold_metrics[1]['training_metrics'][1].keys()`
#
# - 'iou_score', 'precision_score', 'recall_score', 'f1_score'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_metric_history(fold_metrics, metric, title=None):
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))

    for fold in range(len(rpn_fold_metrics)):
        train = []
        test = []
        ax=axes[fold]
        
        for epoch in range(len(fold_metrics[fold]['training_metrics'])):
            th = np.array(fold_metrics[fold]['training_metrics'][epoch][metric]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_metrics'][epoch][metric]).mean()
            test.append(vh)
            
        sns.lineplot(x=range(1, len(train)+1), y=train, label=f'Training {metric}', ax=ax)
        sns.lineplot(x=range(1, len(test)+1), y=test, label=f'Validation {metric}', ax=ax)
    
    
        ax.set_title(f'{title}Training and Validation {metric}: Fold {fold+1}')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric)
        ax.legend()
        
    plt.tight_layout()  
    plt.show()

# %%
rpn_metrics = ['iou_score', 'precision_score', 'recall_score', 'f1_score']

for metric in rpn_metrics:
    plot_metric_history(rpn_fold_metrics, metric, 'RPN ')

# %% [markdown]
# ### Loss History Visualization

# %%
def plot_loss_history(fold_metrics, title=None):
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))

    for fold in range(2):
        train = []
        test = []
        ax=axes[fold]
        
        for epoch in range(len(fold_metrics[fold]['training_history'])):
            th = np.array(fold_metrics[fold]['training_history'][epoch]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_history'][epoch]).mean()
            test.append(vh)
        
        sns.lineplot(x=range(1, len(train)+1), y=train, label='Training history', ax=ax)
        sns.lineplot(x=range(1, len(test)+1), y=test, label='Validation history', ax=ax)
        
        ax.set_title(f'{title}Training and Validation History: Fold {fold+1}')
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Loss')
        ax.legend()
    
    plt.tight_layout()  
    plt.show()

# %%
plot_loss_history(rpn_fold_metrics, 'RPN ')
# plot_loss_history(vit_fold_metrics, 'ViT ')

# %% [raw]
# rpn_hist = torch.tensor(np.array(rpn_fold_metrics))
# vit_hist = torch.tensor(np.array(vit_fold_metrics))
#
# s_rpn_hist = f'history/{dte}_rpn_hist.pt'
# s_vit_hist = f'history/{dte}_vit_hist.pt'
# rpn_tk.saved_thist = s_rpn_hist
# vit_tk.saved_vhist = s_vit_hist
# torch.save(rpn_hist, s_rpn_hist)
# torch.save(vit_hist, s_vit_hist)

# %% [markdown]
# ### Evaluate Test Set

# %% [markdown]
# #### RPN

# %%
df_rpn_metrics = pd.DataFrame(columns=['fold', 'iou', 'precision', 'recall', 'f1'])
df_rpn_metrics
# Out:
# Empty DataFrame
# Columns: [fold, iou, precision, recall, f1]
# Index: []

# %%
df_rpn_metrics['fold'] = [1, 2]
df_rpn_metrics['iou'] = rpn_test_iou
df_rpn_metrics['precision'] = rpn_test_precision
df_rpn_metrics['recall'] = rpn_test_recall
df_rpn_metrics['f1'] = rpn_test_f1

# %%
rpn_tk.iou = df_rpn_metrics.iou.mean()
rpn_tk.precision = df_rpn_metrics.precision.mean()
rpn_tk.recall = df_rpn_metrics.recall.mean()
rpn_tk.f1 = df_rpn_metrics.f1.mean()

# %%
df_rpn_metrics
# Out:
#    fold       iou  precision    recall        f1
# 0     1  0.287936   0.322969  0.758769  0.429057
# 1     2  0.246020   0.261421  0.708828  0.367577

# %%
rpn_iou_score = np.array(rpn_test_iou).mean()
rpn_precision_score = np.array(rpn_test_precision).mean()
rpn_recall_score = np.array(rpn_test_recall).mean()
rpn_f1_score = np.array(rpn_test_f1).mean()

print('RPN Test Set Performance Metrics')
print(f'Average IOU: {rpn_iou_score} ')
print(f'Average Precision: {rpn_precision_score} ')
print(f'Average Recall: {rpn_recall_score} ')
print(f'Average F1 Score: {rpn_f1_score} ')
# Out:
# RPN Test Set Performance Metrics
# Average IOU: 0.2669780194563301
# Average Precision: 0.29219467232101837
# Average Recall: 0.7337986379861832
# Average F1 Score: 0.39831726449100596

# %%
df_rpn_metrics.to_csv(f'{fold_dir}/rpn_metrics.csv')

# %% [markdown]
# ### Sample

# %% [markdown]
# #### RPN

# %%
rpn_sample = next(enumerate(rpn_test_dataloader))
rpn_slices, rpn_masks, rpn_target, rpn_case = rpn_sample[1][1]

# %%
rpn_x = rpn_slices.squeeze(1).float().to(device)
# rpn_x = rpn_slices.squeeze(1).repeat(1, 3, 1, 1).float().to(device)
rpn_T = rpn_masks.squeeze(1).float().to(device)

# %%
rpn_y = rpn_fitter.model(rpn_x, rpn_target)
rpn_y
# Out:
# tensor([[0.2310, 0.1612, 0.7783, 0.8311]], device='cuda:0',
#        grad_fn=<SigmoidBackward0>)

# %%
rpn_fitter.loss(rpn_y, rpn_T[rpn_target])
# Out:
# tensor(108.4840, device='cuda:0', grad_fn=<AddBackward0>)

# %%
rpn_bbox = rpn_masks[rpn_target].squeeze().cpu().long()
rpn_y = (rpn_y*300).squeeze().detach().cpu().long()

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

ax = sns.heatmap(rpn_x[rpn_target][0].squeeze().cpu(), cmap='gray')

truth = patches.Rectangle(
    (rpn_bbox[0], rpn_bbox[1]),
    rpn_bbox[2] - rpn_bbox[0],
    rpn_bbox[3] - rpn_bbox[1],
    linewidth=1, edgecolor='g', facecolor='none'
)

pred = patches.Rectangle(
    (rpn_y[0], rpn_y[1]),
    rpn_y[2] - rpn_y[0],
    rpn_y[3] - rpn_y[1],
    linewidth=1, edgecolor='r', facecolor='none'
)

ax.add_patch(truth)
ax.add_patch(pred)
plt.show()

# %% [markdown]
# # Log Progress

# %%
rpn_tk.notes = '''
Global Context
'''

# %%
rpn_tk()
# Out:
#                            model loaded_weights stage1_weights  uses_resnet  \
# date
# 2024-11-22 17:57:56.889124   RPN           None           None        False
#
#                             only_cmb_slices  cohort1  cohort2  cohort3  \
# date
# 2024-11-22 17:57:56.889124             True     True    False     True
#
#                                                   optimizer  epochs  ...  \
# date                                                                 ...
# 2024-11-22 17:57:56.889124  <class 'torch.optim.adam.Adam'>       2  ...
#
#                               recall        f1   fpr  saved_weights  \
# date
# 2024-11-22 17:57:56.889124  0.733799  0.398317  None           None
#
#                            saved_thist  saved_vhist  \
# date
# 2024-11-22 17:57:56.889124        None         None
#
#                                                             model_hyperparams  \
# date
# 2024-11-22 17:57:56.889124  {'input_dim': 512, 'output_dim': 4, 'image_siz...
#
#                                                    logfile  device  \
# date
# 2024-11-22 17:57:56.889124  rpn_vit_Nov_22_2024_175756.log    cuda
#
#                                          notes
# date
# 2024-11-22 17:57:56.889124  \nGlobal Context\n
#
# [1 rows x 28 columns]

# %%
if os.path.exists('history/runs.csv'):
    print('Merging to old df')
    prev_df = pd.read_csv('history/runs.csv', index_col='date')
    merged = pd.concat([prev_df, rpn_tk()])
    merged.to_csv('history/runs.csv')
else:
    print('Making new csv file')
    rpn_tk().to_csv('history/runs.csv')
# Out:
# Merging to old df
