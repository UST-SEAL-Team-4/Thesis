# %%
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform
from project.utils import collatev2
import winsound
from project.utils import compute_statistics
from project.evaluation import isa_rpn_metric, isa_vit_metric, Tracker
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.21 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations

# %%
vit_tk = Tracker()
rpn_tk = Tracker()

# %% [markdown]
# ### Update RPN Weights before running this notebook

# %%
rpn_weights = r'fold\Nov_24_2024_024303\fold_4\rpn_fold4.pt'

# %% [markdown]
# ### Monitoring and CUDA Setup

# %%
import logging
from datetime import datetime as dtt
import os

path = 'logs'
os.makedirs(path, exist_ok=True)
os.makedirs('history', exist_ok=True)
rn = dtt.now()
dte = rn.strftime('%b_%d_%Y_%H%M%S')

logger = logging.getLogger('kess')
fh = logging.FileHandler(f'logs/rpn_vit_{dte}.log')
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)

logger.setLevel(logging.DEBUG)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)

logger.addHandler(fh)

dte
# Out:
# 'Nov_25_2024_024514'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
vit_tk.date = rn
vit_tk.logfile = f'rpn_vit_{dte}.log'
vit_tk.device = device

# %% [markdown]
# ### Config for RPN and ViT Fitter

# %%
from project.model import RPN, ISAVIT
image_size = 300

rpn_config = {
    'model': RPN(
        input_dim=512,
        output_dim=16,
        image_size=image_size,
        global_context=True,
        nh=4,
        pretrained=False
    ).to(device),
}

patch_size = image_size/(rpn_config['model'].config['output_dim']**.5)
assert patch_size == int(patch_size), 'image size must be divisible by patch size'
patch_size = int(patch_size)

vit_tk.uses_resnet = rpn_config['model'].config['pretrained']
# Out:
# 324
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
vit_config = {
    'model': ISAVIT(
        d_model=512,
        patch_size=patch_size,
        dim_ff=1600,
        global_context=True,
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 5,
    'loss': nn.BCEWithLogitsLoss(),
    'lr': 0.0001
}

# %%
vit_tk.model = 'ViT'
vit_tk.model_hyperparams = vit_config['model'].config
vit_tk.optimizer = f"{vit_config['optimizer']}"
vit_tk.epochs = vit_config['epochs']
vit_tk.loss = f"{vit_config['loss']}"
vit_tk.lr = vit_config['lr']

rpn_tk.model = 'RPN'
rpn_tk.model_hyperparams = rpn_config['model'].config

# %% [markdown]
# ### Dataset Loading

# %%
data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 9)

# %%
data = data.query('has_microbleed_slice == 1').reset_index(drop=True)
vit_tk.only_cmb_slices = True
data
# Out:
#                                                    mri  \
# 0    C:\Users\araza\Documents\1\gits\thesis_project...
# 1    C:\Users\araza\Documents\1\gits\thesis_project...
# 2    C:\Users\araza\Documents\1\gits\thesis_project...
# 3    C:\Users\araza\Documents\1\gits\thesis_project...
# 4    C:\Users\araza\Documents\1\gits\thesis_project...
# ..                                                 ...
# 359  C:\Users\araza\Documents\1\gits\thesis_project...
# 360  C:\Users\araza\Documents\1\gits\thesis_project...
# 361  C:\Users\araza\Documents\1\gits\thesis_project...
# 362  C:\Users\araza\Documents\1\gits\thesis_project...
# 363  C:\Users\araza\Documents\1\gits\thesis_project...
#
#                                                  masks  \
# 0    C:\Users\araza\Documents\1\gits\thesis_project...
# 1    C:\Users\araza\Documents\1\gits\thesis_project...
# 2    C:\Users\araza\Documents\1\gits\thesis_project...
# 3    C:\Users\araza\Documents\1\gits\thesis_project...
# 4    C:\Users\araza\Documents\1\gits\thesis_project...
# ..                                                 ...
# 359  C:\Users\araza\Documents\1\gits\thesis_project...
# 360  C:\Users\araza\Documents\1\gits\thesis_project...
# 361  C:\Users\araza\Documents\1\gits\thesis_project...
# 362  C:\Users\araza\Documents\1\gits\thesis_project...
# 363  C:\Users\araza\Documents\1\gits\thesis_project...
#
#                                               stripped  target  \
# 0    C:\Users\araza\Documents\1\gits\thesis_project...       8
# 1    C:\Users\araza\Documents\1\gits\thesis_project...       9
# 2    C:\Users\araza\Documents\1\gits\thesis_project...      11
# 3    C:\Users\araza\Documents\1\gits\thesis_project...      12
# 4    C:\Users\araza\Documents\1\gits\thesis_project...      15
# ..                                                 ...     ...
# 359  C:\Users\araza\Documents\1\gits\thesis_project...      25
# 360  C:\Users\araza\Documents\1\gits\thesis_project...      26
# 361  C:\Users\araza\Documents\1\gits\thesis_project...      24
# 362  C:\Users\araza\Documents\1\gits\thesis_project...      25
# 363  C:\Users\araza\Documents\1\gits\thesis_project...      20
#
#      has_microbleed_case  has_microbleed_slice  cohort   max_value  slices
# 0                      1                     1       1  928.405273      35
# 1                      1                     1       1  928.405273      35
# 2                      1                     1       1  928.405273      35
# 3                      1                     1       1  928.405273      35
# 4                      1                     1       1  928.405273      35
# ..                   ...                   ...     ...         ...     ...
# 359                    1                     1       3  241.000000      36
# 360                    1                     1       3  241.000000      36
# 361                    1                     1       3  448.000000      39
# 362                    1                     1       3  448.000000      39
# 363                    1                     1       3  253.000000      39
#
# [364 rows x 9 columns]

# %% [markdown]
# ### Preprocessing and Train-Test Split Function

# %%
from sklearn.model_selection import train_test_split

def make_loaders(data,
                 cohort,
                 test_size=0.2,
                 random_state=12,
                 target_shape=(300, 300),
                 rpn_mode=True,
                 logger=None,
                 vit_tracker=vit_tk
                ):
    if cohort == 1:
        vit_tracker.cohort1 = True
    if cohort == 2:
        vit_tracker.cohort2 = True
    if cohort == 3:
        vit_tracker.cohort3 = True
    
    vit_tracker.target_shape = target_shape
    data = data[data.cohort == cohort]
    
    s = f'Creating loaders for Cohort {cohort}\n'

    data_train, data_test = train_test_split(
        data,
        test_size=test_size,
        random_state=random_state
    )

    s += f'TRAIN & TEST: {data_train.shape, data_test.shape}\n'

    paths = data_train.stripped.unique().tolist()
    s += f'Total Unique MRI Samples in data_train: {len(paths)}\n'
    
    global_min, global_max = compute_statistics(paths)
    s += f'GLOBAL MIN & MAX {global_min, global_max}\n'

    transform = NiftiToTensorTransform(
        target_shape=target_shape,
        rpn_mode=rpn_mode,
        normalization=(global_min, global_max)
    )

    train_set = VALDODataset(
        cases=data_train.stripped.tolist(),
        masks=data_train.masks.tolist(),
        target=data_train.target.tolist(),
        transform=transform
    )
    val_set = VALDODataset(
        cases=data_test.stripped.tolist(),
        masks=data_test.masks.tolist(),
        target=data_test.target.tolist(),
        transform=transform
    )

    if logger != None:
        logger.info(s)
    else:
        print(s)
    
    return train_set, val_set

# %% [markdown]
# ### ViT Fitter

# %%
from project import Fitter

class ViTFitter(Fitter):
    
    def fit(self, train_loader, val_loader, stage1):
        train_history = []
        val_history = []
        train_metric_history = []
        val_metric_history = []
        for epoch in range(self.epochs):
            self.log(f'EPOCH {epoch} ==============================')
            train_loss, train_metric = self.train_one_epoch(train_loader, stage1)
            val_loss, val_metric = self.validation(val_loader, stage1)
            train_history.append(train_loss)
            val_history.append(val_loss)
            train_metric_history.append(train_metric)
            val_metric_history.append(val_metric)
        return train_history, val_history, train_metric_history, val_metric_history

    def train_one_epoch(self, train_loader, stage1):
        self.model.train()
        loss_history = []
        evaluation_metric = {
            'dice_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': [],
            'fpr': []
        }
        counter = 0
        for batch in train_loader:
            Y = []
            T = []
            for slices, masks, target, case in batch:
                slices = slices.squeeze(1).float().to(self.device)
                # slices = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                masks = masks.float().to(self.device)

                # with torch.inference_mode():
                    # x, t = stage1(slices, masks, target)
                x, t = stage1(slices, masks, target)
                
                # self.log(f'{x.requires_grad}, {t.requires_grad}')
                # self.log(f'{x.shape}, {t.shape}')

                x = x.flatten(2).float().to(self.device)
                t = t.flatten(2).float().to(self.device)
                # self.log(f'XT SHAPES: {x.shape}, {t.shape}')
                
                y = self.model(x, target)
                
                # print('Prediction:', (y.sigmoid() >= 0.5).int().unique())
                # print('Truth:', (t[target] >= 0).int().unique())

                dice_score, precision_score, recall_score, f1_score, fpr = isa_vit_metric((y.sigmoid().squeeze().detach().cpu().numpy() >= 0.5), t[target].squeeze().detach().cpu().numpy())

                evaluation_metric['dice_score'].append(dice_score)
                evaluation_metric['precision_score'].append(precision_score)
                evaluation_metric['recall_score'].append(recall_score)
                evaluation_metric['f1_score'].append(f1_score)
                evaluation_metric['fpr'].append(fpr)
                # self.log(f'EVAL METS: {dice_score, precision_score, recall_score, f1_score, fpr}')

                Y.append(y)
                T.append(t[target])
            
            losses = self.loss(torch.stack(Y), torch.stack(T))
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += 1
            self.log(f'Batch:\t{counter}/{len(train_loader)}')
            self.log(f'Batch samples:\t{len(batch)}')
            self.log(f'Current error:\t{losses}\n')
            
            loss_history.append(losses.detach().cpu().numpy())
        
        self.log(f'\nTraining Evaluation Metric:')
        self.log(f"Avg Dice: {sum(evaluation_metric['dice_score']) / len(evaluation_metric['dice_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        self.log(f"Avg FPR: {sum(evaluation_metric['fpr']) / len(evaluation_metric['fpr'])}\n")
        return loss_history, evaluation_metric
    
    def validation(self, val_loader, stage1):
        self.model.eval()
        loss_history = []
        evaluation_metric = {
            'dice_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': [],
            'fpr': []
        }
        with torch.inference_mode():
            for batch in val_loader:
                Y = []
                T = []
                for slices, masks, target, case in batch:
                    slices = slices.squeeze(1).float().to(self.device)
                    # slices = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                    masks = masks.float().to(self.device)
                    x, t = stage1(slices, masks, target)
                    x = x.flatten(2).float().to(self.device)
                    t = t.flatten(2).float().to(self.device)
                    y = self.model(x, target)

                    dice_score, precision_score, recall_score, f1_score, fpr = isa_vit_metric((y.sigmoid().squeeze().detach().cpu().numpy() >= 0.5), t[target].squeeze().detach().cpu().numpy())
                    evaluation_metric['dice_score'].append(dice_score)
                    evaluation_metric['precision_score'].append(precision_score)
                    evaluation_metric['recall_score'].append(recall_score)
                    evaluation_metric['f1_score'].append(f1_score)
                    evaluation_metric['fpr'].append(fpr)
                    Y.append(y)
                    T.append(t[target])
                
                losses = self.loss(torch.stack(Y), torch.stack(T))
                loss_history.append(losses.cpu().numpy())
        
        self.log(f'\nValidations Evaluation Metric:')
        self.log(f"Avg Dice: {sum(evaluation_metric['dice_score']) / len(evaluation_metric['dice_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        self.log(f"Avg FPR: {sum(evaluation_metric['fpr']) / len(evaluation_metric['fpr'])}\n")
        return loss_history, evaluation_metric

# %% [markdown]
# ### Train-Test Split

# %%
vit_t1, vit_v1 = make_loaders(
    data=data,
    cohort=1,
    rpn_mode=False
)

vit_t3, vit_v3 = make_loaders(
    data=data,
    cohort=3,
    rpn_mode=False
)
# Out:
# Creating loaders for Cohort 1
# TRAIN & TEST: ((36, 9), (9, 9))
# Total Unique MRI Samples in data_train: 8
# GLOBAL MIN & MAX (0.0, 1417.92822265625)
#
# Creating loaders for Cohort 3
# TRAIN & TEST: ((37, 9), (10, 9))
# Total Unique MRI Samples in data_train: 26
# GLOBAL MIN & MAX (0.0, 573.0)

# %%
from torch.utils.data import ConcatDataset

vit_train_set = ConcatDataset([vit_t1, vit_t3])
vit_test_set = ConcatDataset([vit_v1, vit_v3])

print(f'ViT Train Set Size: {vit_train_set}')
print(f'ViT Test Set Size: {vit_test_set}')
# Out:
# ViT Train Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x000002527359C9D0>
# ViT Test Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x000002527359F6A0>

# %%
batchs = 15

vit_test_dataloader = DataLoader(
    vit_test_set,
    shuffle=True,
    batch_size=batchs,
    collate_fn=collatev2
)

# %% [markdown]
# ### K-Fold Cross Validation

# %%
from torch.utils.data import Subset
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=45)
kf
# Out:
# KFold(n_splits=5, random_state=45, shuffle=True)

# %%
from project.model import Feeder, GCRPN, AnchorFeeder
from project.preprocessing import NiftiToTensorTransform, get_transform

# image_size = 300
# patch_size = 32

# %%
vit_test_dice = []
vit_test_precision = []
vit_test_recall = []
vit_test_f1 = []
vit_test_fpr = []

# %%
vit_fold_metrics = []


fold_dir = f'./fold/{dte}'
os.makedirs(fold_dir, exist_ok=True)

for i, (train_index, val_index) in enumerate(kf.split(vit_train_set)):
    print(f'Fold {i + 1}/{5}')
    logger.info(f'################################### Fold {i+1}/5 ###################################')
    
    # RPN
    # rpn_config['model'] = RPN(**rpn_tk.model_hyperparams).to(device)
    rpn = RPN(**rpn_tk.model_hyperparams).to(device)
    rpn.load_state_dict(torch.load(rpn_weights))
    vit_tk.stage1_weights = rpn_weights

    # FEEDER
    
    feeder = AnchorFeeder(patch_size)
    stone = GCRPN(
        rpn=rpn,
        feeder=feeder,
        image_size=image_size,
        patch_size=patch_size,
        model_b=True
    ).to(device)
    
    # ViT
    
    vit_config['model'] = ISAVIT(**vit_tk.model_hyperparams).to(device)
    
    vit_fitter = ViTFitter(vit_config, logger=logger)
    
    train_subset = Subset(vit_train_set, train_index)
    val_subset = Subset(vit_train_set, val_index)

    vit_tk.batch_size = 15
    
    train_subset_dl = DataLoader(
        train_subset,
        shuffle=True,
        batch_size=vit_tk.batch_size,
        collate_fn=collatev2
    )
    
    val_subset_dl = DataLoader(
        val_subset,
        shuffle=True,
        batch_size=vit_tk.batch_size,
        collate_fn=collatev2
    )
    
    vit_thist, vit_vhist, vit_tmhist, vit_vmhist = vit_fitter.fit(train_subset_dl, val_subset_dl, stone)
    
    vit_fold_metrics.append({
        'fold': i + 1,
        'training_history': vit_thist,
        'validation_history': vit_vhist,
        'training_metrics': vit_tmhist,
        'validation_metrics': vit_vmhist
    })
    
    vit_h, vit_mh = vit_fitter.validation(vit_test_dataloader, stone)
    vit_valmets = pd.DataFrame(vit_mh)
    vit_mets = vit_valmets.mean()
    
    vit_test_dice.append(vit_mets.dice_score)
    vit_test_precision.append(vit_mets.precision_score)
    vit_test_recall.append(vit_mets.recall_score)
    vit_test_f1.append(vit_mets.f1_score)
    vit_test_fpr.append(vit_mets.fpr)

    os.makedirs(f'{fold_dir}/fold_{i+1}', exist_ok=True)
    torch.save(vit_fitter.model.state_dict(), f'{fold_dir}/fold_{i+1}/vit_fold{i+1}.pt')
# Out:
# INFO:kess:################################### Fold 1/5 ###################################
# Fold 1/5
# 324
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# INFO:kess:EPOCH 0 ==============================
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# C:\Program Files\Python310\lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7387356758117676
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7247595191001892
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7112894654273987
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.6970090866088867
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0014030052816356466
# INFO:kess:Avg Precision: 0.0007050966814861049
# INFO:kess:Avg Recall: 0.19815284243198963
# INFO:kess:Avg F1: 0.0014030052816356466
# INFO:kess:Avg FPR: 0.32304711118365337
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.002738374536118962
# INFO:kess:Avg Precision: 0.0013839572244703537
# INFO:kess:Avg Recall: 0.2335764335764336
# INFO:kess:Avg F1: 0.002738374536118962
# INFO:kess:Avg FPR: 0.2997102007133693
#
# INFO:kess:EPOCH 1 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6849468350410461
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.676670253276825
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.663489580154419
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.6566063761711121
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0012247050195026382
# INFO:kess:Avg Precision: 0.0006162160810888463
# INFO:kess:Avg Recall: 0.14926980026029765
# INFO:kess:Avg F1: 0.0012247050195026382
# INFO:kess:Avg FPR: 0.29076928382921957
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.002993067899921003
# INFO:kess:Avg Precision: 0.0015161819908279875
# INFO:kess:Avg Recall: 0.19204019204019207
# INFO:kess:Avg F1: 0.002993067899921003
# INFO:kess:Avg FPR: 0.2685995056197889
#
# INFO:kess:EPOCH 2 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6453109979629517
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6376485228538513
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6286249756813049
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.6215565800666809
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0009885787767211617
# INFO:kess:Avg Precision: 0.0004975369202982239
# INFO:kess:Avg Recall: 0.1039520625159791
# INFO:kess:Avg F1: 0.0009885787767211617
# INFO:kess:Avg FPR: 0.2623985621787346
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0027635161268945584
# INFO:kess:Avg Precision: 0.0014030187877702729
# INFO:kess:Avg Recall: 0.1714824314824315
# INFO:kess:Avg F1: 0.0027635161268945584
# INFO:kess:Avg FPR: 0.2383524104173838
#
# INFO:kess:EPOCH 3 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6161937713623047
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6043139696121216
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5979934334754944
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.5891563296318054
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.001048309489795764
# INFO:kess:Avg Precision: 0.0005285347920182911
# INFO:kess:Avg Recall: 0.09414451856411021
# INFO:kess:Avg F1: 0.0010483094897957635
# INFO:kess:Avg FPR: 0.2357544955022264
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.002192614218315564
# INFO:kess:Avg Precision: 0.0011095862450166848
# INFO:kess:Avg Recall: 0.172048932048932
# INFO:kess:Avg F1: 0.002192614218315564
# INFO:kess:Avg FPR: 0.20977970562081977
#
# INFO:kess:EPOCH 4 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5815648436546326
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.576192319393158
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5690637826919556
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.5584107637405396
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0009628295228646493
# INFO:kess:Avg Precision: 0.0004859738350983267
# INFO:kess:Avg Recall: 0.07479577947211775
# INFO:kess:Avg F1: 0.0009628295228646493
# INFO:kess:Avg FPR: 0.20795460659861656
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.002327091494458903
# INFO:kess:Avg Precision: 0.0011880807876632684
# INFO:kess:Avg Recall: 0.11562037562037561
# INFO:kess:Avg F1: 0.0023270914944589025
# INFO:kess:Avg FPR: 0.18017982666004106
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0012482052699342885
# INFO:kess:Avg Precision: 0.0006334119320255932
# INFO:kess:Avg Recall: 0.07683286393240626
# INFO:kess:Avg F1: 0.0012482052699342885
# INFO:kess:Avg FPR: 0.18029731251123624
#
# INFO:kess:################################### Fold 2/5 ###################################
# Fold 2/5
# 324
# INFO:kess:EPOCH 0 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7337019443511963
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.720159649848938
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7059207558631897
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.6942447423934937
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0016503621067303518
# INFO:kess:Avg Precision: 0.0008305350097793787
# INFO:kess:Avg Recall: 0.21415823785245694
# INFO:kess:Avg F1: 0.0016503621067303516
# INFO:kess:Avg FPR: 0.32122692355149257
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0012365436756049722
# INFO:kess:Avg Precision: 0.0006219902916655317
# INFO:kess:Avg Recall: 0.15942028985507245
# INFO:kess:Avg F1: 0.0012365436756049722
# INFO:kess:Avg FPR: 0.29538007601155325
#
# INFO:kess:EPOCH 1 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.682255208492279
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6704772114753723
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6621080636978149
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.650740921497345
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0013897592033674168
# INFO:kess:Avg Precision: 0.0006994496948438873
# INFO:kess:Avg Recall: 0.16915692347994576
# INFO:kess:Avg F1: 0.0013897592033674168
# INFO:kess:Avg FPR: 0.2885503167591495
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0014024187267171395
# INFO:kess:Avg Precision: 0.0007062973552151221
# INFO:kess:Avg Recall: 0.15108695652173912
# INFO:kess:Avg F1: 0.0014024187267171395
# INFO:kess:Avg FPR: 0.26082536002946
#
# INFO:kess:EPOCH 2 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6420655846595764
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6336957216262817
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6226111054420471
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.6187188625335693
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.001729922407463924
# INFO:kess:Avg Precision: 0.0008738100204402302
# INFO:kess:Avg Recall: 0.14483758924681842
# INFO:kess:Avg F1: 0.0017299224074639236
# INFO:kess:Avg FPR: 0.25927736020212183
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0012540291278856045
# INFO:kess:Avg Precision: 0.0006323249139313202
# INFO:kess:Avg Recall: 0.12306763285024154
# INFO:kess:Avg F1: 0.0012540291278856047
# INFO:kess:Avg FPR: 0.23103202959204275
#
# INFO:kess:EPOCH 3 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6107172966003418
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6002406477928162
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5944022536277771
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.5835504531860352
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0018430944624042824
# INFO:kess:Avg Precision: 0.0009324966803243667
# INFO:kess:Avg Recall: 0.12691911869343275
# INFO:kess:Avg F1: 0.0018430944624042824
# INFO:kess:Avg FPR: 0.23173292684925675
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.001491193998529259
# INFO:kess:Avg Precision: 0.0007528573693344705
# INFO:kess:Avg Recall: 0.1286231884057971
# INFO:kess:Avg F1: 0.001491193998529259
# INFO:kess:Avg FPR: 0.2014529961888602
#
# INFO:kess:EPOCH 4 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5767002105712891
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5715910196304321
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5619741678237915
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.555138885974884
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0015353126755691842
# INFO:kess:Avg Precision: 0.0007766452927855707
# INFO:kess:Avg Recall: 0.1079737072891231
# INFO:kess:Avg F1: 0.001535312675569184
# INFO:kess:Avg FPR: 0.20273595500773092
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0015854361417911606
# INFO:kess:Avg Precision: 0.0008013618272918961
# INFO:kess:Avg Recall: 0.11586770717205501
# INFO:kess:Avg F1: 0.0015854361417911606
# INFO:kess:Avg FPR: 0.17143986360223798
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0016613742086908645
# INFO:kess:Avg Precision: 0.0008453165376451183
# INFO:kess:Avg Recall: 0.06803232998885173
# INFO:kess:Avg F1: 0.0016613742086908645
# INFO:kess:Avg FPR: 0.17386408665617364
#
# INFO:kess:################################### Fold 3/5 ###################################
# Fold 3/5
# 324
# INFO:kess:EPOCH 0 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7325749397277832
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7183002829551697
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7059215903282166
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.6930838823318481
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.001392136865903254
# INFO:kess:Avg Precision: 0.0007017820335690264
# INFO:kess:Avg Recall: 0.1455883929404522
# INFO:kess:Avg F1: 0.001392136865903254
# INFO:kess:Avg FPR: 0.32011732898634127
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0009618963832263215
# INFO:kess:Avg Precision: 0.0004829699306270415
# INFO:kess:Avg Recall: 0.15645424836601307
# INFO:kess:Avg F1: 0.0009618963832263215
# INFO:kess:Avg FPR: 0.29643578791520564
#
# INFO:kess:EPOCH 1 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6814528107643127
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6704016327857971
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6570793390274048
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.6528351902961731
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0011671384772384942
# INFO:kess:Avg Precision: 0.0005880577043041302
# INFO:kess:Avg Recall: 0.14259177165077155
# INFO:kess:Avg F1: 0.0011671384772384945
# INFO:kess:Avg FPR: 0.2873842384673107
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0010030833294593585
# INFO:kess:Avg Precision: 0.000504193383261941
# INFO:kess:Avg Recall: 0.13200980392156864
# INFO:kess:Avg F1: 0.0010030833294593585
# INFO:kess:Avg FPR: 0.26381111048628303
#
# INFO:kess:EPOCH 2 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6445984840393066
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6305045485496521
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6227163672447205
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.6158857941627502
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.001176114971327697
# INFO:kess:Avg Precision: 0.0005920939300728737
# INFO:kess:Avg Recall: 0.1384539606679311
# INFO:kess:Avg F1: 0.001176114971327697
# INFO:kess:Avg FPR: 0.25841560752975884
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0008592975262429394
# INFO:kess:Avg Precision: 0.00043254070715382907
# INFO:kess:Avg Recall: 0.08450980392156862
# INFO:kess:Avg F1: 0.0008592975262429394
# INFO:kess:Avg FPR: 0.23578721398361163
#
# INFO:kess:EPOCH 3 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6080041527748108
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6025413870811462
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5909978151321411
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.5832766890525818
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0018113354250938456
# INFO:kess:Avg Precision: 0.0009170849938706681
# INFO:kess:Avg Recall: 0.13063751217358238
# INFO:kess:Avg F1: 0.0018113354250938458
# INFO:kess:Avg FPR: 0.2307164975905319
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0009177905920369536
# INFO:kess:Avg Precision: 0.0004627178371962866
# INFO:kess:Avg Recall: 0.07339869281045751
# INFO:kess:Avg F1: 0.0009177905920369535
# INFO:kess:Avg FPR: 0.2075018384224233
#
# INFO:kess:EPOCH 4 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.577725350856781
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5679635405540466
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5644651651382446
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	13
# INFO:kess:Current error:	0.5533021092414856
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0011655495429706614
# INFO:kess:Avg Precision: 0.0005879503348836688
# INFO:kess:Avg Recall: 0.10936987102323552
# INFO:kess:Avg F1: 0.0011655495429706614
# INFO:kess:Avg FPR: 0.20323750697244092
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0008967705465849734
# INFO:kess:Avg Precision: 0.0004530049945699542
# INFO:kess:Avg Recall: 0.05836601307189542
# INFO:kess:Avg F1: 0.0008967705465849734
# INFO:kess:Avg FPR: 0.17784881522493487
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0012009089509641918
# INFO:kess:Avg Precision: 0.000611614532602034
# INFO:kess:Avg Recall: 0.04493927125506073
# INFO:kess:Avg F1: 0.0012009089509641918
# INFO:kess:Avg FPR: 0.17682009915955318
#
# INFO:kess:################################### Fold 4/5 ###################################
# Fold 4/5
# 324
# INFO:kess:EPOCH 0 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7359895706176758
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7211500406265259
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7070813775062561
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.6953657865524292
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0019011693104875186
# INFO:kess:Avg Precision: 0.0009571494722973495
# INFO:kess:Avg Recall: 0.24068134669049315
# INFO:kess:Avg F1: 0.0019011693104875186
# INFO:kess:Avg FPR: 0.3224372968246809
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0005402203462583556
# INFO:kess:Avg Precision: 0.00027151942415916164
# INFO:kess:Avg Recall: 0.08630952380952381
# INFO:kess:Avg F1: 0.0005402203462583556
# INFO:kess:Avg FPR: 0.29882425817414093
#
# INFO:kess:EPOCH 1 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6806337833404541
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6715467572212219
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6583259701728821
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.6500666737556458
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0020016151398169874
# INFO:kess:Avg Precision: 0.0010080070349491287
# INFO:kess:Avg Recall: 0.22442132660878597
# INFO:kess:Avg F1: 0.0020016151398169874
# INFO:kess:Avg FPR: 0.2882493210069231
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.00027780149432274516
# INFO:kess:Avg Precision: 0.00013924575187372468
# INFO:kess:Avg Recall: 0.07142857142857142
# INFO:kess:Avg F1: 0.00027780149432274516
# INFO:kess:Avg FPR: 0.26675378979773073
#
# INFO:kess:EPOCH 2 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6383486986160278
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6300053596496582
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6233468055725098
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.6169869899749756
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0019720488978544146
# INFO:kess:Avg Precision: 0.000996347997461943
# INFO:kess:Avg Recall: 0.17703102794730088
# INFO:kess:Avg F1: 0.0019720488978544146
# INFO:kess:Avg FPR: 0.2579825695720834
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.00023735763639703557
# INFO:kess:Avg Precision: 0.00011899353760952568
# INFO:kess:Avg Recall: 0.05952380952380952
# INFO:kess:Avg F1: 0.00023735763639703557
# INFO:kess:Avg FPR: 0.2395784455415653
#
# INFO:kess:EPOCH 3 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6071925163269043
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5992767810821533
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5922091007232666
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.584338366985321
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.001988435447264141
# INFO:kess:Avg Precision: 0.0010047389358522982
# INFO:kess:Avg Recall: 0.1539886516023323
# INFO:kess:Avg F1: 0.001988435447264141
# INFO:kess:Avg FPR: 0.23054039076879282
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.00018563416738048212
# INFO:kess:Avg Precision: 9.306900726392252e-05
# INFO:kess:Avg Recall: 0.047619047619047616
# INFO:kess:Avg F1: 0.00018563416738048212
# INFO:kess:Avg FPR: 0.20994408504903292
#
# INFO:kess:EPOCH 4 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5775747895240784
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5685737729072571
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5591485500335693
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.5551851987838745
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0021658267786700547
# INFO:kess:Avg Precision: 0.0011011744979497569
# INFO:kess:Avg Recall: 0.1158186555185775
# INFO:kess:Avg F1: 0.0021658267786700547
# INFO:kess:Avg FPR: 0.20145091239120486
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.00010589854918987609
# INFO:kess:Avg Precision: 5.302789267154523e-05
# INFO:kess:Avg Recall: 0.03571428571428571
# INFO:kess:Avg F1: 0.00010589854918987609
# INFO:kess:Avg FPR: 0.1797327521584231
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0018509615417665807
# INFO:kess:Avg Precision: 0.0009392411685100683
# INFO:kess:Avg Recall: 0.09156728568913924
# INFO:kess:Avg F1: 0.0018509615417665807
# INFO:kess:Avg FPR: 0.17327474077130206
#
# INFO:kess:################################### Fold 5/5 ###################################
# Fold 5/5
# 324
# INFO:kess:EPOCH 0 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.730228841304779
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7163874506950378
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.7036433219909668
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.6923007369041443
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0016372575910993828
# INFO:kess:Avg Precision: 0.0008250211109957285
# INFO:kess:Avg Recall: 0.1828319286173983
# INFO:kess:Avg F1: 0.0016372575910993828
# INFO:kess:Avg FPR: 0.31950376941825626
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0013646244099985783
# INFO:kess:Avg Precision: 0.0006853716871486228
# INFO:kess:Avg Recall: 0.1738583312112724
# INFO:kess:Avg F1: 0.001364624409998578
# INFO:kess:Avg FPR: 0.29627324036786806
#
# INFO:kess:EPOCH 1 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6788097023963928
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6674104332923889
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6575829386711121
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.6505094766616821
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0015188425981870536
# INFO:kess:Avg Precision: 0.0007649040473616696
# INFO:kess:Avg Recall: 0.1772502440942772
# INFO:kess:Avg F1: 0.0015188425981870536
# INFO:kess:Avg FPR: 0.28747210441669035
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0012407733945163054
# INFO:kess:Avg Precision: 0.0006235541695388511
# INFO:kess:Avg Recall: 0.14108522196757492
# INFO:kess:Avg F1: 0.0012407733945163054
# INFO:kess:Avg FPR: 0.26437919483417655
#
# INFO:kess:EPOCH 2 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.63973468542099
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6287072896957397
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6208757162094116
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.6153864860534668
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.001530239250357102
# INFO:kess:Avg Precision: 0.000772904236157927
# INFO:kess:Avg Recall: 0.14187494511793353
# INFO:kess:Avg F1: 0.0015302392503571019
# INFO:kess:Avg FPR: 0.25816005443541545
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.001783721606477962
# INFO:kess:Avg Precision: 0.0009019657744175538
# INFO:kess:Avg Recall: 0.10879806468041762
# INFO:kess:Avg F1: 0.0017837216064779623
# INFO:kess:Avg FPR: 0.23526215783334276
#
# INFO:kess:EPOCH 3 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.6033723950386047
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5980468988418579
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5875502824783325
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.5862228870391846
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0013990374975807523
# INFO:kess:Avg Precision: 0.0007072248932634152
# INFO:kess:Avg Recall: 0.10583742870090351
# INFO:kess:Avg F1: 0.0013990374975807523
# INFO:kess:Avg FPR: 0.23047483728279902
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0026083743049099477
# INFO:kess:Avg Precision: 0.0013186157179434024
# INFO:kess:Avg Recall: 0.17007257448433918
# INFO:kess:Avg F1: 0.0026083743049099477
# INFO:kess:Avg FPR: 0.2058859654733365
#
# INFO:kess:EPOCH 4 ==============================
# INFO:kess:Batch:	1/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5730116367340088
#
# INFO:kess:Batch:	2/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5655137896537781
#
# INFO:kess:Batch:	3/4
# INFO:kess:Batch samples:	15
# INFO:kess:Current error:	0.5587804317474365
#
# INFO:kess:Batch:	4/4
# INFO:kess:Batch samples:	14
# INFO:kess:Current error:	0.5554466843605042
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.0014888842320943058
# INFO:kess:Avg Precision: 0.0007546525941695188
# INFO:kess:Avg Recall: 0.11189870346151502
# INFO:kess:Avg F1: 0.0014888842320943058
# INFO:kess:Avg FPR: 0.20245362893400007
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0014004950755409488
# INFO:kess:Avg Precision: 0.000705621900324205
# INFO:kess:Avg Recall: 0.10344410491469315
# INFO:kess:Avg F1: 0.0014004950755409488
# INFO:kess:Avg FPR: 0.1759187360311046
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.0015664907459513417
# INFO:kess:Avg Precision: 0.0007944225871551617
# INFO:kess:Avg Recall: 0.08445696180249956
# INFO:kess:Avg F1: 0.0015664907459513417
# INFO:kess:Avg FPR: 0.17501316576423095

# %%
import winsound

winsound.Beep(500, 500)
winsound.Beep(500, 500)
winsound.Beep(500, 500)

# %% [markdown]
# ### Metrics Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_metric_history(fold_metrics, metric, title=None):
    avg_train = []
    avg_test = []

    for fold in range(len(fold_metrics)):
        train = []
        test = []
        
        for epoch in range(len(fold_metrics[fold]['training_metrics'])):
            th = np.array(fold_metrics[fold]['training_metrics'][epoch][metric]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_metrics'][epoch][metric]).mean()
            test.append(vh)
            
        avg_train.append(np.array(train))
        avg_test.append(np.array(test))
    
    epochs = len(np.mean(avg_train, axis=0)) + 1
            
    sns.lineplot(x=range(1, epochs), y=np.mean(avg_train, axis=0), label=f'Training {metric}')
    sns.lineplot(x=range(1, epochs), y=np.mean(avg_test, axis=0), label=f'Validation {metric}')
    
    plt.title(f'{title} - Training and Validation {metric}')
    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.legend()
        
    plt.tight_layout()  
    plt.show()

# %%
vit_metrics = ['dice_score', 'precision_score', 'recall_score', 'f1_score', 'fpr']

for metric in vit_metrics:
    plot_metric_history(vit_fold_metrics, metric, 'ViT ')

# %% [markdown]
# ### Loss History Visualization

# %%
def plot_loss_history(fold_metrics, title=None):
    avg_train = []
    avg_test = []

    for fold in range(len(fold_metrics)):
        train = []
        test = []
        
        for epoch in range(len(fold_metrics[fold]['training_history'])):
            th = np.array(fold_metrics[fold]['training_history'][epoch]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_history'][epoch]).mean()
            test.append(vh)
            
        avg_train.append(np.array(train))
        avg_test.append(np.array(test))
    
    epochs = len(np.mean(avg_train, axis=0)) + 1
        
    sns.lineplot(x=range(1, epochs), y=np.mean(avg_train, axis=0), label='Training history')
    sns.lineplot(x=range(1, epochs), y=np.mean(avg_test, axis=0), label='Validation history')
        
    plt.title(f'{title} - Training and Validation history')
    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.legend()
    
    plt.tight_layout()  
    plt.show()

# %%
plot_loss_history(vit_fold_metrics, 'ViT ')

# %% [raw]
# rpn_hist = torch.tensor(np.array(rpn_fold_metrics))
# vit_hist = torch.tensor(np.array(vit_fold_metrics))
#
# s_rpn_hist = f'history/{dte}_rpn_hist.pt'
# s_vit_hist = f'history/{dte}_vit_hist.pt'
# rpn_tk.saved_thist = s_rpn_hist
# vit_tk.saved_vhist = s_vit_hist
# torch.save(rpn_hist, s_rpn_hist)
# torch.save(vit_hist, s_vit_hist)

# %% [markdown]
# ### Evaluate Test Set

# %% [markdown]
# #### ViT

# %%
df_vit_metrics = pd.DataFrame(columns=['fold', 'dice', 'precision', 'recall', 'f1', 'fpr'])
df_vit_metrics
# Out:
# Empty DataFrame
# Columns: [fold, dice, precision, recall, f1, fpr]
# Index: []

# %%
df_vit_metrics['fold'] = [1, 2, 3, 4, 5]
df_vit_metrics['dice'] = vit_test_dice
df_vit_metrics['precision'] = vit_test_precision
df_vit_metrics['recall'] = vit_test_recall
df_vit_metrics['f1'] = vit_test_f1
df_vit_metrics['fpr'] = vit_test_fpr

# %%
vit_tk.dice = df_vit_metrics.dice
vit_tk.precision = df_vit_metrics.precision
vit_tk.recall = df_vit_metrics.recall
vit_tk.f1 = df_vit_metrics.f1
vit_tk.fpr = df_vit_metrics.fpr

# %%
df_vit_metrics
# Out:
#    fold      dice  precision    recall        f1       fpr
# 0     1  0.001248   0.000633  0.076833  0.001248  0.180297
# 1     2  0.001661   0.000845  0.068032  0.001661  0.173864
# 2     3  0.001201   0.000612  0.044939  0.001201  0.176820
# 3     4  0.001851   0.000939  0.091567  0.001851  0.173275
# 4     5  0.001566   0.000794  0.084457  0.001566  0.175013

# %%
# vit_iou_score = np.array(vit_test_iou).mean()
vit_dice_score = np.array(vit_test_dice).mean()
vit_precision_score = np.array(vit_test_precision).mean()
vit_recall_score = np.array(vit_test_recall).mean()
vit_f1_score = np.array(vit_test_f1).mean()
vit_fpr_score = np.array(vit_test_fpr).mean()

print('ViT Test Set Performance Metrics')
print(f'Average Dice Score: {vit_dice_score} ')
print(f'Average Precision: {vit_precision_score} ')
print(f'Average Recall: {vit_recall_score} ')
print(f'Average F1 Score: {vit_f1_score} ')
print(f'Average FPR: {vit_fpr_score} ')
# Out:
# ViT Test Set Performance Metrics
# Average Dice Score: 0.0015055881434614534
# Average Precision: 0.000764801351587595
# Average Recall: 0.07316574253359151
# Average F1 Score: 0.0015055881434614534
# Average FPR: 0.17585388097249924

# %%
df_vit_metrics.to_csv(f'{fold_dir}/vit_metrics.csv')

# %%
df_vit_metrics.to_csv(f'./statistical-treatment/isa-rpn_isa-vit.csv')

# %% [markdown]
# ### Sample

# %% [markdown]
# #### ViT

# %%
import matplotlib.patches as patches

# %%
sample = next(iter(vit_test_dataloader))

for i in range(len(next(iter(vit_test_dataloader)))):
    vit_slices, vit_masks, vit_target, vit_case = sample[i]
    
    vit_slices = vit_slices.squeeze(1).float().to(device)
    vit_masks = vit_masks.float().to(device)
    
    vit_x, vit_t = stone(vit_slices, vit_masks, vit_target)
    
    f, a = plt.subplots(1, 2, figsize=(10, 4))

    f.tight_layout()
    ax1 = a.flat[0]
    ax2 = a.flat[1]
    ax1.set_title('MRI Slice Crop')
    ax2.set_title('Mask Slice Crop')
    sns.heatmap(vit_x[vit_target].squeeze().numpy(force=True), ax=ax1)
    sns.heatmap(vit_t[vit_target].squeeze().numpy(force=True), ax=ax2)

    vit_y = vit_fitter.model(vit_x.flatten(2).to(device), vit_target)
    vit_y = vit_y.view(patch_size, patch_size)
    
    f, a = plt.subplots(1, 2, figsize=(10, 4))

    f.tight_layout()
    ax1 = a.flat[0]
    ax2 = a.flat[1]
    ax1.set_title('Mask Prediction')
    ax2.set_title('Mask Truth')
    sns.heatmap((vit_y.sigmoid() >= 0.5).detach().cpu(), ax=ax1, vmax=1)
    sns.heatmap(vit_t[vit_target].squeeze().cpu(), ax=ax2, vmax=1)
# Out:
# C:\Users\araza\AppData\Local\Temp\ipykernel_27288\206781252.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   f, a = plt.subplots(1, 2, figsize=(10, 4))

# %%
while True:
    winsound.Beep(500, 1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 2
#       1 while True:
# ----> 2     winsound.Beep(500, 1000)
#
# KeyboardInterrupt:

# %% [markdown]
# # Log Progress

# %%
vit_tk.notes = '''
Global Context
'''

# %%
vit_tk()

# %%
if os.path.exists('history/runs.csv'):
    print('Merging to old df')

    prev_df = pd.read_csv('history/runs.csv', index_col='date')
    merged = pd.concat([prev_df, vit_tk()])
    merged.to_csv('history/runs.csv')
else:
    print('Making new csv file')
    vit_tk().to_csv('history/runs.csv')
