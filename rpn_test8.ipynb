# %%
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform, z_score_normalization
from project.utils import collate_fn, plot_mri_slice, plot_all_slices, plot_all_slices_from_array, collatev2
import winsound
from torchvision.models import resnet18, ResNet18_Weights
from project.utils import memcheck
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.18 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations

# %%
import logging
logger = logging.getLogger('andy')
fh = logging.FileHandler('andy.log')
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)

logger.setLevel(logging.DEBUG)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)

logger.addHandler(fh)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
ds = Dataset()

data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 3)

# %%
ch1 = ds.load_raw_mri(1)
data = data[data.mri.isin(ch1)]
data.shape
# Out:
# (385, 3)

# %%
transform = NiftiToTensorTransform(target_shape = (256, 256), rpn_mode=True) # Hanggang dito lang kaya ng GPU mem ko

cases = data.mri
masks = data.masks
target = data.target

# %%
dataset = VALDODataset(
    cases=cases,
    masks=masks,
    target=target,
    transform=transform,
    normalization=z_score_normalization,
)

# %%
dloader = DataLoader(
    dataset,
    shuffle=True,
    batch_size=20,
    collate_fn=collatev2,
)

# %% [markdown]
# ### Config for fitter

# %%
from project.model import RPN

config = {
    'model': RPN(
        input_dim=2500,
        output_dim=4,
        image_size=256
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 1,
    'loss': nn.MSELoss(),
    # 'loss': nn.MSELoss(),
    'lr': 0.0000001
}
# Out:
# 1024
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# ### Sample trial

# %% [markdown]
# ### Fitter

# %%
from project import Fitter

class RPNFitter(Fitter):
    def train_one_epoch(self, train_loader):
        self.model.train()
        loss_history = []
        counter = 0
        for batch in train_loader:
            Y = []
            T = []
            for slices, masks, target, case in batch:
                num_slices = slices.shape[0]
                # x = slices.view(num_slices, 1, -1).float().to(self.device)
                # x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                # masks = masks.view(num_slices, 1, -1).float().to(self.device)
                x = slices.squeeze(1).float().to(self.device)
                masks = masks.squeeze(1).float().to(self.device)
                y = self.model(x, target)
                logger.info(f'MEMORY after X, Y, T to device\t{memcheck()}')
                Y.append(y)
                T.append(masks[target])
                # memcheck()
                # del x, y, masks, slices
                # torch.cuda.empty_cache()
                # memcheck()
            
            losses = self.loss(torch.stack(Y), torch.stack(T))
            loss_history.append(losses)
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += len(batch)
            if counter % 100 == 0:
                logger.info(f'Progress:\t{counter}/{len(dataset)}')
                logger.info(f'Current error:\t{losses}')
            
            # del losses, Y, T
            # torch.cuda.empty_cache()
            # logger.info(f'MEMORY after CLEARING MEMORY\t{memcheck()}')
            
        return loss_history

# %%
fitter = RPNFitter(config)

# %% [markdown]
# ### Training

# %%
hist = fitter.fit(dloader, dloader)
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# C:\Program Files\Python310\lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# INFO:andy:MEMORY after X, Y, T to device	(384077824, 400556032)
# INFO:andy:MEMORY after X, Y, T to device	(396816384, 421527552)
# INFO:andy:MEMORY after X, Y, T to device	(409882624, 423624704)
# INFO:andy:MEMORY after X, Y, T to device	(422621184, 446693376)
# INFO:andy:MEMORY after X, Y, T to device	(435687424, 446693376)
# INFO:andy:MEMORY after X, Y, T to device	(449409024, 469762048)
# INFO:andy:MEMORY after X, Y, T to device	(462475264, 469762048)
# INFO:andy:MEMORY after X, Y, T to device	(475213824, 492830720)
# INFO:andy:MEMORY after X, Y, T to device	(488280064, 513802240)
# INFO:andy:MEMORY after X, Y, T to device	(501018624, 515899392)
# INFO:andy:MEMORY after X, Y, T to device	(513757184, 538968064)
# INFO:andy:MEMORY after X, Y, T to device	(526823424, 541065216)
# INFO:andy:MEMORY after X, Y, T to device	(539561984, 562036736)
# INFO:andy:MEMORY after X, Y, T to device	(552628224, 564133888)
# INFO:andy:MEMORY after X, Y, T to device	(565694464, 585105408)
# INFO:andy:MEMORY after X, Y, T to device	(578760704, 587202560)
# INFO:andy:MEMORY after X, Y, T to device	(591499264, 610271232)
# INFO:andy:MEMORY after X, Y, T to device	(604565504, 631242752)
# INFO:andy:MEMORY after X, Y, T to device	(617304064, 633339904)
# INFO:andy:MEMORY after X, Y, T to device	(630042624, 654311424)
# C:\Program Files\Python310\lib\site-packages\torch\autograd\graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877262848, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(890984448, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(904050688, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(916789248, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(929626112, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(942692352, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(955758592, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(968497152, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(981563392, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(994301952, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1007368192, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1021089792, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1034156032, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1046894592, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1059960832, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1072699392, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1085437952, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1098504192, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1111242752, 1283457024)
# INFO:andy:MEMORY after X, Y, T to device	(1124308992, 1283457024)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877263360, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(890984960, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(903723520, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(916560384, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(929626624, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(942365184, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(955202048, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(968268288, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(981334528, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(994073088, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1007139328, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1019877888, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1032944128, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1046665728, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1059731968, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1072470528, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1085536768, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1098275328, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1111013888, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1124080128, 1358954496)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877755392, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(891476992, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(904215552, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(917052416, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(930118656, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(942857216, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(955923456, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(968662016, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(981728256, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(995449856, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1008516096, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1021254656, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1034320896, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1047059456, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1059798016, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1072864256, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1085602816, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1098669056, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1111735296, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1124801536, 1358954496)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877264384, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(890985984, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(903724544, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(916561408, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(929627648, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(942366208, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(955203072, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(968269312, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(981335552, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(994074112, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1007140352, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1019878912, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1032945152, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1046666752, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1059732992, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1072471552, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1085537792, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1098276352, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1111014912, 1358954496)
# INFO:andy:MEMORY after X, Y, T to device	(1124081152, 1361051648)
# INFO:andy:Progress:	100/385
# INFO:andy:Current error:	605.8997802734375
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877756416, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(891478016, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(904216576, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(917053440, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(930119680, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(942858240, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(955924480, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(968663040, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(981729280, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(995450880, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1008517120, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1021255680, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1034321920, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1047060480, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059799040, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072865280, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085603840, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098670080, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111736320, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124802560, 1361051648)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877265408, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(890987008, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(903725568, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(916562432, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(929628672, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(942367232, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(955204096, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(968270336, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(981336576, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(994075136, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1007141376, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1019879936, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1032946176, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1046667776, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059734016, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072472576, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085538816, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098277376, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111015936, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124082176, 1361051648)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877757440, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(891479040, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(904217600, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(917054464, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(930120704, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(942859264, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(955925504, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(968664064, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(981730304, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(995451904, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1008518144, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1021256704, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1034322944, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1047061504, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059800064, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072866304, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085604864, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098671104, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111737344, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124803584, 1361051648)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877266432, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(890988032, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(903726592, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(916563456, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(929629696, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(942368256, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(955205120, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(968271360, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(981337600, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(994076160, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1007142400, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1019880960, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1032947200, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1046668800, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059735040, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072473600, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085539840, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098278400, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111016960, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124083200, 1361051648)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877758464, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(891480064, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(904218624, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(917055488, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(930121728, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(942860288, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(955926528, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(968665088, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(981731328, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(995452928, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1008519168, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1021257728, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1034323968, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1047062528, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059801088, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072867328, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085605888, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098672128, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111738368, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124804608, 1361051648)
# INFO:andy:Progress:	200/385
# INFO:andy:Current error:	1000.6778564453125
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# ...
# INFO:andy:MEMORY after X, Y, T to device	(1021260800, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1034327040, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1047065600, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059804160, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072870400, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085608960, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098675200, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111741440, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124807680, 1361051648)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877270528, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(890992128, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(903730688, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(916567552, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(929633792, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(942372352, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(955209216, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(968275456, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(981341696, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(994080256, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1007146496, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1019885056, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1032951296, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1046672896, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059739136, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072477696, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085543936, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098282496, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111021056, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124087296, 1361051648)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877762560, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(891484160, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(904222720, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(917059584, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(930125824, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(942864384, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(955930624, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(968669184, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(981735424, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(995457024, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1008523264, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1021261824, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1034328064, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1047066624, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059805184, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072871424, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085609984, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098676224, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111742464, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124808704, 1361051648)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877271552, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(890993152, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(903731712, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(916568576, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(929634816, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(942373376, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(955210240, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(968276480, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(981342720, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(994081280, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1007147520, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1019886080, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1032952320, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1046673920, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1059740160, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1072478720, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1085544960, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1098283520, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1111022080, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(1124088320, 1361051648)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(877763584, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(891485184, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(904223744, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(917060608, 1361051648)
# INFO:andy:MEMORY after X, Y, T to device	(930126848, 1361051648)

# %%
winsound.Beep(500, 500)
winsound.Beep(500, 500)
winsound.Beep(500, 500)

# %%
import seaborn as sns

sns.lineplot(torch.tensor(hist).view(-1))
torch.tensor(hist).mean()
# Out:
# tensor(1590.2507)

# %% [markdown]
# # Summary
#
# Performance of self-made embedder is a bit better compared to the pretrained embedder. Might work better if self-made embedder is also pretrained
#
# ### Next goals
# - train embedder with an autoencoder setup

# %% [markdown]
# # Trial

# %%
model = fitter.model

# %%
sample = next(enumerate(dloader))
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1

# %%
slices, masks, target, case = sample[1][1]

# %%
masks[target]
# Out:
# tensor([[[0., 0., 0., 0.]]], dtype=torch.float64)

# %%
num_slices = slices.shape[0]
num_slices
# Out:
# 35

# %%
x = slices.squeeze(1).float().to(device)
T = masks.squeeze(1).float().to(device)

# %%
y = model(x, target)

# %%
fitter.loss(y, T[target])
# Out:
# tensor(0.1562, device='cuda:0', grad_fn=<MseLossBackward0>)

# %%
y
# Out:
# tensor([[ 0.1409,  0.4172, -0.5458, -0.3646]], device='cuda:0',
#        grad_fn=<EluBackward0>)
