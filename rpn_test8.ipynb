# %%
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform, z_score_normalization
from project.utils import collate_fn, plot_mri_slice, plot_all_slices, plot_all_slices_from_array, collatev2
import winsound
from torchvision.models import resnet18, ResNet18_Weights
from project.utils import memcheck
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.18 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations

# %%
import logging
logger = logging.getLogger('andy')
fh = logging.FileHandler('andy.log')
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)

logger.setLevel(logging.DEBUG)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)

logger.addHandler(fh)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
ds = Dataset()

data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 3)

# %%
ch1 = ds.load_raw_mri(1)
data = data[data.mri.isin(ch1)]
data.shape
# Out:
# (385, 3)

# %%
transform = NiftiToTensorTransform(target_shape = (300, 300), rpn_mode=True) # Hanggang dito lang kaya ng GPU mem ko

cases = data.mri
masks = data.masks
target = data.target

# %%
dataset = VALDODataset(
    cases=cases,
    masks=masks,
    target=target,
    transform=transform,
    normalization=z_score_normalization,
)

# %%
dloader = DataLoader(
    dataset,
    shuffle=True,
    batch_size=20,
    collate_fn=collatev2,
)

# %% [markdown]
# ### Config for fitter

# %%
from project.model import RPN

config = {
    'model': RPN(
        input_dim=2500,
        output_dim=4,
        image_size=300
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 1,
    'loss': nn.SmoothL1Loss(),
    # 'loss': nn.MSELoss(),
    'lr': 0.00001
}
# Out:
# 1369
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# ### Sample trial

# %%
model = config['model']

# %%
model.embedder.load_state_dict(torch.load('Encoder_weights_211024184155.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Fitter

# %%
from project import Fitter

class RPNFitter(Fitter):
    def train_one_epoch(self, train_loader):
        self.model.train()
        loss_history = []
        counter = 0
        for batch in train_loader:
            Y = []
            T = []
            for slices, masks, target, case in batch:
                num_slices = slices.shape[0]
                # x = slices.view(num_slices, 1, -1).float().to(self.device)
                # x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                # masks = masks.view(num_slices, 1, -1).float().to(self.device)
                x = slices.squeeze(1).float().to(self.device)
                masks = masks.squeeze(1).float().to(self.device)
                y = self.model(x, target)
                logger.info(f'MEMORY after X, Y, T to device\t{memcheck()}')
                Y.append(y)
                T.append(masks[target])
                # memcheck()
                # del x, y, masks, slices
                # torch.cuda.empty_cache()
                # memcheck()
            
            losses = self.loss(torch.stack(Y), torch.stack(T))
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += len(batch)
            if counter % 100 == 0:
                logger.info(f'Progress:\t{counter}/{len(dataset)}')
                logger.info(f'Current error:\t{losses}')
            loss_history.append(losses.detach().cpu().numpy())
            
            # del losses, Y, T
            # torch.cuda.empty_cache()
            # logger.info(f'MEMORY after CLEARING MEMORY\t{memcheck()}')
            
        return loss_history

# %%
fitter = RPNFitter(config)

# %% [markdown]
# ### Training

# %%
hist = fitter.fit(dloader, dloader)
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# C:\Program Files\Python310\lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# INFO:andy:MEMORY after X, Y, T to device	(508836864, 591396864)
# INFO:andy:MEMORY after X, Y, T to device	(641882624, 799014912)
# INFO:andy:MEMORY after X, Y, T to device	(774928384, 901775360)
# INFO:andy:MEMORY after X, Y, T to device	(907974144, 1107296256)
# INFO:andy:MEMORY after X, Y, T to device	(1041019904, 1212153856)
# INFO:andy:MEMORY after X, Y, T to device	(1174065664, 1314914304)
# INFO:andy:MEMORY after X, Y, T to device	(1307111424, 1522532352)
# INFO:andy:MEMORY after X, Y, T to device	(1440157184, 1625292800)
# INFO:andy:MEMORY after X, Y, T to device	(1573202944, 1830813696)
# INFO:andy:MEMORY after X, Y, T to device	(1706248704, 1935671296)
# INFO:andy:MEMORY after X, Y, T to device	(1839294464, 2038431744)
# INFO:andy:MEMORY after X, Y, T to device	(1972340224, 2246049792)
# INFO:andy:MEMORY after X, Y, T to device	(2105385984, 2348810240)
# INFO:andy:MEMORY after X, Y, T to device	(2238431744, 2451570688)
# INFO:andy:MEMORY after X, Y, T to device	(2371477504, 2659188736)
# INFO:andy:MEMORY after X, Y, T to device	(2504523264, 2761949184)
# INFO:andy:MEMORY after X, Y, T to device	(2637569024, 2864709632)
# INFO:andy:MEMORY after X, Y, T to device	(2770614784, 3072327680)
# INFO:andy:MEMORY after X, Y, T to device	(2903660544, 3175088128)
# INFO:andy:MEMORY after X, Y, T to device	(3036706304, 3277848576)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1010754560, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(1143800320, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(1276846080, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(1409891840, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(1542937600, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(1675983360, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(1809029120, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(1942074880, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(2075120640, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(2208166400, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(2341212160, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(2474257920, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(2607303680, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(2740349440, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(2873395200, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(3006440960, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(3139486720, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(3272532480, 3609198592)
# INFO:andy:MEMORY after X, Y, T to device	(3405578240, 3711959040)
# INFO:andy:MEMORY after X, Y, T to device	(3538624000, 3816816640)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1011147264, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1144193024, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1277238784, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1410380288, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1543426048, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1676471808, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1809517568, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1942563328, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2075609088, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2208654848, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2341700608, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2474746368, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2607792128, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2740837888, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2873883648, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3006929408, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3139975168, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3273020928, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3406066688, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3539112448, 4022337536)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1010257408, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1143303168, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1276348928, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1409394688, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1542618624, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1675664384, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1808710144, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1941755904, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2074801664, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2207847424, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2340893184, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2473938944, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2606984704, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2740030464, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2873076224, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3006121984, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3139167744, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3272213504, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3405259264, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3538305024, 4022337536)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1010257408, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1144193024, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1277238784, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1410284544, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1543426048, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1676471808, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1809517568, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1942563328, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2075609088, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2208654848, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2341700608, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2474746368, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2607792128, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2740837888, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2873883648, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3006929408, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3139975168, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3273020928, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3406066688, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3539112448, 4022337536)
# INFO:andy:Progress:	100/385
# INFO:andy:Current error:	47.95832061767578
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1011147264, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1144193024, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1277238784, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1410284544, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1543330304, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1676376064, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1809421824, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1942467584, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2075513344, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2208559104, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2341604864, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2474650624, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2607696384, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2740742144, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2873787904, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3006833664, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3139879424, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3272925184, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3405970944, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3539016704, 4022337536)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1010257408, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1144193024, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1277238784, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1410284544, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1543330304, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1676376064, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1809421824, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(1942467584, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2075513344, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2208559104, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2341604864, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2474650624, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2607696384, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2741609984, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(2874655744, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3007701504, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3140747264, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3273793024, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3406838784, 4022337536)
# INFO:andy:MEMORY after X, Y, T to device	(3539884544, 4022337536)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1010257408, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1144193024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1277238784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1410284544, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1543330304, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1676376064, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1809421824, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1942467584, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2075513344, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2208559104, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2341604864, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2474650624, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2607696384, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2740742144, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2873787904, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3006833664, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3139879424, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3272925184, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3405970944, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3539016704, 4125097984)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1010257408, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1144193024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1277238784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1410284544, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1543330304, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1676376064, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1809421824, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1942467584, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2075513344, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2208559104, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2341604864, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2474650624, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2607696384, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2741609984, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2874655744, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3007701504, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3140747264, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3273793024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3406838784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3539884544, 4125097984)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1010257408, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1144193024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1277238784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1410284544, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1543330304, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1676376064, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1809421824, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1942467584, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2075513344, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2208559104, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2341604864, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2475518464, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2608564224, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2741609984, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2874655744, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3007701504, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3140747264, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3273793024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3406838784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3539884544, 4125097984)
# INFO:andy:Progress:	200/385
# INFO:andy:Current error:	19.29964256286621
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# ...
# INFO:andy:MEMORY after X, Y, T to device	(1943335424, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2076381184, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2209426944, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2342472704, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2475518464, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2608564224, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2741609984, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2874655744, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3007701504, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3140747264, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3273793024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3406838784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3539884544, 4125097984)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1012015104, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1145060864, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1278106624, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1411152384, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1544198144, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1677243904, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1810289664, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1943335424, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2076381184, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2209426944, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2342472704, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2475518464, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2608564224, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2741609984, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2874655744, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3007701504, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3140747264, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3273793024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3406838784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3539884544, 4125097984)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1012015104, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1145060864, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1278106624, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1411152384, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1544198144, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1677243904, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1810289664, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1943335424, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2076381184, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2209426944, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2342472704, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2475518464, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2608564224, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2741609984, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2874655744, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3007701504, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3140747264, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3273793024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3406838784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3539884544, 4125097984)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1012015104, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1145060864, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1278106624, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1411152384, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1544198144, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1677243904, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1810289664, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1943335424, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2076381184, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2209426944, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2342472704, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2475518464, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2608564224, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2741609984, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(2874655744, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3007701504, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3140747264, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3273793024, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3406838784, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(3539884544, 4125097984)
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:andy:MEMORY after X, Y, T to device	(1012015104, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1145060864, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1278106624, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1411152384, 4125097984)
# INFO:andy:MEMORY after X, Y, T to device	(1544198144, 4125097984)

# %%
winsound.Beep(500, 500)
winsound.Beep(500, 500)
winsound.Beep(500, 500)

# %%
import seaborn as sns
import numpy as np

sns.lineplot(torch.tensor(np.array(hist)).view(-1))
torch.tensor(np.array(hist)).mean()
# Out:
# tensor(15.3424)

# %%
torch.tensor(np.array(hist)).view(-1)
# Out:
# tensor([ 8.5205, 24.3194, 11.3234, 13.0319, 47.9583, 13.3369, 11.5042, 19.1295,
#          5.5710, 19.2996,  4.8228, 19.0603, 17.4291,  5.1104, 10.3782, 21.4693,
#          8.3507, 15.8129,  5.8360, 24.5842])

# %% [markdown]
# # Summary
#
# Performance of self-made embedder is a bit better compared to the pretrained embedder. Might work better if self-made embedder is also pretrained
#
# ### Next goals
# - train embedder with an autoencoder setup

# %% [markdown]
# # Trial

# %%
model = fitter.model

# %%
sample = next(enumerate(dloader))
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1

# %%
slices, masks, target, case = sample[1][1]

# %%
masks[target]
# Out:
# tensor([[[0., 0., 0., 0.]]], dtype=torch.float64)

# %%
num_slices = slices.shape[0]
num_slices
# Out:
# 35

# %%
x = slices.squeeze(1).float().to(device)
T = masks.squeeze(1).float().to(device)

# %%
y = model(x, target)

# %%
fitter.loss(y, T[target])
# Out:
# tensor(0.0359, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)

# %%
y
# Out:
# tensor([[-0.2505,  0.4688, -0.0679,  0.0022]], device='cuda:0',
#        grad_fn=<EluBackward0>)
