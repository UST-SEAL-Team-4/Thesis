# %%
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform
from project.utils import collatev2
import winsound
from project.utils import compute_statistics
from project.evaluation import isa_rpn_metric, isa_vit_metric, Tracker

# %%
vit_tk = Tracker()

# %% [markdown]
# ### Monitoring and CUDA Setup

# %%
import logging
from datetime import datetime as dtt
import os

path = 'logs'
os.makedirs(path, exist_ok=True)
os.makedirs('history', exist_ok=True)
rn = dtt.now()
dte = rn.strftime('%b_%d_%Y_%H%M%S')

logger = logging.getLogger('kess')
fh = logging.FileHandler(f'logs/rpn_vit_{dte}.log')
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)

logger.setLevel(logging.DEBUG)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)

logger.addHandler(fh)

dte
# Out:
# 'Nov_21_2024_121712'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
vit_tk.date = rn
vit_tk.logfile = f'rpn_vit_{dte}.log'
vit_tk.device = device

# %% [markdown]
# ### Config for RPN and ViT Fitter

# %%
from project.model import ISAVIT, Feeder

# %%
image_size = 300
patch_size = 32

# %%
vit_config = {
    'model': ISAVIT(
        d_model=512,
        patch_size=patch_size,
        dim_ff=1600,
        global_context=True,
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 10,
    'loss': nn.BCEWithLogitsLoss(),
    'lr': 0.0001
}
# Out:
# d:\Programming Files\Python\Lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
vit_tk.model = 'ViT'
vit_tk.model_hyperparams = vit_config['model'].config
vit_tk.optimizer = f"{vit_config['optimizer']}"
vit_tk.epochs = vit_config['epochs']
vit_tk.loss = f"{vit_config['loss']}"
vit_tk.lr = vit_config['lr']

# %% [markdown]
# ### Dataset Loading

# %%
data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 9)

# %%
data = data.query('has_microbleed_slice == 1').reset_index(drop=True)
data
# Out:
#                                                    mri  \
# 0    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 1    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 2    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 3    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 4    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# ..                                                 ...
# 359  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 360  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 361  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 362  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 363  d:\Github\Thesis and ML Project\Dataset\VALDO_...
#
#                                                  masks  \
# 0    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 1    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 2    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 3    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 4    d:\Github\Thesis and ML Project\Dataset\VALDO_...
# ..                                                 ...
# 359  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 360  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 361  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 362  d:\Github\Thesis and ML Project\Dataset\VALDO_...
# 363  d:\Github\Thesis and ML Project\Dataset\VALDO_...
#
#                                               stripped  target  \
# 0    d:\Github\Thesis and ML Project\Dataset\VALDO_...       8
# 1    d:\Github\Thesis and ML Project\Dataset\VALDO_...       9
# 2    d:\Github\Thesis and ML Project\Dataset\VALDO_...      11
# 3    d:\Github\Thesis and ML Project\Dataset\VALDO_...      12
# 4    d:\Github\Thesis and ML Project\Dataset\VALDO_...      15
# ..                                                 ...     ...
# 359  d:\Github\Thesis and ML Project\Dataset\VALDO_...      25
# 360  d:\Github\Thesis and ML Project\Dataset\VALDO_...      26
# 361  d:\Github\Thesis and ML Project\Dataset\VALDO_...      24
# 362  d:\Github\Thesis and ML Project\Dataset\VALDO_...      25
# 363  d:\Github\Thesis and ML Project\Dataset\VALDO_...      20
#
#      has_microbleed_case  has_microbleed_slice  cohort   max_value  slices
# 0                      1                     1       1  928.405273      35
# 1                      1                     1       1  928.405273      35
# 2                      1                     1       1  928.405273      35
# 3                      1                     1       1  928.405273      35
# 4                      1                     1       1  928.405273      35
# ..                   ...                   ...     ...         ...     ...
# 359                    1                     1       3  241.000000      36
# 360                    1                     1       3  241.000000      36
# 361                    1                     1       3  448.000000      39
# 362                    1                     1       3  448.000000      39
# 363                    1                     1       3  253.000000      39
#
# [364 rows x 9 columns]

# %%
vit_tk.only_cmb_slices = True

# %%
def make_feedset(
        data,
        target_shape=(300, 300),
        rpn_mode=True,
        logger=None
    ):
    s = f'Creating feedset\n'
    paths = data.stripped.unique().tolist()
    s += f'Total Unique MRI Samples in data_train: {len(paths)}\n'
    
    global_min, global_max = compute_statistics(paths)
    s += f'GLOBAL MIN & MAX {global_min, global_max}\n'
    global_min, global_max = compute_statistics(paths)
    
    feedset_transform = NiftiToTensorTransform(
        target_shape=target_shape,
        rpn_mode=rpn_mode,
        normalization=(global_min, global_max)
    )
    feedset = VALDODataset(
    cases=data.stripped,
    masks=data.masks,
    target=data.target,
    transform=feedset_transform
    )
    print(s)
    return feedset

# %%
feedset = make_feedset(
    data=data,
    rpn_mode=True,
    target_shape=(300, 300)
)
# Out:
# Creating feedset
# Total Unique MRI Samples in data_train: 50
# GLOBAL MIN & MAX (0.0, 87519.8515625)

# %% [markdown]
# ### Preprocessing and Train-Test Split Function

# %%
from sklearn.model_selection import train_test_split

def make_loaders(data,
                 cohort,
                 test_size=0.2,
                 random_state=12,
                 target_shape=(300, 300),
                 rpn_mode=True,
                 logger=None,
                ):
    
    if cohort == 1:
        vit_tk.cohort1 = True
    if cohort == 2:
        vit_tk.cohort2 = True
    if cohort == 3:
        vit_tk.cohort3 = True

    vit_tk.test_size = test_size
    vit_tk.target_shape = target_shape
    data = data[data.cohort == cohort]
    
    s = f'Creating loaders for Cohort {cohort}\n'

    data_train, data_test = train_test_split(
        data,
        test_size=test_size,
        random_state=random_state
    )

    s += f'TRAIN & TEST: {data_train.shape, data_test.shape}\n'

    paths = data_train.stripped.unique().tolist()
    s += f'Total Unique MRI Samples in data_train: {len(paths)}\n'
    
    global_min, global_max = compute_statistics(paths)
    s += f'GLOBAL MIN & MAX {global_min, global_max}\n'

    transform = NiftiToTensorTransform(
        target_shape=target_shape,
        rpn_mode=rpn_mode,
        normalization=(global_min, global_max)
    )

    train_set = VALDODataset(
        cases=data_train.stripped.tolist(),
        masks=data_train.masks.tolist(),
        target=data_train.target.tolist(),
        transform=transform
    )
    val_set = VALDODataset(
        cases=data_test.stripped.tolist(),
        masks=data_test.masks.tolist(),
        target=data_test.target.tolist(),
        transform=transform
    )

    if logger != None:
        logger.info(s)
    else:
        print(s)
    
    return train_set, val_set

# %%
from project import Fitter
from project.preprocessing import get_transform

# %%
resize = get_transform(
    height=patch_size,
    width=patch_size,
    p=1.0,
    rpn_mode=False
)

# %%
import torch

# %%
feeder = Feeder(resize)

# %% [markdown]
# ### ViT Fitter

# %%
from project import Fitter

class ViTFitter(Fitter):
    
    def fit(self, train_loader, val_loader):
        train_history = []
        val_history = []
        train_metric_history = []
        val_metric_history = []
        for epoch in range(self.epochs):
            self.log(f'EPOCH {epoch} ==============================')
            train_loss, train_metric = self.train_one_epoch(train_loader)
            val_loss, val_metric = self.validation(val_loader)
            train_history.append(train_loss)
            val_history.append(val_loss)
            train_metric_history.append(train_metric)
            val_metric_history.append(val_metric)
        return train_history, val_history, train_metric_history, val_metric_history

    def train_one_epoch(self, train_loader):
        self.model.train()
        loss_history = []
        evaluation_metric = {
            'dice_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': [],
            'fpr': []
        }
        counter = 0
        for batch in train_loader:
            Y = []
            T = []
            for slices, masks, target, case in batch:
                slices = slices.squeeze(1).float().to(self.device)
                masks = masks.float().to(self.device)

                regions = feedset.locate_case_by_mri(case)
                bboxes = regions[1].view(regions[1].shape[0], -1)
                bbox = bboxes[target].int().tolist()
                
                x = feeder(slices, bbox, 32)
                t = feeder(masks, bbox, 32)

                x = x.flatten(2).float().to(self.device)
                t = t.flatten(2).float().to(self.device)
                # self.log(f'XT SHAPES: {x.shape}, {t.shape}')
                
                y = self.model(x, target)
                
                # print('Prediction:', (y.sigmoid() >= 0.5).int().unique())
                # print('Truth:', (t[target] >= 0).int().unique())

                dice_score, precision_score, recall_score, f1_score, fpr = isa_vit_metric((y.sigmoid().squeeze().detach().cpu().numpy() >= 0.5), (t[target].squeeze().detach().cpu().numpy() > 0))

                evaluation_metric['dice_score'].append(dice_score)
                evaluation_metric['precision_score'].append(precision_score)
                evaluation_metric['recall_score'].append(recall_score)
                evaluation_metric['f1_score'].append(f1_score)
                evaluation_metric['fpr'].append(fpr)
                # self.log(f'EVAL METS: {dice_score, precision_score, recall_score, f1_score, fpr}')

                Y.append(y)
                T.append(t[target])
            
            losses = self.loss(torch.stack(Y), torch.stack(T))
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += 1
            self.log(f'Batch:\t{counter}/{len(train_loader)}')
            self.log(f'Batch samples:\t{len(batch)}')
            self.log(f'Current error:\t{losses}\n')
            
            loss_history.append(losses.detach().cpu().numpy())
        
        self.log(f'\nTraining Evaluation Metric:')
        self.log(f"Avg Dice: {sum(evaluation_metric['dice_score']) / len(evaluation_metric['dice_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        self.log(f"Avg FPR: {sum(evaluation_metric['fpr']) / len(evaluation_metric['fpr'])}\n")
        return loss_history, evaluation_metric
    
    def validation(self, val_loader):
        self.model.eval()
        loss_history = []
        evaluation_metric = {
            'dice_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': [],
            'fpr': []
        }
        with torch.inference_mode():
            for batch in val_loader:
                Y = []
                T = []
                for slices, masks, target, case in batch:
                    slices = slices.squeeze(1).float().to(self.device)
                    masks = masks.float().to(self.device)
                    regions = feedset.locate_case_by_mri(case)
                    bboxes = regions[1].view(regions[1].shape[0], -1)
                    bbox = bboxes[target].int().tolist()
                
                    x = feeder(slices, bbox, 32)
                    t = feeder(masks, bbox, 32)
                    x = x.flatten(2).float().to(self.device)
                    t = t.flatten(2).float().to(self.device)
                    y = self.model(x, target)

                    dice_score, precision_score, recall_score, f1_score, fpr = isa_vit_metric((y.sigmoid().squeeze().detach().cpu().numpy() >= 0.5), (t[target].squeeze().detach().cpu().numpy() > 0))
                    evaluation_metric['dice_score'].append(dice_score)
                    evaluation_metric['precision_score'].append(precision_score)
                    evaluation_metric['recall_score'].append(recall_score)
                    evaluation_metric['f1_score'].append(f1_score)
                    evaluation_metric['fpr'].append(fpr)
                    Y.append(y)
                    T.append(t[target])
                
                losses = self.loss(torch.stack(Y), torch.stack(T))
                loss_history.append(losses.cpu().numpy())
        
        self.log(f'\nValidations Evaluation Metric:')
        self.log(f"Avg Dice: {sum(evaluation_metric['dice_score']) / len(evaluation_metric['dice_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        self.log(f"Avg FPR: {sum(evaluation_metric['fpr']) / len(evaluation_metric['fpr'])}\n")
        return loss_history, evaluation_metric

# %% [markdown]
# ### Train-Test Split

# %%
vit_t1, vit_v1 = make_loaders(
    data=data,
    cohort=1,
    rpn_mode=False
)

vit_t3, vit_v3 = make_loaders(
    data=data,
    cohort=3,
    rpn_mode=False
)
# Out:
# Creating loaders for Cohort 1
# TRAIN & TEST: ((36, 9), (9, 9))
# Total Unique MRI Samples in data_train: 8
# GLOBAL MIN & MAX (0.0, 1417.92822265625)
#
# Creating loaders for Cohort 3
# TRAIN & TEST: ((37, 9), (10, 9))
# Total Unique MRI Samples in data_train: 26
# GLOBAL MIN & MAX (0.0, 573.0)

# %%
from torch.utils.data import ConcatDataset

vit_train_set = ConcatDataset([vit_t1, vit_t3])
vit_test_set = ConcatDataset([vit_v1, vit_v3])

print(f'ViT Train Set Size: {vit_train_set}')
print(f'ViT Test Set Size: {vit_test_set}')
# Out:
# ViT Train Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x000002CAFAAA5890>
# ViT Test Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x000002CAD9C89390>

# %%
batchs = 20
vit_tk.batch_size = batchs

vit_test_dataloader = DataLoader(
    vit_test_set,
    shuffle=True,
    batch_size=batchs,
    collate_fn=collatev2
)

# %% [markdown]
# ### K-Fold Cross Validation

# %%
from torch.utils.data import Subset
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=45)
kf
# Out:
# KFold(n_splits=5, random_state=45, shuffle=True)

# %%
from project.model import Feeder, GCRPN
from project.preprocessing import NiftiToTensorTransform, get_transform

# %%
vit_test_dice = []
vit_test_precision = []
vit_test_recall = []
vit_test_f1 = []
vit_test_fpr = []

# %%
rpn_fold_metrics = []
vit_fold_metrics = []


fold_dir = f'./fold/{dte}'
os.makedirs(fold_dir, exist_ok=True)

for i, (train_index, val_index) in enumerate(kf.split(vit_train_set)):
    print(f'Fold {i + 1}/{5}')

    os.makedirs(f'{fold_dir}/fold_{i+1}', exist_ok=True)

    # ViT
    
    vit_config['model'] = ISAVIT(**vit_tk.model_hyperparams).to(device)
    
    vit_fitter = ViTFitter(vit_config, logger=logger)
    
    train_subset = Subset(vit_train_set, train_index)
    val_subset = Subset(vit_train_set, val_index)

    vit_tk.batch_size = 2
    
    train_subset_dl = DataLoader(
        train_subset,
        shuffle=True,
        batch_size=vit_tk.batch_size,
        collate_fn=collatev2
    )
    
    val_subset_dl = DataLoader(
        val_subset,
        shuffle=True,
        batch_size=vit_tk.batch_size,
        collate_fn=collatev2
    )
    
    vit_thist, vit_vhist, vit_tmhist, vit_vmhist = vit_fitter.fit(train_subset_dl, val_subset_dl)
    
    vit_fold_metrics.append({
        'fold': i + 1,
        'training_history': vit_thist,
        'validation_history': vit_vhist,
        'training_metrics': vit_tmhist,
        'validation_metrics': vit_vmhist
    })
    
    vit_h, vit_mh = vit_fitter.validation(vit_test_dataloader)
    vit_valmets = pd.DataFrame(vit_mh)
    vit_mets = vit_valmets.mean()
    
    vit_test_dice.append(vit_mets.dice_score)
    vit_test_precision.append(vit_mets.precision_score)
    vit_test_recall.append(vit_mets.recall_score)
    vit_test_f1.append(vit_mets.f1_score)
    vit_test_fpr.append(vit_mets.fpr)
    
    torch.save(vit_fitter.model.state_dict(), f'{fold_dir}/fold_{i+1}/vit_fold{i+1}.pt')
# Out:
# d:\Programming Files\Python\Lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# INFO:kess:EPOCH 0 ==============================
# Fold 1/5
# INFO:kess:Batch:	1/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.7047647833824158
#
# INFO:kess:Batch:	2/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6979032158851624
#
# INFO:kess:Batch:	3/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6892434358596802
#
# INFO:kess:Batch:	4/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6802039742469788
#
# INFO:kess:Batch:	5/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.672012448310852
#
# INFO:kess:Batch:	6/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6582196950912476
#
# INFO:kess:Batch:	7/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6474086046218872
#
# INFO:kess:Batch:	8/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6408723592758179
#
# INFO:kess:Batch:	9/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6257638931274414
#
# INFO:kess:Batch:	10/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6151905059814453
#
# INFO:kess:Batch:	11/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6124322414398193
#
# INFO:kess:Batch:	12/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.6102502346038818
#
# INFO:kess:Batch:	13/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5929690599441528
#
# INFO:kess:Batch:	14/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.586215615272522
#
# INFO:kess:Batch:	15/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5803183913230896
#
# INFO:kess:Batch:	16/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5943520069122314
#
# INFO:kess:Batch:	17/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5507427453994751
#
# INFO:kess:Batch:	18/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5376578569412231
#
# INFO:kess:Batch:	19/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5581142902374268
#
# INFO:kess:Batch:	20/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5310555100440979
#
# INFO:kess:Batch:	21/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5444228649139404
#
# INFO:kess:Batch:	22/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5280112028121948
#
# INFO:kess:Batch:	23/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.5249319076538086
#
# INFO:kess:Batch:	24/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.4922637939453125
#
# INFO:kess:Batch:	25/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.480465829372406
#
# INFO:kess:Batch:	26/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.4951271414756775
#
# INFO:kess:Batch:	27/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.4850861132144928
#
# INFO:kess:Batch:	28/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.4625035524368286
#
# INFO:kess:Batch:	29/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.4935086965560913
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.013766453890309598
# INFO:kess:Avg Precision: 0.00704352315228163
# INFO:kess:Avg Recall: 0.6814244663382595
# INFO:kess:Avg F1: 0.013766453890309598
# INFO:kess:Avg FPR: 0.19475727628864628
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.029144755974389886
# INFO:kess:Avg Precision: 0.015334680122737724
# INFO:kess:Avg Recall: 0.6222222222222221
# INFO:kess:Avg F1: 0.029144755974389893
# INFO:kess:Avg FPR: 0.05503321934279905
#
# INFO:kess:EPOCH 1 ==============================
# INFO:kess:Batch:	1/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.
29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.042027734220027924
#
# INFO:kess:Batch:	26/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.05987165495753288
#
# INFO:kess:Batch:	27/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.08745827525854111
#
# INFO:kess:Batch:	28/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.06753689795732498
#
# INFO:kess:Batch:	29/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.05057240277528763
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.3807471264367816
# INFO:kess:Avg Precision: 0.41379310344827586
# INFO:kess:Avg Recall: 0.3702791461412151
# INFO:kess:Avg F1: 0.3807471264367816
# INFO:kess:Avg FPR: 0.00018623882978996572
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.4414814814814816
# INFO:kess:Avg Precision: 0.6666666666666666
# INFO:kess:Avg Recall: 0.3898148148148148
# INFO:kess:Avg F1: 0.44148148148148153
# INFO:kess:Avg FPR: 0.00032666960622071786
#
# INFO:kess:EPOCH 4 ==============================
# INFO:kess:Batch:	1/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.07446689903736115
#
# INFO:kess:Batch:	2/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.08334065973758698
#
# INFO:kess:Batch:	3/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.0625561773777008
#
# INFO:kess:Batch:	4/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.0523611456155777
#
# INFO:kess:Batch:	5/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.04004540294408798
#
# INFO:kess:Batch:	6/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.030740704387426376
#
# INFO:kess:Batch:	7/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.05637378990650177
#
# INFO:kess:Batch:	8/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.03162716329097748
#
# INFO:kess:Batch:	9/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.050697892904281616
#
# INFO:kess:Batch:	10/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.06812812387943268
#
# INFO:kess:Batch:	11/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.045155756175518036
#
# INFO:kess:Batch:	12/29
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.034406878054142
#
# ...
# INFO:kess:Current error:	0.029694190248847008
#
# INFO:kess:Batch:	15/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.04362637549638748
#
# INFO:kess:Batch:	16/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.025954823940992355
#
# INFO:kess:Batch:	17/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.05066225305199623
#
# INFO:kess:Batch:	18/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.023649778217077255
#
# INFO:kess:Batch:	19/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.020244799554347992
#
# INFO:kess:Batch:	20/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.04175295680761337
#
# INFO:kess:Batch:	21/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.013055332005023956
#
# INFO:kess:Batch:	22/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.0267593152821064
#
# INFO:kess:Batch:	23/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.029148824512958527
#
# INFO:kess:Batch:	24/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.022239435464143753
#
# INFO:kess:Batch:	25/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.021938877180218697
#
# INFO:kess:Batch:	26/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.022906867787241936
#
# INFO:kess:Batch:	27/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.021601326763629913
#
# INFO:kess:Batch:	28/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.015339641831815243
#
# INFO:kess:Batch:	29/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.021402236074209213
#
# INFO:kess:Batch:	30/30
# INFO:kess:Batch samples:	1
# INFO:kess:Current error:	0.04137875512242317
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.30088781275221954
# INFO:kess:Avg Precision: 0.3898305084745763
# INFO:kess:Avg Recall: 0.27636534839924676
# INFO:kess:Avg F1: 0.30088781275221954
# INFO:kess:Avg FPR: 0.00014963428997520538
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.31428571428571433
# INFO:kess:Avg Precision: 0.35714285714285715
# INFO:kess:Avg Recall: 0.30357142857142855
# INFO:kess:Avg F1: 0.31428571428571433
# INFO:kess:Avg FPR: 0.00013998743473883187
#
# INFO:kess:EPOCH 6 ==============================
# INFO:kess:Batch:	1/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.021248899400234222
#
# INFO:kess:Batch:	2/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.024406109005212784
#
# INFO:kess:Batch:	3/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01891113817691803
#
# INFO:kess:Batch:	4/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01928386092185974
#
# INFO:kess:Batch:	5/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.03160890191793442
#
# INFO:kess:Batch:	6/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.010409957729279995
#
# INFO:kess:Batch:	7/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.018884945660829544
#
# INFO:kess:Batch:	8/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01729176938533783
#
# INFO:kess:Batch:	9/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.03721197694540024
#
# INFO:kess:Batch:	10/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01484617404639721
#
# INFO:kess:Batch:	11/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.023566730320453644
#
# INFO:kess:Batch:	12/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.024289555847644806
#
# INFO:kess:Batch:	13/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.014919138513505459
#
# INFO:kess:Batch:	14/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.014408590272068977
#
# INFO:kess:Batch:	15/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.020975351333618164
#
# INFO:kess:Batch:	16/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.023541856557130814
#
# INFO:kess:Batch:	17/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.018724698573350906
#
# INFO:kess:Batch:	18/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.03931280970573425
#
# INFO:kess:Batch:	19/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.022744469344615936
#
# INFO:kess:Batch:	20/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.03827947378158569
#
# INFO:kess:Batch:	21/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.026544982567429543
#
# INFO:kess:Batch:	22/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.028046943247318268
#
# INFO:kess:Batch:	23/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.015818405896425247
#
# INFO:kess:Batch:	24/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.027193740010261536
#
# INFO:kess:Batch:	25/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.05303874611854553
#
# INFO:kess:Batch:	26/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02531600557267666
#
# INFO:kess:Batch:	27/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.020482925698161125
#
# INFO:kess:Batch:	28/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.010470961220562458
#
# INFO:kess:Batch:	29/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.038664959371089935
#
# INFO:kess:Batch:	30/30
# INFO:kess:Batch samples:	1
# INFO:kess:Current error:	0.03346346318721771
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.20521926284638145
# INFO:kess:Avg Precision: 0.288135593220339
# INFO:kess:Avg Recall: 0.1885593220338983
# INFO:kess:Avg F1: 0.20521926284638145
# INFO:kess:Avg FPR: 0.00011664675895364762
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.31428571428571433
# INFO:kess:Avg Precision: 0.35714285714285715
# INFO:kess:Avg Recall: 0.30357142857142855
# INFO:kess:Avg F1: 0.31428571428571433
# INFO:kess:Avg FPR: 0.0
#
# INFO:kess:EPOCH 7 ==============================
# INFO:kess:Batch:	1/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.023347727954387665
#
# INFO:kess:Batch:	2/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.014611524529755116
#
# INFO:kess:Batch:	3/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.022529128938913345
#
# INFO:kess:Batch:	4/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.027654830366373062
#
# INFO:kess:Batch:	5/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01854986697435379
#
# INFO:kess:Batch:	6/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.021382149308919907
#
# INFO:kess:Batch:	7/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.0255978275090456
#
# INFO:kess:Batch:	8/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02965492755174637
#
# INFO:kess:Batch:	9/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.0211821049451828
#
# INFO:kess:Batch:	10/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.018126023933291435
#
# INFO:kess:Batch:	11/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.027370233088731766
#
# INFO:kess:Batch:	12/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02680104225873947
#
# INFO:kess:Batch:	13/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.013432714156806469
#
# INFO:kess:Batch:	14/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.015426522120833397
#
# INFO:kess:Batch:	15/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.018126387149095535
#
# INFO:kess:Batch:	16/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.028070196509361267
#
# INFO:kess:Batch:	17/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.023492075502872467
#
# INFO:kess:Batch:	18/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.012967107817530632
#
# INFO:kess:Batch:	19/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.023020360618829727
#
# INFO:kess:Batch:	20/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.021163487806916237
#
# INFO:kess:Batch:	21/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.018556617200374603
#
# INFO:kess:Batch:	22/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.012519226409494877
#
# INFO:kess:Batch:	23/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.010599764063954353
#
# INFO:kess:Batch:	24/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.030399952083826065
#
# INFO:kess:Batch:	25/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.020992521196603775
#
# INFO:kess:Batch:	26/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02535000629723072
#
# INFO:kess:Batch:	27/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.031111612915992737
#
# INFO:kess:Batch:	28/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.010144118219614029
#
# INFO:kess:Batch:	29/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.030704107135534286
#
# INFO:kess:Batch:	30/30
# INFO:kess:Batch samples:	1
# INFO:kess:Current error:	0.009334644302725792
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.35060532687651336
# INFO:kess:Avg Precision: 0.4406779661016949
# INFO:kess:Avg Recall: 0.32297551789077217
# INFO:kess:Avg F1: 0.35060532687651336
# INFO:kess:Avg FPR: 0.00016633490169632104
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.07142857142857142
# INFO:kess:Avg Precision: 0.07142857142857142
# INFO:kess:Avg Recall: 0.07142857142857142
# INFO:kess:Avg F1: 0.07142857142857142
# INFO:kess:Avg FPR: 0.0
#
# INFO:kess:EPOCH 8 ==============================
# INFO:kess:Batch:	1/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02196725830435753
#
# INFO:kess:Batch:	2/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.016784194856882095
#
# INFO:kess:Batch:	3/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.013108404353260994
#
# INFO:kess:Batch:	4/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02087072655558586
#
# INFO:kess:Batch:	5/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.018934432417154312
#
# INFO:kess:Batch:	6/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01942773349583149
#
# INFO:kess:Batch:	7/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.007357798051089048
#
# INFO:kess:Batch:	8/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.033504851162433624
#
# INFO:kess:Batch:	9/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.011733478866517544
#
# INFO:kess:Batch:	10/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.013661451637744904
#
# INFO:kess:Batch:	11/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.020822621881961823
#
# INFO:kess:Batch:	12/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02281387709081173
#
# INFO:kess:Batch:	13/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.007949156686663628
#
# INFO:kess:Batch:	14/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.013979658484458923
#
# INFO:kess:Batch:	15/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.03028080239892006
#
# INFO:kess:Batch:	16/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.013289561495184898
#
# INFO:kess:Batch:	17/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01623636484146118
#
# INFO:kess:Batch:	18/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.012049764394760132
#
# INFO:kess:Batch:	19/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.027737664058804512
#
# INFO:kess:Batch:	20/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.018437135964632034
#
# INFO:kess:Batch:	21/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.010933063924312592
#
# INFO:kess:Batch:	22/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.017901724204421043
#
# INFO:kess:Batch:	23/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01560819149017334
#
# INFO:kess:Batch:	24/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02724568545818329
#
# INFO:kess:Batch:	25/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.018176376819610596
#
# INFO:kess:Batch:	26/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.028201505541801453
#
# INFO:kess:Batch:	27/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.025520935654640198
#
# INFO:kess:Batch:	28/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.008262693881988525
#
# INFO:kess:Batch:	29/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.012118544429540634
#
# INFO:kess:Batch:	30/30
# INFO:kess:Batch samples:	1
# INFO:kess:Current error:	0.026661217212677002
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.11412429378531073
# INFO:kess:Avg Precision: 0.15254237288135594
# INFO:kess:Avg Recall: 0.10546139359698682
# INFO:kess:Avg F1: 0.11412429378531073
# INFO:kess:Avg FPR: 6.64347785838648e-05
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.07142857142857142
# INFO:kess:Avg Precision: 0.07142857142857142
# INFO:kess:Avg Recall: 0.07142857142857142
# INFO:kess:Avg F1: 0.07142857142857142
# INFO:kess:Avg FPR: 0.0
#
# INFO:kess:EPOCH 9 ==============================
# INFO:kess:Batch:	1/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.015856850892305374
#
# INFO:kess:Batch:	2/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.024152003228664398
#
# INFO:kess:Batch:	3/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.007510925643146038
#
# INFO:kess:Batch:	4/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01766612008213997
#
# INFO:kess:Batch:	5/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.010903708636760712
#
# INFO:kess:Batch:	6/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.028769738972187042
#
# INFO:kess:Batch:	7/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.012470871210098267
#
# INFO:kess:Batch:	8/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.028519127517938614
#
# INFO:kess:Batch:	9/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.023346319794654846
#
# INFO:kess:Batch:	10/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.010124241933226585
#
# INFO:kess:Batch:	11/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.03738982230424881
#
# INFO:kess:Batch:	12/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.008060852065682411
#
# INFO:kess:Batch:	13/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.010607009753584862
#
# INFO:kess:Batch:	14/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.006930188275873661
#
# INFO:kess:Batch:	15/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.0108905378729105
#
# INFO:kess:Batch:	16/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01154470257461071
#
# INFO:kess:Batch:	17/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.014108920469880104
#
# INFO:kess:Batch:	18/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.016442477703094482
#
# INFO:kess:Batch:	19/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.022192317992448807
#
# INFO:kess:Batch:	20/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01689578779041767
#
# INFO:kess:Batch:	21/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.01108535099774599
#
# INFO:kess:Batch:	22/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.016441892832517624
#
# INFO:kess:Batch:	23/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.013559848070144653
#
# INFO:kess:Batch:	24/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.017459046095609665
#
# INFO:kess:Batch:	25/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.027209578081965446
#
# INFO:kess:Batch:	26/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.02108774147927761
#
# INFO:kess:Batch:	27/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.015569580718874931
#
# INFO:kess:Batch:	28/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.0036931918002665043
#
# INFO:kess:Batch:	29/30
# INFO:kess:Batch samples:	2
# INFO:kess:Current error:	0.023985739797353745
#
# INFO:kess:Batch:	30/30
# INFO:kess:Batch samples:	1
# INFO:kess:Current error:	0.009778901003301144
#
# INFO:kess:
# Training Evaluation Metric:
# INFO:kess:Avg Dice: 0.16666666666666666
# INFO:kess:Avg Precision: 0.1864406779661017
# INFO:kess:Avg Recall: 0.1581920903954802
# INFO:kess:Avg F1: 0.16666666666666666
# INFO:kess:Avg FPR: 8.321530727693172e-05
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.14285714285714285
# INFO:kess:Avg Precision: 0.14285714285714285
# INFO:kess:Avg Recall: 0.14285714285714285
# INFO:kess:Avg F1: 0.14285714285714285
# INFO:kess:Avg FPR: 0.0
#
# INFO:kess:
# Validations Evaluation Metric:
# INFO:kess:Avg Dice: 0.15789473684210525
# INFO:kess:Avg Precision: 0.15789473684210525
# INFO:kess:Avg Recall: 0.15789473684210525
# INFO:kess:Avg F1: 0.15789473684210525
# INFO:kess:Avg FPR: 0.0

# %%
import winsound

winsound.Beep(500, 500)
winsound.Beep(500, 500)
winsound.Beep(500, 500)

# %% [markdown]
# ### Metrics Visualization

# %% [markdown]
# `rpn_fold_metrics[i]`
#
# - represents each fold
#
# `rpn_fold_metrics[1].keys()`
#
# - 'fold', 'training_history', 'validation_history', 'training_metrics', 'validation_metrics'
#
# `rpn_fold_metrics[1]['training_metrics'][i]`
#
# - represents each epoch
#
# `rpn_fold_metrics[1]['training_metrics'][1].keys()`
#
# - 'iou_score', 'precision_score', 'recall_score', 'f1_score'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_metric_history(fold_metrics, metric, title=None):
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))

    for fold in range(len(vit_fold_metrics)):
        train = []
        test = []
        ax=axes[fold]
        
        for epoch in range(len(fold_metrics[fold]['training_metrics'])):
            th = np.array(fold_metrics[fold]['training_metrics'][epoch][metric]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_metrics'][epoch][metric]).mean()
            test.append(vh)
            
        sns.lineplot(x=range(1, len(train)+1), y=train, label=f'Training {metric}', ax=ax)
        sns.lineplot(x=range(1, len(test)+1), y=test, label=f'Validation {metric}', ax=ax)
    

        ax.set_title(f'{title}Training and Validation {metric}: Fold {fold+1}')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric)
        ax.legend()
        
    plt.tight_layout()  
    plt.show()

# %%
vit_metrics = ['dice_score', 'precision_score', 'recall_score', 'f1_score', 'fpr']

for metric in vit_metrics:
    plot_metric_history(vit_fold_metrics, metric, 'ViT ')

# %% [markdown]
# ### Loss History Visualization

# %%
def plot_loss_history(fold_metrics, title=None):
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))

    for fold in range(5):
        train = []
        test = []
        ax=axes[fold]
        
        for epoch in range(len(fold_metrics[fold]['training_history'])):
            th = np.array(fold_metrics[fold]['training_history'][epoch]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_history'][epoch]).mean()
            test.append(vh)
        
        sns.lineplot(x=range(1, len(train)+1), y=train, label='Training history', ax=ax)
        sns.lineplot(x=range(1, len(test)+1), y=test, label='Validation history', ax=ax)
        
        ax.set_title(f'{title}Training and Validation History: Fold {fold+1}')
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Loss')
        ax.legend()
    
    plt.tight_layout()  
    plt.show()

# %%
plot_loss_history(vit_fold_metrics, 'ViT ')

# %% [markdown]
# ### Evaluate Test Set

# %% [markdown]
# #### ViT

# %%
df_vit_metrics = pd.DataFrame(columns=['fold', 'dice', 'precision', 'recall', 'f1', 'fpr'])
df_vit_metrics
# Out:
# Empty DataFrame
# Columns: [fold, dice, precision, recall, f1, fpr]
# Index: []

# %%
df_vit_metrics['fold'] = [1, 2, 3, 4, 5]
df_vit_metrics['dice'] = vit_test_dice
df_vit_metrics['precision'] = vit_test_precision
df_vit_metrics['recall'] = vit_test_recall
df_vit_metrics['f1'] = vit_test_f1
df_vit_metrics['fpr'] = vit_test_fpr

# %%
vit_tk.dice = df_vit_metrics.dice
vit_tk.precision = df_vit_metrics.precision
vit_tk.recall = df_vit_metrics.recall
vit_tk.f1 = df_vit_metrics.f1
vit_tk.fpr = df_vit_metrics.fpr

# %%
df_vit_metrics
# Out:
#    fold      dice  precision    recall        f1       fpr
# 0     1  0.605263   0.736842  0.554386  0.605263  0.000155
# 1     2  0.359649   0.421053  0.333333  0.359649  0.000000
# 2     3  0.626316   0.789474  0.567544  0.626316  0.000207
# 3     4  0.254386   0.315789  0.228070  0.254386  0.000000
# 4     5  0.157895   0.157895  0.157895  0.157895  0.000000

# %%
# vit_iou_score = np.array(vit_test_iou).mean()
vit_dice_score = np.array(vit_test_dice).mean()
vit_precision_score = np.array(vit_test_precision).mean()
vit_recall_score = np.array(vit_test_recall).mean()
vit_f1_score = np.array(vit_test_f1).mean()
vit_fpr_score = np.array(vit_test_fpr).mean()

print('ViT Test Set Performance Metrics')
print(f'Average Dice Score: {vit_dice_score} ')
print(f'Average Precision: {vit_precision_score} ')
print(f'Average Recall: {vit_recall_score} ')
print(f'Average F1 Score: {vit_f1_score} ')
print(f'Average FPR: {vit_fpr_score} ')
# Out:
# ViT Test Set Performance Metrics
# Average Dice Score: 0.4007017543859649
# Average Precision: 0.4842105263157895
# Average Recall: 0.3682456140350877
# Average F1 Score: 0.4007017543859649
# Average FPR: 7.252445089479454e-05

# %%
df_vit_metrics.to_csv(f'{fold_dir}/vit_metrics.csv')

# %% [markdown]
# ### Sample

# %% [markdown]
# #### ViT

# %%
vit_sample = next(enumerate(vit_test_dataloader))
vit_slices, vit_masks, vit_target, vit_case = vit_sample[1][0]

# %%
vit_slices = vit_slices.squeeze(1).float().to(device)
vit_masks = vit_masks.float().to(device)

# %%
regions = feedset.locate_case_by_mri(vit_case)
bboxes = regions[1].view(regions[1].shape[0], -1)
bbox = bboxes[vit_target].int().tolist()
                
vit_x = feeder(vit_slices, bbox, 16)
vit_t = feeder(vit_masks, bbox, 16)

# %%
f, a = plt.subplots(1, 2, figsize=(10, 4))

f.tight_layout()
ax1 = a.flat[0]
ax2 = a.flat[1]
ax1.set_title('MRI Slice Crop')
ax2.set_title('Mask Slice Crop')
sns.heatmap(vit_x[vit_target].squeeze(), ax=ax1)
sns.heatmap(vit_t[vit_target].squeeze(), ax=ax2)
# Out:
# <Axes: title={'center': 'Mask Slice Crop'}>

# %%
vit_y = vit_fitter.model(vit_x.flatten(2).to(device), vit_target)
vit_y = vit_y.view(patch_size, patch_size)

# %%
f, a = plt.subplots(1, 2, figsize=(10, 4))

f.tight_layout()
ax1 = a.flat[0]
ax2 = a.flat[1]
ax1.set_title('Mask Prediction')
ax2.set_title('Mask Truth')
sns.heatmap((vit_y > 0.3).detach().cpu(), ax=ax1, vmax=1)
sns.heatmap(vit_t[vit_target].squeeze(), ax=ax2, vmax=1)
# Out:
# <Axes: title={'center': 'Mask Truth'}>

# %% [markdown]
# # Log Progress

# %%
vit_tk.notes = '''
no global context
'''

# %%
vit_tk()
# Out:
#                            model loaded_weights stage1_weights uses_resnet  \
# date
# 2024-11-21 12:17:12.070289   ViT           None           None        None
#
#                             only_cmb_slices  cohort1  cohort2  cohort3  \
# date
# 2024-11-21 12:17:12.070289             True     True    False     True
#
#                                                   optimizer  epochs  ...  \
# date                                                                 ...
# 2024-11-21 12:17:12.070289  <class 'torch.optim.adam.Adam'>      10  ...
#
#                                                                        recall  \
# date
# 2024-11-21 12:17:12.070289  0    0.554386
# 1    0.333333
# 2    0.567544
# 3   ...
#
#                                                                            f1  \
# date
# 2024-11-21 12:17:12.070289  0    0.605263
# 1    0.359649
# 2    0.626316
# 3   ...
#
#                                                                           fpr  \
# date
# 2024-11-21 12:17:12.070289  0    0.000155
# 1    0.000000
# 2    0.000207
# 3   ...
#
#                             saved_weights saved_thist saved_vhist  \
# date
# 2024-11-21 12:17:12.070289           None        None        None
#
#                                                             model_hyperparams  \
# date
# 2024-11-21 12:17:12.070289  {'d_model': 512, 'patch_size': 32, 'dim_ff': 1...
#
#                                                    logfile device  \
# date
# 2024-11-21 12:17:12.070289  rpn_vit_Nov_21_2024_121712.log   cuda
#
#                                             notes
# date
# 2024-11-21 12:17:12.070289  \nno global context\n
#
# [1 rows x 28 columns]

# %%
if os.path.exists('history/runs.csv'):
    print('Merging to old df')
    prev_df = pd.read_csv('history/runs.csv', index_col='date')
    merged = pd.concat([prev_df, vit_tk()])
    merged.to_csv('history/runs.csv')
else:
    print('Making new csv file')
    vit_tk().to_csv('history/runs.csv')
# Out:
# Merging to old df
# C:\Users\JOSHUA KYLE\AppData\Local\Temp\ipykernel_16724\3886131270.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat([prev_df, vit_tk()])
