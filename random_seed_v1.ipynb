# %% [markdown]
# Gawa ka ng notebook WITH RANDOM SEED na tapos mag train test split ka muna and gamitin mo compute statistics for each cohort para makuha natin yung global max and global min kasa cohort

# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt
from project.dataset import Dataset, VALDODataset
from project.preprocessing import NiftiToTensorTransform
from project.utils import compute_statistics
import numpy as np
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.20 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
ds = Dataset()

data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 5)

# %%
np.random.seed(42)
random_numbers = np.random.rand(5)
random_numbers
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848, 0.15601864])

# %% [markdown]
# # Ch1

# %%
ch1 = ds.load_raw_mri(1)
ch1_data = data[data.mri.isin(ch1)]
ch1_data.shape
# Out:
# (385, 5)

# %%
ch1_cases = ch1_data.mri
ch1_masks = ch1_data.masks
ch1_target = ch1_data.target

# %%
ch1_min, ch1_max = compute_statistics(ch1_cases)
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# ...

# %%
ch1_min
# Out:
# 0.0

# %%
ch1_max
# Out:
# 1417.92822265625

# %% [markdown]
# # Ch2

# %%
ch2 = ds.load_raw_mri(2)
ch2_data = data[data.mri.isin(ch2)]
ch2_data.shape
# Out:
# (6528, 5)

# %%
ch2_cases = ch2_data.mri
ch2_masks = ch2_data.masks
ch2_target = ch2_data.target

# %%
ch2_min, ch2_max = compute_statistics(ch2_cases)
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# ...

# %%
ch2_min
# Out:
# 0.0

# %%
ch2_max
# Out:
# 88731.5390625

# %% [markdown]
# # Ch3

# %%
ch3 = ds.load_raw_mri(3)
ch3_data = data[data.mri.isin(ch3)]
ch3_data.shape
# Out:
# (1073, 5)

# %%
ch3_cases = ch3_data.mri
ch3_masks = ch3_data.masks
ch3_target = ch3_data.target

# %%
ch3_global_min, ch3_global_max = compute_statistics(ch3_cases)

# %%
ch3_global_min
# Out:
# 0.0

# %%
ch3_global_max
# Out:
# 664.0
