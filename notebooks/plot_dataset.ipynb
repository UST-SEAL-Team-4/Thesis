# %%
from project.utils import plot_all_slices, plot_mri_slice
from project.dataset import Dataset
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.13 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations

# %%
ds = Dataset()

# %%
cohort1_mris = ds.load_raw_mri(cohort_num=1)
cohort2_mris = ds.load_raw_mri(cohort_num=2)
cohort3_mris = ds.load_raw_mri(cohort_num=3)
all_raw_mris = ds.load_raw_mri()

# %%
cohort1_masks = ds.load_cmb_masks(cohort_num=1)
cohort2_masks = ds.load_cmb_masks(cohort_num=2)
cohort3_masks = ds.load_cmb_masks(cohort_num=3)
all_masks = ds.load_cmb_masks()

# %%
cohort1_skullstrip = ds.load_skullstripped_mri(cohort_num=1)
cohort2_skullstrip = ds.load_skullstripped_mri(cohort_num=2)
cohort3_skullstrip = ds.load_skullstripped_mri(cohort_num=3)
all_skullstrip = ds.load_skullstripped_mri()

# %% [markdown]
# ## Plot a slice for raw MRI dataset

# %%
plot_mri_slice(cohort1_mris[0], get_middle_slice=True)
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1

# %%
plot_mri_slice(cohort2_mris[0], get_middle_slice=True)
# Out:
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# INFO:nibabel.global:pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1

# %%
plot_mri_slice(cohort3_mris[0], get_middle_slice=True)

# %%
plot_mri_slice(all_raw_mris[71], get_middle_slice=True)

# %% [markdown]
# ## Plot a slice for skullstripped MRI dataset

# %%
plot_mri_slice(cohort1_skullstrip[0], get_middle_slice=True)

# %%
plot_mri_slice(cohort2_skullstrip[0], get_middle_slice=True)

# %%
plot_mri_slice(cohort3_skullstrip[0], get_middle_slice=True)

# %%
plot_mri_slice(all_skullstrip[71], get_middle_slice=True)

# %% [markdown]
# ## Plot all slices of CMB masks

# %%
plot_all_slices(cohort1_masks[0])

# %%
plot_all_slices(cohort2_masks[0])

# %%
plot_all_slices(cohort3_masks[0])

# %%
plot_all_slices(all_masks[71])
