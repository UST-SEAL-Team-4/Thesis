# %% [markdown]
# # Metrics for ISAViT

# %%
from torch import Tensor
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform, get_transform
from project.utils import collatev2, compute_statistics
import winsound
from project.model import ISAVIT
from torchvision.models import resnet18, ResNet18_Weights
from project.utils import memcheck
from project.evaluation import isa_vit_metric

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
image_size = 300
patch_size = 16

config = {
    'model': ISAVIT(
        d_model=512,
        patch_size=patch_size,
        dim_ff=1600
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 10,
    'loss': nn.BCEWithLogitsLoss(),
    # 'loss': nn.MSELoss(),
    'lr': 0.0001
}

# %% [markdown]
# ### Load dataset

# %%
ds = Dataset()

data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 7)

# %%
data = data.query('has_microbleed_slice == 1').reset_index(drop=True)
data
# Out:
#                                                    mri  \
# 0    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# 1    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# 2    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# 3    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# 4    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# ..                                                 ...
# 359  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# 360  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# 361  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# 362  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
# 363  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...
#
#                                                  masks  target  \
# 0    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...       8
# 1    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...       9
# 2    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...      11
# 3    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...      12
# 4    c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...      15
# ..                                                 ...     ...
# 359  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...      25
# 360  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...      26
# 361  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...      24
# 362  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...      25
# 363  c:\Users\Lex Zedrick Lorenzo\Documents\GitHub\...      20
#
#      has_microbleed_case  has_microbleed_slice  cohort   max_value
# 0                      1                     1       1  928.405273
# 1                      1                     1       1  928.405273
# 2                      1                     1       1  928.405273
# 3                      1                     1       1  928.405273
# 4                      1                     1       1  928.405273
# ..                   ...                   ...     ...         ...
# 359                    1                     1       3  241.000000
# 360                    1                     1       3  241.000000
# 361                    1                     1       3  448.000000
# 362                    1                     1       3  448.000000
# 363                    1                     1       3  253.000000
#
# [364 rows x 7 columns]

# %% [markdown]
# ### `DataLoader` Generator

# %%
def iqr(data, col):
    q3 = data[col].quantile(0.75)
    q1 = data[col].quantile(0.25)
    iqr = q3-q1
    new = data[(data[col] < (q3 + 1.5*iqr)) & (data[col] > (q1 - 1.5*iqr))]
    return new

# %%
from sklearn.model_selection import train_test_split

def make_loaders(data,
                 cohort,
                 batch_size,
                 test_size=0.2,
                 random_state=12,
                 target_shape=(300, 300),
                 rpn_mode=True,
                 logger=None
                ):
    data = data[data.cohort == cohort]
    # data = iqr(data, 'max_value')
    
    s = f'Creating loaders for Cohort {cohort}\n'

    data_train, data_test = train_test_split(
        data,
        test_size=test_size,
        random_state=random_state
    )

    s += f'TRAIN & TEST: {data_train.shape, data_test.shape}\n'

    paths = data_train.mri.unique().tolist()
    s += f'Total Unique MRI Samples in data_train: {len(paths)}\n'
    
    global_min, global_max = compute_statistics(paths)
    s += f'GLOBAL MIN & MAX {global_min, global_max}\n'

    transform = NiftiToTensorTransform(
        target_shape=target_shape,
        rpn_mode=rpn_mode,
        normalization=(global_min, global_max)
    )

    train_set = VALDODataset(
        cases=data_train.mri.tolist(),
        masks=data_train.masks.tolist(),
        target=data_train.target.tolist(),
        transform=transform
    )
    val_set = VALDODataset(
        cases=data_test.mri.tolist(),
        masks=data_test.masks.tolist(),
        target=data_test.target.tolist(),
        transform=transform
    )

    train_loader = DataLoader(
        train_set,
        shuffle=True,
        batch_size=batch_size,
        collate_fn=collatev2
    )
    val_loader = DataLoader(
        val_set,
        shuffle=True,
        batch_size=batch_size,
        collate_fn=collatev2
    )

    if logger != None:
        logger.info(s)
    else:
        print(s)
    
    return train_loader, val_loader

# %%
tl, vl = make_loaders(
    data=data,
    cohort=1,
    rpn_mode=False,
    batch_size=1
)
# Out:
# Creating loaders for Cohort 1
# TRAIN & TEST: ((36, 7), (9, 7))
# Total Unique MRI Samples in data_train: 8
# GLOBAL MIN & MAX (0.0, 1417.92822265625)

# %% [markdown]
# ### Create Stage 1 Network

# %%
from project.model import Feeder, RPN, GCRPN

resize = get_transform(
    height=patch_size,
    width=patch_size,
    p=1.0,
    rpn_mode=False
)

feeder = Feeder(resize)
rpn = RPN(
    input_dim=512,
    output_dim=4,
    image_size=image_size,
    nh=4,
)

stone = GCRPN(
    rpn=rpn,
    feeder=feeder,
    image_size=image_size,
    patch_size=patch_size
).to(device)
# Out:
# 324
# c:\Users\Lex Zedrick Lorenzo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
stone.rpn.load_state_dict(torch.load('RPN_test15_weights_Nov_02_2024_192506.pt'))
vit = config['model']

vit.load_state_dict(torch.load('vit_weights_101124203757.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Metrics

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from torchmetrics.functional.segmentation import generalized_dice_score

# %%
sample_tensor = torch.randint(0, 2, (4, 5, 16, 16))
print(sample_tensor.shape)
# Out:
# torch.Size([4, 5, 16, 16])

# %% [markdown]
# Source of the functions: https://medium.com/@nghihuynh_37300/understanding-evaluation-metrics-in-medical-image-segmentation-d289a373a3f
#
# same precision and recall computation from https://labelyourdata.com/articles/object-detection-metrics
#
# Meron din dice na metric from torchmetrics pero same lang naman ng score from the link above

# %%
preds = []
truths = []
cases = []
targets = []
precision_scores = []
recall_scores = []
dice_scores = []
accuracy_scores = []
counter = 0

for batch in enumerate(tl):
    slices, masks, target, case = batch[1][0]
    slices = slices.squeeze(1).float().to(device)
    masks = masks.float().to(device)
    with torch.inference_mode():
        x, t = stone(slices, masks, target)
    
    x = x.flatten(2).to(device)
    t = t.flatten(2).to(device)
    y = vit(x, target)

    y = y.view(1, patch_size, patch_size).unsqueeze(1)
    t = t[target].view(1, patch_size, patch_size).unsqueeze(1)
    y = y.sigmoid()
    y = (y > 0.5)
    
    print('Dice from torchmetrics:', generalized_dice_score(t, y, num_classes=1, per_class=True))

    y = y.squeeze().detach().cpu().numpy()
    t = t.squeeze().detach().cpu().numpy()

    # f, a = plt.subplots(1, 2, figsize=(10, 4))

    # f.tight_layout()
    # ax1 = a.flat[0]
    # ax2 = a.flat[1]
    # ax1.set_title('Mask Prediction')
    # ax2.set_title('Mask Truth')

    # print(y.shape)
    # print(t.shape)
    # sns.heatmap((y > -0.2), ax=ax1, vmax=1)
    # sns.heatmap(t, ax=ax2, vmax=1)

    dice_score, precision_score, recall_score, accuracy_score = isa_vit_metric(y, t)

    print('Dice from medium:', dice_score)
    print('Precision from medium:', precision_score)
    print('Recall from medium:', recall_score)
    print('Accuracy from medium:', accuracy_score)
    print()

    preds.append(y)
    truths.append(t)
    cases.append(case)
    targets.append(target)
    precision_scores.append(precision_score)
    recall_scores.append(recall_score)
    dice_scores.append(dice_score)
    accuracy_scores.append(accuracy_score)
    
    counter += 1
# Out:
# c:\Users\Lex Zedrick Lorenzo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9844
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9961
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9297
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0
# Recall from medium: 0.0
# Accuracy from medium: 0.9963
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9766
#
# Dice from torchmetrics: tensor([[0.4638]], device='cuda:0')
# Dice from medium: 0.4638
# Precision from medium: 0.3125
# Recall from medium: 0.8989
# Accuracy from medium: 0.9915
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9772
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9841
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9961
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0
# Recall from medium: 0.0
# Accuracy from medium: 0.9961
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0
# Recall from medium: 0.0
# Accuracy from medium: 0.9963
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9961
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0
# Recall from medium: 0.0
# Accuracy from medium: 0.9968
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9961
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0
# Precision from medium: 0
# Recall from medium: 0
# Accuracy from medium: 1.0
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.954
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9896
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9433
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9885
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9805
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0
# Precision from medium: 0
# Recall from medium: 0
# Accuracy from medium: 1.0
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9728
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9961
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9922
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9785
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0
# Precision from medium: 0
# Recall from medium: 0
# Accuracy from medium: 1.0
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9922
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9873
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9922
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9954
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9961
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0
# Precision from medium: 0
# Recall from medium: 0
# Accuracy from medium: 1.0
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9961
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0.0
# Accuracy from medium: 0.9945
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0.0
# Precision from medium: 0.0
# Recall from medium: 0
# Accuracy from medium: 0.9844
#
# Dice from torchmetrics: tensor([[0.]], device='cuda:0')
# Dice from medium: 0
# Precision from medium: 0
# Recall from medium: 0
# Accuracy from medium: 1.0

# %%
def avg(scores):
    return sum(scores) / len(scores)

# %%
print('Precision:', round(avg(precision_scores), 3))
print('Recall:', round(avg(recall_scores), 3))
print('Dice:', round(avg(dice_scores), 3))
print('Accuracy:', round(avg(accuracy_scores), 3))
# Out:
# Precision: 0.009
# Recall: 0.025
# Dice: 0.013
# Accuracy: 0.987

# %%
num = dice_scores.index(max(dice_scores))
print(num)

f, a = plt.subplots(1, 2, figsize=(10, 4))

f.tight_layout()
ax1 = a.flat[0]
ax2 = a.flat[1]
ax1.set_title('Mask Prediction')
ax2.set_title('Mask Truth')

pred = preds[num]
truth = truths[num]

print(dice_scores[num])

sns.heatmap((pred > 0.5), ax=ax1, vmax=1)
sns.heatmap(truth, ax=ax2, vmax=1)
# Out:
# 5
# 0.4638
# <Axes: title={'center': 'Mask Truth'}>
