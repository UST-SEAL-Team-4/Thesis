# %%
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform, z_score_normalization
from project.utils import collate_fn, plot_mri_slice, plot_all_slices, plot_all_slices_from_array, collatev2
import winsound
from torchvision.models import resnet18, ResNet18_Weights
from project.utils import memcheck, compute_statistics
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.20 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations

# %%
import logging
from datetime import datetime as dtt
import os

path = 'logs'
os.makedirs(path, exist_ok=True)
dte = dtt.now().strftime('%b_%d_%Y_%H%M%S')

logger = logging.getLogger('andy')
fh = logging.FileHandler(f'logs/{dte}.log')
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)

logger.setLevel(logging.DEBUG)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)

logger.addHandler(fh)

dte
# Out:
# 'Oct_31_2024_093330'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ### Config for fitter

# %%
from project.model import RPN

config = {
    'model': RPN(
        input_dim=512,
        output_dim=4,
        image_size=300,
        nh=4,
        pretrained=True
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 20,
    'loss': nn.SmoothL1Loss(),
    # 'loss': nn.MSELoss(),
    # 'loss': nn.L1Loss(),
    'lr': 0.0001
}
# Out:
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# #### Load Pretrained Embedder

# %% [raw]
# model = config['model']

# %% [raw]
# model.embedder.load_state_dict(torch.load('weights/Encoder_weights_Final_301024012901.pt'))

# %% [markdown]
# #### Load RPN Weights

# %% [raw]
# model = config['model']
# model.load_state_dict(torch.load('RPN_weights_241024213949.pt'))

# %% [markdown]
# ### Load dataset

# %%
ds = Dataset()

data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 8)

# %%
data = data.query('has_microbleed_slice == 1').reset_index(drop=True)
data
# Out:
#                                                    mri  \
# 0    C:\Users\araza\Documents\1\gits\thesis_project...
# 1    C:\Users\araza\Documents\1\gits\thesis_project...
# 2    C:\Users\araza\Documents\1\gits\thesis_project...
# 3    C:\Users\araza\Documents\1\gits\thesis_project...
# 4    C:\Users\araza\Documents\1\gits\thesis_project...
# ..                                                 ...
# 359  C:\Users\araza\Documents\1\gits\thesis_project...
# 360  C:\Users\araza\Documents\1\gits\thesis_project...
# 361  C:\Users\araza\Documents\1\gits\thesis_project...
# 362  C:\Users\araza\Documents\1\gits\thesis_project...
# 363  C:\Users\araza\Documents\1\gits\thesis_project...
#
#                                                  masks  target  \
# 0    C:\Users\araza\Documents\1\gits\thesis_project...       8
# 1    C:\Users\araza\Documents\1\gits\thesis_project...       9
# 2    C:\Users\araza\Documents\1\gits\thesis_project...      11
# 3    C:\Users\araza\Documents\1\gits\thesis_project...      12
# 4    C:\Users\araza\Documents\1\gits\thesis_project...      15
# ..                                                 ...     ...
# 359  C:\Users\araza\Documents\1\gits\thesis_project...      25
# 360  C:\Users\araza\Documents\1\gits\thesis_project...      26
# 361  C:\Users\araza\Documents\1\gits\thesis_project...      24
# 362  C:\Users\araza\Documents\1\gits\thesis_project...      25
# 363  C:\Users\araza\Documents\1\gits\thesis_project...      20
#
#      has_microbleed_case  has_microbleed_slice  cohort   max_value  slices
# 0                      1                     1       1  928.405273      35
# 1                      1                     1       1  928.405273      35
# 2                      1                     1       1  928.405273      35
# 3                      1                     1       1  928.405273      35
# 4                      1                     1       1  928.405273      35
# ..                   ...                   ...     ...         ...     ...
# 359                    1                     1       3  241.000000      36
# 360                    1                     1       3  241.000000      36
# 361                    1                     1       3  448.000000      39
# 362                    1                     1       3  448.000000      39
# 363                    1                     1       3  253.000000      39
#
# [364 rows x 8 columns]

# %% [markdown]
# ### `DataLoader` Generator

# %%
def iqr(data, col):
    q3 = data[col].quantile(0.75)
    q1 = data[col].quantile(0.25)
    iqr = q3-q1
    new = data[(data[col] < (q3 + 1.5*iqr)) & (data[col] > (q1 - 1.5*iqr))]
    return new

# %%
from sklearn.model_selection import train_test_split

def make_loaders(data,
                 cohort,
                 batch_size,
                 test_size=0.2,
                 random_state=12,
                 target_shape=(300, 300),
                 rpn_mode=True,
                 logger=None
                ):
    data = data[data.cohort == cohort]
    # data = iqr(data, 'max_value')
    
    s = f'Creating loaders for Cohort {cohort}\n'

    data_train, data_test = train_test_split(
        data,
        test_size=test_size,
        random_state=random_state
    )

    s += f'TRAIN & TEST: {data_train.shape, data_test.shape}\n'

    paths = data_train.mri.unique().tolist()
    s += f'Total Unique MRI Samples in data_train: {len(paths)}\n'
    
    global_min, global_max = compute_statistics(paths)
    s += f'GLOBAL MIN & MAX {global_min, global_max}\n'

    transform = NiftiToTensorTransform(
        target_shape=target_shape,
        rpn_mode=rpn_mode,
        normalization=(global_min, global_max)
    )

    train_set = VALDODataset(
        cases=data_train.mri.tolist(),
        masks=data_train.masks.tolist(),
        target=data_train.target.tolist(),
        transform=transform
    )
    val_set = VALDODataset(
        cases=data_test.mri.tolist(),
        masks=data_test.masks.tolist(),
        target=data_test.target.tolist(),
        transform=transform
    )

    train_loader = DataLoader(
        train_set,
        shuffle=True,
        batch_size=batch_size,
        collate_fn=collatev2
    )
    val_loader = DataLoader(
        val_set,
        shuffle=True,
        batch_size=batch_size,
        collate_fn=collatev2
    )

    if logger != None:
        logger.info(s)
    else:
        print(s)
    
    return train_loader, val_loader

# %% [markdown]
# ### Fitter

# %%
from project import Fitter

class RPNFitter(Fitter):
    def train_one_epoch(self, train_loader):
        self.model.train()
        loss_history = []
        counter = 0
        for batch in train_loader:
            # self.log('----------------- BATCH -----------------')
            Y = []
            T = []
            for slices, masks, target, case in batch:
                x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                masks = masks.squeeze(1).float().to(self.device)/300
                y = self.model(x, target)
                Y.append(y)
                T.append(masks[target])
            
            losses = self.loss(torch.stack(Y), torch.stack(T))
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += 1
            # if counter % len(batch) == 0:
            self.log(f'Batch:\t{counter}/{len(train_loader)}')
            self.log(f'Batch samples:\t{len(batch)}')
            self.log(f'Current error:\t{losses}\n')
            
            loss_history.append(losses.detach().cpu().numpy())
            
            # del losses, Y, T
            # torch.cuda.empty_cache()
            # logger.info(f'MEMORY after CLEARING MEMORY\t{memcheck()}')
        
        return loss_history
    def validation(self, val_loader):
        self.model.eval()
        loss_history = []
        with torch.inference_mode():
            for batch in val_loader:
                Y = []
                T = []
                for slices, masks, target, case in batch:
                    x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                    masks = masks.squeeze(1).float().to(self.device)/300
                    y = self.model(x, target)
                    Y.append(y)
                    T.append(masks[target])
                losses = self.loss(torch.stack(Y), torch.stack(T))
                loss_history.append(losses.cpu().numpy())
        return loss_history

# %%
fitter = RPNFitter(config, logger=logger)

# %% [markdown]
# ### Training

# %%
tl, vl = make_loaders(
    data=data,
    cohort=3,
    batch_size=2
)
# Out:
# Creating loaders for Cohort 3
# TRAIN & TEST: ((37, 8), (10, 8))
# Total Unique MRI Samples in data_train: 26
# GLOBAL MIN & MAX (0.0, 664.0)

# %%
thist, vhist = fitter.fit(tl, vl)
# Out:
# INFO:andy:EPOCH 0 ==============================
# C:\Program Files\Python310\lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# C:\Program Files\Python310\lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.03349815309047699
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.015790564939379692
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.012550652027130127
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.02177763730287552
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.021852117031812668
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.017817329615354538
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.007707627490162849
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005964621901512146
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.011040865443646908
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.019945412874221802
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.015393206849694252
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.01627025008201599
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.011189641430974007
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00803085695952177
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.019804101437330246
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.014683823101222515
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.01846073940396309
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.01194685511291027
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0053734006360173225
#
# INFO:andy:EPOCH 1 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.021482817828655243
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.008711462840437889
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.009709830395877361
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004565100185573101
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002588065108284354
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.012898018583655357
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0057196710258722305
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0058187926188111305
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005289739929139614
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.010508193634450436
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.008214565925300121
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00872244592756033
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.01072115171700716
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.018240289762616158
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0030508232302963734
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005679628346115351
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004242637660354376
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.010466519743204117
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.02206455171108246
#
# INFO:andy:EPOCH 2 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0036739232018589973
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.010104335844516754
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003042293945327401
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0030301250517368317
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.007628009654581547
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0021970272064208984
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004400337114930153
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0028519057668745518
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015386298764497042
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.012376370839774609
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0026091369800269604
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005301562137901783
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0027572913095355034
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002419679658487439
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.006002927664667368
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001227174187079072
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.006634577643126249
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.007730904966592789
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.002511553931981325
#
# INFO:andy:EPOCH 3 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002625857712700963
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003141198307275772
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0035935649648308754
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015386291779577732
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0034192190505564213
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0035320445895195007
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0024565670173615217
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001341754337772727
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0022339830175042152
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0069736819714307785
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0028332576621323824
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0033410126343369484
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0023613714147359133
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.008410606533288956
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0028830196242779493
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0027061798609793186
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017478973604738712
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004770114552229643
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0041826460510492325
#
# INFO:andy:EPOCH 4 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015576789155602455
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0022893259301781654
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005030854605138302
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0027349861338734627
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0034002128522843122
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002654429292306304
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005752690602093935
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004601117689162493
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002855151891708374
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015767670702189207
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0031403701286762953
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005521135870367289
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018475488759577274
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003496980294585228
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004451392218470573
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0036342707462608814
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004388562403619289
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002498544752597809
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.00046841095900163054
#
# INFO:andy:EPOCH 5 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0027327900752425194
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003308285493403673
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00790546927601099
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0024460090789943933
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0009456730913370848
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0043994588777422905
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0005863283295184374
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.007348434068262577
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.010700656101107597
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0030055041424930096
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0021989229135215282
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010112372692674398
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0026428927667438984
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004609451163560152
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004334138706326485
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.006895106285810471
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004968424793332815
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0040262737311422825
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.001564954873174429
#
# INFO:andy:EPOCH 6 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.006767494138330221
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0030318801291286945
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00716684153303504
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004740939941257238
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003986445255577564
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014727367088198662
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.007501909509301186
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004977192729711533
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0011133933439850807
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0011801882646977901
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002162783406674862
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003380938433110714
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014860695227980614
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0037077979650348425
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013798624277114868
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001117912819609046
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002379264449700713
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0006808189209550619
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.003027416067197919
#
# INFO:andy:EPOCH 7 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018233227310702205
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001355703454464674
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0034818779677152634
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017834813334047794
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0025641298852860928
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0038257057312875986
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0037952850107103586
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004292090889066458
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0020531623158603907
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0020012520253658295
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010208752937614918
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001977450679987669
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0004050551797263324
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004210141021758318
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.006786711048334837
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014339226763695478
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013443867210298777
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004268122836947441
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0012706692796200514
#
# INFO:andy:EPOCH 8 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014345496892929077
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0008420789381489158
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002807758515700698
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012129731476306915
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0005800517974421382
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014741893392056227
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002530008088797331
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001186306239105761
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017571907956153154
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0009553437121212482
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004247936420142651
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002846021205186844
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002925344742834568
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002217610366642475
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0009321856778115034
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002096337266266346
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005447977222502232
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015390361659228802
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0031209741719067097
#
# INFO:andy:EPOCH 9 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004612651187926531
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0033002030104398727
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002591249067336321
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0032832948490977287
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0028161979280412197
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004109956789761782
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0034558959305286407
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0005354802706278861
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0022178369108587503
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004833909682929516
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005217667669057846
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0007959657814353704
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.000974100548774004
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0004470825078897178
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0033273505978286266
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00156744837295264
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003456529462710023
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010283754672855139
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.003331240965053439
#
# INFO:andy:EPOCH 10 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010440530022606254
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002507811179384589
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002490371698513627
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0031625153496861458
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001631451305001974
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.005511868745088577
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012792780762538314
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00078210374340415
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001961294561624527
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00039234498399309814
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0035702174063771963
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0011716927401721478
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0009629969717934728
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010735937394201756
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018718328792601824
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0038780358154326677
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0028306343592703342
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003462217515334487
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.00022825095220468938
#
# INFO:andy:EPOCH 11 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015184342628344893
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017090898472815752
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0032086577266454697
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0009999817702919245
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0020271684043109417
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0016525901155546308
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015321671962738037
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014546399470418692
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017878917278721929
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0023158728145062923
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00106274604331702
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.000919305020943284
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013149121077731252
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001469647977501154
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0007290226640179753
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017736611189320683
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0037253927439451218
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018099152948707342
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0017761590424925089
#
# INFO:andy:EPOCH 12 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013494743034243584
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013967604609206319
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018161751795560122
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0022768101189285517
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015728692524135113
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002646865788847208
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0008142605074681342
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0006855182582512498
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0016735891113057733
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0027440267149358988
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002443842589855194
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017207131022587419
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.006225623190402985
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0016182337421923876
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0016609876183792949
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0022854686249047518
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018390745390206575
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0016829329542815685
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0005663384217768908
#
# INFO:andy:EPOCH 13 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0005680619506165385
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013771792873740196
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002862943336367607
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0023584351874887943
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017258420120924711
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012038336135447025
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0009427279001101851
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015654374146834016
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0006132361595518887
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0021570792887359858
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0007560533122159541
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001295628841035068
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0006069140508770943
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017416859045624733
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002943384926766157
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012603523209691048
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0037381243892014027
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001868529594503343
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0008260395261459053
#
# INFO:andy:EPOCH 14 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0021603761706501245
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0005648286314681172
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0011373413726687431
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001298624905757606
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015384384896606207
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012894092360511422
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013315551914274693
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0033384542912244797
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0023696310818195343
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015935025876387954
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013042050413787365
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014214817201718688
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002091881586238742
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00032613903749734163
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015732464380562305
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001461360021494329
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0006757189985364676
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0007350256200879812
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0013766547199338675
#
# INFO:andy:EPOCH 15 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003638091031461954
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018149898387491703
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00207018805667758
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014104526489973068
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0007814854616299272
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015319178346544504
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002092583803460002
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013467411044985056
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015680219512432814
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002189288381487131
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00051144725875929
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001831435482017696
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017621841980144382
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0021458244882524014
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001031217398121953
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017618692945688963
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0022722799330949783
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.000797228654846549
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0018369907047599554
#
# INFO:andy:EPOCH 16 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003089004196226597
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002057276200503111
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018325566779822111
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0019633483607321978
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003323730081319809
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013034241273999214
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002169611630961299
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012791964691132307
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0008038566447794437
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0023328347597271204
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013214114587754011
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0009633649024181068
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0015937068965286016
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0008756488095968962
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.004240707959979773
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0011511853663250804
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0032075857743620872
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0014896206557750702
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0007482406799681485
#
# INFO:andy:EPOCH 17 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017756050219759345
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002547507407143712
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010576295899227262
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001311528729274869
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0004884955706074834
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001768027083016932
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00025422454928047955
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010666534071788192
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012511766981333494
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0006487619830295444
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0011904173297807574
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012048130156472325
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0016216975636780262
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0001722599845379591
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0016628009034320712
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0021625757217407227
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0009570161928422749
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001807639840990305
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.003165417117998004
#
# INFO:andy:EPOCH 18 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0021393841598182917
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0005195255507715046
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010702902218326926
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002008205046877265
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002062779851257801
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0021612776909023523
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017004976980388165
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.000695297378115356
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002800992224365473
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012122748885303736
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0004991301102563739
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010508244158700109
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0019754725508391857
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0010678324615582824
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0030662876088172197
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00110148498788476
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0004498482740018517
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0007161028916016221
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.001154790399596095
#
# INFO:andy:EPOCH 19 ==============================
# INFO:andy:Batch:	1/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0020831984002143145
#
# INFO:andy:Batch:	2/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001110738841816783
#
# INFO:andy:Batch:	3/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0006063468754291534
#
# INFO:andy:Batch:	4/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012763849226757884
#
# INFO:andy:Batch:	5/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.002637397265061736
#
# INFO:andy:Batch:	6/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0020739699248224497
#
# INFO:andy:Batch:	7/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.00267586437985301
#
# INFO:andy:Batch:	8/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0022760890424251556
#
# INFO:andy:Batch:	9/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013602405088022351
#
# INFO:andy:Batch:	10/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0045009516179561615
#
# INFO:andy:Batch:	11/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0016848603263497353
#
# INFO:andy:Batch:	12/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0017193378880620003
#
# INFO:andy:Batch:	13/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.003379615256562829
#
# INFO:andy:Batch:	14/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0018714944599196315
#
# INFO:andy:Batch:	15/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.001998004037886858
#
# INFO:andy:Batch:	16/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0012820879928767681
#
# INFO:andy:Batch:	17/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0031553797889500856
#
# INFO:andy:Batch:	18/19
# INFO:andy:Batch samples:	2
# INFO:andy:Current error:	0.0013069190317764878
#
# INFO:andy:Batch:	19/19
# INFO:andy:Batch samples:	1
# INFO:andy:Current error:	0.0006909666699357331

# %%
winsound.Beep(500, 500)
winsound.Beep(500, 500)
winsound.Beep(500, 500)

# %%
import seaborn as sns
import numpy as np

th = torch.tensor(np.array(thist))
vh = torch.tensor(np.array(vhist))
# print(th.shape)
sns.lineplot(th.mean(1), label='Training history')
sns.lineplot(vh.mean(1), label='Validation history')
# Out:
# <Axes: >

# %% [markdown]
# ### Save the weights

# %% [raw]
# model = config['model']

# %% [raw]
# s = f'RPN_test15a_weights_{dte}.pt'
# s

# %% [raw]
# model = config['model']

# %% [raw]
# torch.save(model.state_dict(), s)

# %% [markdown]
# # Summary
#
# Trained using bboxes that have a padding of 50 or more. Improved the model but it seems like cheating to get the metrics up
#
# Decision for which embedder to use is also decided here
#
# TODO:
# - multiple bounding box proposal
# - start with vit optimizations

# %% [markdown]
# # Trial

# %%
model = fitter.model

# %%
sample = next(enumerate(vl))

# %%
slices, masks, target, case = sample[1][1]

# %%
x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(device)
T = masks.squeeze(1).float().to(device)

# %%
y = model(x, target)

# %%
y
# Out:
# tensor([[0.2164, 0.2440, 0.5812, 0.7298]], device='cuda:0',
#        grad_fn=<SigmoidBackward0>)

# %%
fitter.loss(y, T[target])
# Out:
# tensor(157.5533, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)

# %%
masks[target]
# Out:
# tensor([[[ 80.8594, 116.0156, 201.5625, 235.5469]]], dtype=torch.float64)

# %%
y
# Out:
# tensor([[0.2164, 0.2440, 0.5812, 0.7298]], device='cuda:0',
#        grad_fn=<SigmoidBackward0>)

# %%
bbox = masks[target].squeeze().cpu().long()

# %%
y = (y*300).squeeze().detach().cpu().long()

# %%
bbox, y
# Out:
# (tensor([ 80, 116, 201, 235]), tensor([ 64,  73, 174, 218]))

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

ax = sns.heatmap(x[target][0].squeeze().cpu(), cmap='gray')

truth = patches.Rectangle(
    (bbox[0], bbox[1]),
    bbox[2] - bbox[0],
    bbox[3] - bbox[1],
    linewidth=1, edgecolor='g', facecolor='none'
)

pred = patches.Rectangle(
    (y[0], y[1]),
    y[2] - y[0],
    y[3] - y[1],
    linewidth=1, edgecolor='r', facecolor='none'
)

ax.add_patch(truth)
ax.add_patch(pred)
plt.show()
