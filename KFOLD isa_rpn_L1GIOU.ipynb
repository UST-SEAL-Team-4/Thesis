# %%
import torch
import torch.nn as nn
import pandas as pd
from project.dataset import Dataset, VALDODataset
from torch.utils.data import DataLoader
from project.preprocessing import NiftiToTensorTransform
from project.utils import collatev2
import winsound
from project.utils import compute_statistics
from project.evaluation import isa_rpn_metric, isa_vit_metric, Tracker, L1_GIOU
# Out:
# c:\Users\nigel\AppData\Local\Programs\Python\Python312\Lib\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
rpn_tk = Tracker()

# %% [markdown]
# ### Monitoring and CUDA Setup

# %%
import logging
from datetime import datetime as dtt
import os

path = 'logs'
os.makedirs(path, exist_ok=True)
os.makedirs('history', exist_ok=True)
rn = dtt.now()
dte = rn.strftime('%b_%d_%Y_%H%M%S')

logger = logging.getLogger('kess')
fh = logging.FileHandler(f'logs/rpn_vit_{dte}.log')
formatter = logging.Formatter(
    '%(asctime)s - %(levelname)s - %(message)s'
)

logger.setLevel(logging.DEBUG)
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)

logger.addHandler(fh)

dte
# Out:
# 'Nov_21_2024_094819'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
rpn_tk.date = rn
rpn_tk.logfile = f'rpn_vit_{dte}.log'
rpn_tk.device = device

# %% [markdown]
# ### Config for RPN and ViT Fitter

# %%
from project.model import RPN, ISAVIT

rpn_config = {
    'model': RPN(
        input_dim=512,
        output_dim=4,
        image_size=300,
        global_context=True,
        nh=4,
        pretrained=True
    ).to(device),
    'optimizer': torch.optim.Adam,
    'device': device,
    'epochs': 10,
    'loss': L1_GIOU.loss,
    'lr': 0.0001
}
# Out:
# c:\Users\nigel\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
rpn_tk.model = 'RPN'
rpn_tk.model_hyperparams = rpn_config['model'].config
rpn_tk.uses_resnet = rpn_config['model'].config['pretrained']
rpn_tk.optimizer = f"{rpn_config['optimizer']}"
rpn_tk.epochs = rpn_config['epochs']
rpn_tk.loss = f"{rpn_config['loss']}"
rpn_tk.lr = rpn_config['lr']

# %% [markdown]
# ### Dataset Loading

# %%
data = pd.read_csv('targets.csv')
data.shape
# Out:
# (7986, 9)

# %%
data = data.query('has_microbleed_slice == 1').reset_index(drop=True)
rpn_tk.only_cmb_slices = True
data
# Out:
#                                                    mri  \
# 0    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 1    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 2    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 3    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 4    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# ..                                                 ...
# 359  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 360  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 361  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 362  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 363  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
#
#                                                  masks  \
# 0    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 1    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 2    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 3    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 4    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# ..                                                 ...
# 359  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 360  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 361  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 362  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
# 363  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...
#
#                                               stripped  target  \
# 0    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...       8
# 1    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...       9
# 2    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...      11
# 3    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...      12
# 4    c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...      15
# ..                                                 ...     ...
# 359  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...      25
# 360  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...      26
# 361  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...      24
# 362  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...      25
# 363  c:\Users\nigel\Documents\Thesis\Dataset\VALDO_...      20
#
#      has_microbleed_case  has_microbleed_slice  cohort   max_value  slices
# 0                      1                     1       1  928.405273      35
# 1                      1                     1       1  928.405273      35
# 2                      1                     1       1  928.405273      35
# 3                      1                     1       1  928.405273      35
# 4                      1                     1       1  928.405273      35
# ..                   ...                   ...     ...         ...     ...
# 359                    1                     1       3  241.000000      36
# 360                    1                     1       3  241.000000      36
# 361                    1                     1       3  448.000000      39
# 362                    1                     1       3  448.000000      39
# 363                    1                     1       3  253.000000      39
#
# [364 rows x 9 columns]

# %% [markdown]
# ### Preprocessing and Train-Test Split Function

# %%
from sklearn.model_selection import train_test_split

def make_loaders(data,
                 cohort,
                 test_size=0.2,
                 random_state=12,
                 target_shape=(300, 300),
                 rpn_mode=True,
                 logger=None,
                 rpn_tracker=rpn_tk,
                ):
    if cohort == 1:
        rpn_tracker.cohort1 = True
    if cohort == 2:
        rpn_tracker.cohort2 = True
    if cohort == 3:
        rpn_tracker.cohort3 = True
    
    rpn_tracker.test_size = test_size
    data = data[data.cohort == cohort]
    
    s = f'Creating loaders for Cohort {cohort}\n'

    data_train, data_test = train_test_split(
        data,
        test_size=test_size,
        random_state=random_state
    )

    s += f'TRAIN & TEST: {data_train.shape, data_test.shape}\n'

    paths = data_train.stripped.unique().tolist()
    s += f'Total Unique MRI Samples in data_train: {len(paths)}\n'
    
    global_min, global_max = compute_statistics(paths)
    s += f'GLOBAL MIN & MAX {global_min, global_max}\n'

    transform = NiftiToTensorTransform(
        target_shape=target_shape,
        rpn_mode=rpn_mode,
        normalization=(global_min, global_max)
    )

    train_set = VALDODataset(
        cases=data_train.stripped.tolist(),
        masks=data_train.masks.tolist(),
        target=data_train.target.tolist(),
        transform=transform
    )
    val_set = VALDODataset(
        cases=data_test.stripped.tolist(),
        masks=data_test.masks.tolist(),
        target=data_test.target.tolist(),
        transform=transform
    )

    if logger != None:
        logger.info(s)
    else:
        print(s)
    
    return train_set, val_set

# %% [markdown]
# ### RPN Fitter

# %%
from project import Fitter

# %%
class RPNFitter(Fitter):
    def train_one_epoch(self, train_loader):
        self.model.train()
        loss_history = []
        evaluation_metric = {
            'iou_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': []
        }
        counter = 0
        for batch in train_loader:
            # self.log('----------------- BATCH -----------------')
            Y = []
            T = []
            for slices, masks, target, case in batch:
                x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                # x = slices.squeeze(1).float().to(self.device)
                masks = masks.squeeze(1).float().to(self.device)/300
                y = self.model(x, target)

                iou_score, precision_score, recall_score, f1_score = isa_rpn_metric(image_size=300, target_bbox=masks[target], predicted_bbox=y)
                evaluation_metric['iou_score'].append(iou_score)
                evaluation_metric['precision_score'].append(precision_score)
                evaluation_metric['recall_score'].append(recall_score)
                evaluation_metric['f1_score'].append(f1_score)
                # self.log(f'EVAL METS: {iou_score, precision_score, recall_score, f1_score}')
                Y.append(y)
                T.append(masks[target])
            
            losses= self.loss(pred= torch.stack(Y), target = torch.stack(T))
            print("L1 and GIOU Training loss: ", losses)
            self.optimizer.zero_grad()
            losses.backward()
            self.optimizer.step()
            counter += 1
            # if counter % len(batch) == 0:
            self.log(f'Batch:\t{counter}/{len(train_loader)}')
            self.log(f'Batch samples:\t{len(batch)}')
            self.log(f'Current error:\t{losses}\n')
            
            
            loss_history.append(losses.detach().cpu().numpy())
        
        self.log(f'\nTraining Evaluation Metric:')
        self.log(f"Avg IOU: {sum(evaluation_metric['iou_score']) / len(evaluation_metric['iou_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        
        return loss_history, evaluation_metric
    def validation(self, val_loader):
        self.model.eval()
        loss_history = []
        evaluation_metric = {
            'iou_score': [], 
            'precision_score': [], 
            'recall_score': [], 
            'f1_score': []
        }
        with torch.inference_mode():
            for batch in val_loader:
                Y = []
                T = []
                for slices, masks, target, case in batch:
                    x = slices.squeeze(1).repeat(1, 3, 1, 1).float().to(self.device)
                    # x = slices.squeeze(1).float().to(self.device)
                    masks = masks.squeeze(1).float().to(self.device)/300
                    y = self.model(x, target)
                    iou_score, precision_score, recall_score, f1_score = isa_rpn_metric(image_size=300, target_bbox=masks[target], predicted_bbox=y)
                    evaluation_metric['iou_score'].append(iou_score)
                    evaluation_metric['precision_score'].append(precision_score)
                    evaluation_metric['recall_score'].append(recall_score)
                    evaluation_metric['f1_score'].append(f1_score)
                    Y.append(y)
                    T.append(masks[target])
                losses= self.loss(pred= torch.stack(Y), target = torch.stack(T))
                print("L1 and GIOU Validation loss: ", losses)
                loss_history.append(losses.cpu().numpy())
        self.log(f'\nValidation Evaluation Metric:')
        self.log(f"Avg IOU: {sum(evaluation_metric['iou_score']) / len(evaluation_metric['iou_score'])}")
        self.log(f"Avg Precision: {sum(evaluation_metric['precision_score']) / len(evaluation_metric['precision_score'])}")
        self.log(f"Avg Recall: {sum(evaluation_metric['recall_score']) / len(evaluation_metric['recall_score'])}")
        self.log(f"Avg F1: {sum(evaluation_metric['f1_score']) / len(evaluation_metric['f1_score'])}")
        return loss_history, evaluation_metric

# %% [markdown]
# ### Train-Test Split

# %%
rpn_t1, rpn_v1 = make_loaders(
    data=data,
    cohort=1,
    rpn_mode=True
)

rpn_t3, rpn_v3 = make_loaders(
    data=data,
    cohort=3,
    rpn_mode=True
)
# Out:
# Creating loaders for Cohort 1
# TRAIN & TEST: ((36, 9), (9, 9))
# Total Unique MRI Samples in data_train: 8
# GLOBAL MIN & MAX (0.0, 1417.92822265625)
#
# Creating loaders for Cohort 3
# TRAIN & TEST: ((37, 9), (10, 9))
# Total Unique MRI Samples in data_train: 26
# GLOBAL MIN & MAX (0.0, 573.0)

# %%
from torch.utils.data import ConcatDataset

rpn_train_set = ConcatDataset([rpn_t1, rpn_t3])
rpn_test_set = ConcatDataset([rpn_v1, rpn_v3])

print(f'RPN Train Set Size: {rpn_train_set}')
print(f'RPN Test Set Size: {rpn_test_set}')
# Out:
# RPN Train Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x000001C41D51F530>
# RPN Test Set Size: <torch.utils.data.dataset.ConcatDataset object at 0x000001C434F30740>

# %%
batchs = 20

rpn_test_dataloader = DataLoader(
    rpn_test_set,
    shuffle=True,
    batch_size=batchs,
    collate_fn=collatev2
)

# %% [markdown]
# ### K-Fold Cross Validation

# %%
from torch.utils.data import Subset
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=45)
kf
# Out:
# KFold(n_splits=5, random_state=45, shuffle=True)

# %%
from project.model import Feeder, GCRPN
from project.preprocessing import NiftiToTensorTransform, get_transform

image_size = 300
patch_size = 32

# %%
rpn_test_iou = []
rpn_test_precision = []
rpn_test_recall = []
rpn_test_f1 = []

# %%
rpn_fold_metrics = []

fold_dir = f'./fold/{dte}'
os.makedirs(fold_dir, exist_ok=True)

for i, (train_index, val_index) in enumerate(kf.split(rpn_train_set)):
    print(f'Fold {i + 1}/{5}')
    logger.info(f'################################### Fold {i+1}/5 ###################################')
    
    # RPN
    rpn_config['model'] = RPN(**rpn_tk.model_hyperparams).to(device)
    
    rpn_fitter = RPNFitter(rpn_config, logger=logger)
    
    rpn_train_subset = Subset(rpn_train_set, train_index)
    rpn_val_subset = Subset(rpn_train_set, val_index)

    rpn_tk.batch_size = 2
    
    rpn_train_subset_dl = DataLoader(
        rpn_train_subset,
        shuffle=True,
        batch_size=rpn_tk.batch_size,
        collate_fn=collatev2
    )
    
    rpn_val_subset_dl = DataLoader(
        rpn_val_subset,
        shuffle=True,
        batch_size=rpn_tk.batch_size,
        collate_fn=collatev2
    )
    
    rpn_thist, rpn_vhist, rpn_tmhist, rpn_vmhist = rpn_fitter.fit(rpn_train_subset_dl, rpn_val_subset_dl)
    
    rpn_fold_metrics.append({
        'fold': i + 1,
        'training_history': rpn_thist,
        'validation_history': rpn_vhist,
        'training_metrics': rpn_tmhist,
        'validation_metrics': rpn_vmhist
    })
    
    rpn_h, rpn_mh = rpn_fitter.validation(rpn_test_dataloader)
    rpn_valmets = pd.DataFrame(rpn_mh)
    rpn_mets = rpn_valmets.mean()
    
    rpn_test_iou.append(rpn_mets.iou_score)
    rpn_test_precision.append(rpn_mets.precision_score)
    rpn_test_recall.append(rpn_mets.recall_score)
    rpn_test_f1.append(rpn_mets.f1_score)
    
    os.makedirs(f'{fold_dir}/fold_{i+1}', exist_ok=True)
    torch.save(rpn_fitter.model.state_dict(), f'{fold_dir}/fold_{i+1}/rpn_fold{i+1}.pt')
# Out:
# Fold 1/5
# c:\Users\nigel\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# L1 and GIOU Training loss:  tensor(1.6387, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-0.2877, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-0.9006, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-6.6869, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.9204, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-0.7200, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.9174, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-11.2769, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-8.4935, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.1457, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.0795, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.6874, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-16.7257, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.3605, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-7.7953, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.7944, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.3863, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-22.1431, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4016, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-9.0266, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4458, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-8.1543, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.6021, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-10.3398, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-8.9162, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.1091, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.1083, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.2553, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.1766, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Validation loss:  tensor(-13.3386, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-4.5253, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-6.5262, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-13.3650, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-7.8579, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-13.3848, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-6.4696, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-4.4722, device='cuda:0')
# L1 and GIOU Training loss:  tensor(-21.6986, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4881, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5565, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5291, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-10.4027, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.2241, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-9.0012, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-9.2323, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-7.9885, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-22.1905, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4353, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4985, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.0802, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.4790, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-16.4994, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.1102, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.3470, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.2518, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.3347, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-8.9455, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-21.7779, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.1154, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-8.2149, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.5268, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5419, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.6272, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.3984, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-2.3065, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.5361, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Validation loss:  tensor(-15.2064, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-4.5300, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-8.5093, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-13.5547, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-6.1361, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-4.4918, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-13.4112, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-4.4954, device='cuda:0')
# L1 and GIOU Training loss:  tensor(-4.3400, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-19.2955, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.3065, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.7072, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5975, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-16.2456, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.2532, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-21.9808, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.6001, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.5666, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.1860, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.2955, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5031, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.1680, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.6026, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4495, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.8159, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-8.2414, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-2.3050, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.6206, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.3675, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5504, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.4393, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-9.3339, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.6320, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-9.1769, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.8320, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5530, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-21.3529, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Validation loss:  tensor(-13.4296, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(
device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-17.5500, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.7043, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-6.5397, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-0.9546, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Validation loss:  tensor(-13.4753, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-13.7957, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-16.5086, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-9.4792, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-12.7094, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-13.5274, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-9.0364, device='cuda:0')
# L1 and GIOU Training loss:  tensor(-4.4017, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-9.1633, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-15.6725, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.3090, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4892, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-8.1919, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-20.6150, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5558, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-6.2559, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-7.7243, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.5524, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4319, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.1430, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5554, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5227, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-6.2771, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.4668, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.4929, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-6.5708, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-2.7708, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.4151, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.8816, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4623, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-14.3544, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4845, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-10.5474, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.6415, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-7.3523, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-18.4344, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-22.8226, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Validation loss:  tensor(-13.8295, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-12.9957, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-9.4812, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-17.0783, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-9.0386, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-21.6000, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-4.5283, device='cuda:0')
# L1 and GIOU Training loss:  tensor(-4.0519, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.6118, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-18.2530, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.2377, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-2.7078, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5843, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.1339, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-7.3533, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5539, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-6.5618, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5239, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.6715, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.4712, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.3957, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-7.2277, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-15.1630, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4934, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.1962, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.5893, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.5334, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4664, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-5.7051, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-10.5207, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.2923, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-7.7280, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-13.6061, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-4.4961, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-15.3738, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-12.7054, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Training loss:  tensor(-3.9711, device='cuda:0', grad_fn=<AddBackward0>)
# L1 and GIOU Validation loss:  tensor(-13.0285, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-13.4187, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-12.7781, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-8.0465, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-9.4194, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-22.8361, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-9.0403, device='cuda:0')
# L1 and GIOU Validation loss:  tensor(-10.2937, device='cuda:0')

# %%
import winsound

winsound.Beep(500, 500)
winsound.Beep(500, 500)
winsound.Beep(500, 500)

# %% [markdown]
# ### Metrics Visualization

# %% [markdown]
# `rpn_fold_metrics[i]`
#
# - represents each fold
#
# `rpn_fold_metrics[1].keys()`
#
# - 'fold', 'training_history', 'validation_history', 'training_metrics', 'validation_metrics'
#
# `rpn_fold_metrics[1]['training_metrics'][i]`
#
# - represents each epoch
#
# `rpn_fold_metrics[1]['training_metrics'][1].keys()`
#
# - 'iou_score', 'precision_score', 'recall_score', 'f1_score'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_metric_history(fold_metrics, metric, title=None):
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))

    for fold in range(len(rpn_fold_metrics)):
        train = []
        test = []
        ax=axes[fold]
        
        for epoch in range(len(fold_metrics[fold]['training_metrics'])):
            th = np.array(fold_metrics[fold]['training_metrics'][epoch][metric]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_metrics'][epoch][metric]).mean()
            test.append(vh)
            
        sns.lineplot(x=range(1, len(train)+1), y=train, label=f'Training {metric}', ax=ax)
        sns.lineplot(x=range(1, len(test)+1), y=test, label=f'Validation {metric}', ax=ax)
    
    
        ax.set_title(f'{title}Training and Validation {metric}: Fold {fold+1}')
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric)
        ax.legend()
        
    plt.tight_layout()  
    plt.show()

# %%
rpn_metrics = ['iou_score', 'precision_score', 'recall_score', 'f1_score']

for metric in rpn_metrics:
    plot_metric_history(rpn_fold_metrics, metric, 'RPN ')

# %% [markdown]
# ### Loss History Visualization

# %%
def plot_loss_history(fold_metrics, title=None):
    fig, axes = plt.subplots(1, 5, figsize=(25, 5))

    for fold in range(5):
        train = []
        test = []
        ax=axes[fold]
        
        for epoch in range(len(fold_metrics[fold]['training_history'])):
            th = np.array(fold_metrics[fold]['training_history'][epoch]).mean()
            train.append(th)
            vh = np.array(fold_metrics[fold]['validation_history'][epoch]).mean()
            test.append(vh)
        
        sns.lineplot(x=range(1, len(train)+1), y=train, label='Training history', ax=ax)
        sns.lineplot(x=range(1, len(test)+1), y=test, label='Validation history', ax=ax)
        
        ax.set_title(f'{title}Training and Validation History: Fold {fold+1}')
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Loss')
        ax.legend()
    
    plt.tight_layout()  
    plt.show()

# %%
plot_loss_history(rpn_fold_metrics, 'RPN ')
# plot_loss_history(vit_fold_metrics, 'ViT ')

# %% [raw]
# rpn_hist = torch.tensor(np.array(rpn_fold_metrics))
# vit_hist = torch.tensor(np.array(vit_fold_metrics))
#
# s_rpn_hist = f'history/{dte}_rpn_hist.pt'
# s_vit_hist = f'history/{dte}_vit_hist.pt'
# rpn_tk.saved_thist = s_rpn_hist
# vit_tk.saved_vhist = s_vit_hist
# torch.save(rpn_hist, s_rpn_hist)
# torch.save(vit_hist, s_vit_hist)

# %% [markdown]
# ### Evaluate Test Set

# %% [markdown]
# #### RPN

# %%
df_rpn_metrics = pd.DataFrame(columns=['fold', 'iou', 'precision', 'recall', 'f1'])
df_rpn_metrics
# Out:
# Empty DataFrame
# Columns: [fold, iou, precision, recall, f1]
# Index: []

# %%
df_rpn_metrics['fold'] = [1, 2, 3, 4, 5]
df_rpn_metrics['iou'] = rpn_test_iou
df_rpn_metrics['precision'] = rpn_test_precision
df_rpn_metrics['recall'] = rpn_test_recall
df_rpn_metrics['f1'] = rpn_test_f1

# %%
rpn_tk.iou = df_rpn_metrics.iou.mean()
rpn_tk.precision = df_rpn_metrics.precision.mean()
rpn_tk.recall = df_rpn_metrics.recall.mean()
rpn_tk.f1 = df_rpn_metrics.f1.mean()

# %%
df_rpn_metrics
# Out:
#    fold       iou  precision    recall        f1
# 0     1  0.000000   0.000000  0.000000  0.000000
# 1     2  0.000000   0.000000  0.000000  0.000000
# 2     3  0.260845   0.316553  0.610527  0.388373
# 3     4  0.238539   0.332234  0.422720  0.347229
# 4     5  0.000000   0.000000  0.000000  0.000000

# %%
rpn_iou_score = np.array(rpn_test_iou).mean()
rpn_precision_score = np.array(rpn_test_precision).mean()
rpn_recall_score = np.array(rpn_test_recall).mean()
rpn_f1_score = np.array(rpn_test_f1).mean()

print('RPN Test Set Performance Metrics')
print(f'Average IOU: {rpn_iou_score} ')
print(f'Average Precision: {rpn_precision_score} ')
print(f'Average Recall: {rpn_recall_score} ')
print(f'Average F1 Score: {rpn_f1_score} ')
# Out:
# RPN Test Set Performance Metrics
# Average IOU: 0.09987664926601084
# Average Precision: 0.1297573348409251
# Average Recall: 0.20664940335248644
# Average F1 Score: 0.14712027287796925

# %%
df_rpn_metrics.to_csv(f'{fold_dir}/rpn_metrics.csv')

# %% [markdown]
# ### Sample

# %% [markdown]
# #### RPN

# %%
rpn_sample = next(enumerate(rpn_test_dataloader))
rpn_slices, rpn_masks, rpn_target, rpn_case = rpn_sample[1][1]

# %%
# rpn_x = rpn_slices.squeeze(1).float().to(device)
rpn_x = rpn_slices.squeeze(1).repeat(1, 3, 1, 1).float().to(device)
rpn_T = rpn_masks.squeeze(1).float().to(device)

# %%
rpn_y = rpn_fitter.model(rpn_x, rpn_target)
rpn_y
# Out:
# tensor([[9.9962e-01, 9.9967e-01, 4.1742e-04, 3.2428e-04]], device='cuda:0',
#        grad_fn=<SigmoidBackward0>)

# %%
rpn_fitter.loss(rpn_y, rpn_T[rpn_target])
# Out:
# tensor(152.6377, device='cuda:0', grad_fn=<AddBackward0>)

# %%
rpn_bbox = rpn_masks[rpn_target].squeeze().cpu().long()
rpn_y = (rpn_y*300).squeeze().detach().cpu().long()

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

ax = sns.heatmap(rpn_x[rpn_target][0].squeeze().cpu(), cmap='gray')

truth = patches.Rectangle(
    (rpn_bbox[0], rpn_bbox[1]),
    rpn_bbox[2] - rpn_bbox[0],
    rpn_bbox[3] - rpn_bbox[1],
    linewidth=1, edgecolor='g', facecolor='none'
)

pred = patches.Rectangle(
    (rpn_y[0], rpn_y[1]),
    rpn_y[2] - rpn_y[0],
    rpn_y[3] - rpn_y[1],
    linewidth=1, edgecolor='r', facecolor='none'
)

ax.add_patch(truth)
ax.add_patch(pred)
plt.show()

# %% [markdown]
# # Log Progress

# %%
rpn_tk.notes = '''
Global Context
'''

# %%
rpn_tk()
# Out:
#                            model loaded_weights stage1_weights  uses_resnet  \
# date
# 2024-11-21 09:48:19.462508   RPN           None           None         True
#
#                             only_cmb_slices  cohort1  cohort2  cohort3  \
# date
# 2024-11-21 09:48:19.462508             True     True    False     True
#
#                                                   optimizer  epochs  ...  \
# date                                                                 ...
# 2024-11-21 09:48:19.462508  <class 'torch.optim.adam.Adam'>      10  ...
#
#                               recall       f1   fpr  saved_weights  \
# date
# 2024-11-21 09:48:19.462508  0.206649  0.14712  None           None
#
#                            saved_thist  saved_vhist  \
# date
# 2024-11-21 09:48:19.462508        None         None
#
#                                                             model_hyperparams  \
# date
# 2024-11-21 09:48:19.462508  {'input_dim': 512, 'output_dim': 4, 'image_siz...
#
#                                                    logfile  device  \
# date
# 2024-11-21 09:48:19.462508  rpn_vit_Nov_21_2024_094819.log    cuda
#
#                                          notes
# date
# 2024-11-21 09:48:19.462508  \nGlobal Context\n
#
# [1 rows x 28 columns]

# %%
if os.path.exists('history/runs.csv'):
    print('Merging to old df')
    prev_df = pd.read_csv('history/runs.csv', index_col='date')
    merged = pd.concat([prev_df, rpn_tk()])
    merged.to_csv('history/runs.csv')
else:
    print('Making new csv file')
    rpn_tk().to_csv('history/runs.csv')
# Out:
# Merging to old df
